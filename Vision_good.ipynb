# %% [markdown]
# <a href="https://colab.research.google.com/github/PeterHJY628/MyOwnExample/blob/main/Vision_good.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip -q install "torch==2.4.0" tensorboard pillow torchvision accelerate huggingface_hub
# !pip -q install  --upgrade \
  "transformers==4.45.1" \
  "datasets==3.0.1" \
  "accelerate==0.34.2" \
  "evaluate==0.4.3" \
  "bitsandbytes==0.44.0" \
  "trl==0.11.1" \
  "peft==0.13.0" \
  "qwen_vl_utils"
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 797.2/797.2 MB 2.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 1.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 36.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 35.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 33.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 7.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 13.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 7.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 6.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.2/176.2 MB 6.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 8.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.4/209.4 MB 5.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 103.1 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchaudio 2.5.1+cu121 requires torch==2.5.1, but you have torch 2.4.0 which is incompatible.
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 2.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 87.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 471.6/471.6 kB 34.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 324.4/324.4 kB 25.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.0/84.0 kB 7.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 122.4/122.4 MB 7.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 318.4/318.4 kB 23.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.5/322.5 kB 25.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 10.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.6/177.6 kB 15.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 90.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 113.8/113.8 kB 10.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.0/33.0 MB 57.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 10.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 16.6 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.6.1 which is incompatible.
# torchaudio 2.5.1+cu121 requires torch==2.5.1, but you have torch 2.4.0 which is incompatible.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.environ['HF_HOME'] = '/home/sa5u24/VQA'
hf_home = os.path.expanduser(
    os.getenv("HF_HOME", os.path.join(os.getenv("XDG_CACHE_HOME", "~/.cache"), "huggingface"))
)
print(hf_home)

from huggingface_hub import login

# Replace 'your-hf-token-here' with your actual Hugging Face token
login(token="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")
# Out:
# /home/sa5u24/VQA

# %%
def generate_SM(que):
    sm = (
        "Select a model to answer the following question:\n"
        f"{que}\n"
        "Select a model only from the following model list: Segment-Video, Segment-MRI, "
        "Detect-Video, Overlaying, Surgical-VQA to answer the question.\n"
        "Generate a shortest prompt for the chosen model. "
        "Your response should be like Model: ? Prompt: ? and no other words."
    )
    return sm

def format_data(sample):
    system_message = generate_SM(sample[0])
    return [
        {
            "role": "system",
            "content": [
                {
                    "type": "text",
                    "text": system_message
                }
            ],
        },
        # {
        #     "role": "user",
        #     "content": [

        #         {
        #             "type": "text",
        #             "text": sample[0],

        #         }
        #     ],
        # },
        {
            "role": "assistant",
            "content": [
                {
                    "type": "text",
                    "text": sample[1]
                }
            ],
        },
    ]

#system_message = generate_SM(test_dataset[0][0])

# %%
from datasets import load_dataset

dataset_id = "HuggingFaceM4/ChartQA"
train_dataset, eval_dataset, test_dataset = load_dataset(dataset_id, split=['train[:10%]', 'val[:10%]', 'test[:10%]'])

train_dataset = [format_data(sample) for sample in train_dataset]
eval_dataset = [format_data(sample) for sample in eval_dataset]
test_dataset = [format_data(sample) for sample in test_dataset]

train_dataset[200], len(train_dataset), len(eval_dataset), len(test_dataset)
# Out:
# ([{'role': 'system',
#    'content': [{'type': 'text',
#      'text': 'You are a Vision Language Model specialized in interpreting visual data from chart images.\nYour task is to analyze the provided chart image and respond to queries with concise answers, usually a single word, number, or short phrase.\nThe charts include a variety of types (e.g., line charts, bar charts) and contain colors, labels, and text.\nFocus on delivering accurate, succinct answers based on the visual information. Avoid additional explanation unless absolutely necessary.'}]},
#   {'role': 'user',
#    'content': [{'type': 'text',
#      'text': 'Is the rightmost value of light brown graph 58?'}]},
#   {'role': 'assistant', 'content': [{'type': 'text', 'text': 'No'}]}],
#  2830,
#  192,
#  250)

# %%
import os
import re
import torch
import random
import numpy as np
from torch.utils.data import Dataset, DataLoader
import pandas as pd
from google.colab import drive

# Mount Google Drive to access the file
drive.mount('/content/drive')

class TextQuestionLabelDataset(Dataset):
    def __init__(self, input_file):
        # Load data from a CSV file
        self.data = pd.read_csv(input_file)
        #print(self.data.head())  # 显示前 5 行数据


        # Extract questions and labels from the Input column
        #self.questions = self.data['Input'].apply(lambda x: re.search(r'Question: (.+?)\n', x).group(1)).tolist()
        self.questions = self.data['Input'].tolist()
        self.labels = self.data['Label'].tolist()

    def __len__(self):
        # Return the total number of samples
        return len(self.questions)

    def __getitem__(self, idx):
        # Return a single sample (question, label) given an index
        question = self.questions[idx]
        label = self.labels[idx]
        return question, label

input_file = '/content/drive/MyDrive/single_task.csv'

# Initialize dataset
dataset = TextQuestionLabelDataset(input_file)

# Split the dataset for train, eval, and test (e.g., 10% for each)
dataset_length = len(dataset)
#train_size = int(0.1 * dataset_length)
train_size = 0
#eval_size = int(0.1 * dataset_length)
eval_size = 0
test_size = dataset_length - train_size - eval_size
#seed everything
seed = 42
torch.manual_seed(seed)
random.seed(seed)
np.random.seed(seed)

# train_dataset, eval_dataset, test_dataset = torch.utils.data.random_split(
#     dataset, [train_size, eval_size, test_size]
# )

train_dataset = torch.utils.data.Subset(dataset, range(0, train_size))
eval_dataset = torch.utils.data.Subset(dataset, range(train_size, train_size + eval_size))
test_dataset = torch.utils.data.Subset(dataset, range(train_size + eval_size, len(dataset)))
#print(train_dataset[0])
train_dataset = [format_data(sample) for sample in train_dataset]
eval_dataset = [format_data(sample) for sample in eval_dataset]
test_dataset = [format_data(sample) for sample in test_dataset]

# Create DataLoaders for batching
# train_loader = DataLoader(train_dataset, batch_size=2, shuffle=True)
# eval_loader = DataLoader(eval_dataset, batch_size=2, shuffle=False)
# test_loader = DataLoader(test_dataset, batch_size=2, shuffle=False)
# test_dataset[0]
# test_dataset[0]
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import gc
import time

def clear_memory():
    # Delete variables if they exist in the current global scope
    if 'inputs' in globals(): del globals()['inputs']
    if 'model' in globals(): del globals()['model']
    if 'processor' in globals(): del globals()['processor']
    if 'trainer' in globals(): del globals()['trainer']
    if 'peft_model' in globals(): del globals()['peft_model']
    if 'bnb_config' in globals(): del globals()['bnb_config']
    time.sleep(2)

    # Garbage collection and clearing CUDA memory
    gc.collect()
    time.sleep(2)
    torch.cuda.empty_cache()
    torch.cuda.synchronize()
    time.sleep(2)
    gc.collect()
    time.sleep(2)

    print(f"GPU allocated memory: {torch.cuda.memory_allocated() / 1024**3:.2f} GB")
    print(f"GPU reserved memory: {torch.cuda.memory_reserved() / 1024**3:.2f} GB")



def generate_text_from_sample(model, processor, sample, max_new_tokens=1024, device="cuda"):
    # Prepare the text input by applying the chat template
    text_input = processor.apply_chat_template(
        sample[:1],  # Use the sample without the system message
        tokenize=False,
        add_generation_prompt=True
    )
    #print("Text Input:", text_input)


    # Process the visual input from the sample
    # image_inputs, _ = process_vision_info(sample)
    #image_inputs = sample[1]['content'][0]['image'].convert("RGB")
    image_data = sample[1]['content'][0].get('image')

    if image_data is not None:
        image_inputs = image_data.convert("RGB")
    else:
        # 提供一个默认值或适当的处理逻辑
        image_inputs = None
        #print("Warning: The 'image' field is None.")
    # Prepare the inputs for the model
    model_inputs = processor(
        text=[text_input],
        images=image_inputs,
        return_tensors="pt",
    ).to(device)  # Move inputs to the specified device

    # Generate text with the model
    generated_ids = model.generate(**model_inputs, max_new_tokens=max_new_tokens)

    # Trim the generated ids to remove the input ids
    trimmed_generated_ids = [
        out_ids[len(in_ids):] for in_ids, out_ids in zip(model_inputs.input_ids, generated_ids)
    ]

    # Decode the output text
    output_text = processor.batch_decode(
        trimmed_generated_ids,
        skip_special_tokens=True,
        clean_up_tokenization_spaces=False
    )

    return output_text[0]  # Return the first decoded output text

# %%
clear_memory()
# Out:
# GPU allocated memory: 0.01 GB
# GPU reserved memory: 0.02 GB

# %%
import evaluate
import torch
from nltk.translate.meteor_score import meteor_score, single_meteor_score
from nltk.translate.bleu_score import sentence_bleu, corpus_bleu
import requests
from torch import nn
from transformers import MllamaForConditionalGeneration, AutoProcessor, MllamaConfig, AutoModelForCausalLM
from typing import List, Optional, Tuple, Union
from PIL import Image
import matplotlib.pyplot as plt
from qwen_vl_utils import process_vision_info
from transformers import BitsAndBytesConfig



quantization_config = BitsAndBytesConfig(
    load_in_4bit=True,
    # low_cpu_mem_usage=True,
    # bnb_4bit_compute_dtype=torch.float16
)

model_id = "meta-llama/Llama-3.2-11B-Vision-Instruct"
processor = AutoProcessor.from_pretrained("meta-llama/Llama-3.2-11B-Vision-Instruct")
model = MllamaForConditionalGeneration.from_pretrained(
            model_id, torch_dtype=torch.bfloat16, device_map="auto", low_cpu_mem_usage=True,
            quantization_config=quantization_config,
        )
# Out:
# WARNING:accelerate.utils.modeling:The model weights are not tied. Please use the `tie_weights` method before using the `infer_auto_device` function.
# Loading checkpoint shards:   0%|          | 0/5 [00:00<?, ?it/s]

# %%
import os
import re
import torch
import random
import numpy as np
from torch.utils.data import Dataset, DataLoader
import pandas as pd
from google.colab import drive


def generate_text_from_sample(model, processor, sample, max_new_tokens=1024, device="cuda"):
    # Prepare the text input by applying the chat template
    text_input = processor.apply_chat_template(
        sample[:1],  # Use the sample without the system message
        tokenize=False,
        add_generation_prompt=True
    )
    #print("Text Input:", text_input)


    # Process the visual input from the sample
    # image_inputs, _ = process_vision_info(sample)
    #image_inputs = sample[1]['content'][0]['image'].convert("RGB")
    image_data = sample[1]['content'][0].get('image')

    if image_data is not None:
        image_inputs = image_data.convert("RGB")
    else:
        # 提供一个默认值或适当的处理逻辑
        image_inputs = None
        #print("Warning: The 'image' field is None.")
    # Prepare the inputs for the model
    model_inputs = processor(
        text=[text_input],
        images=image_inputs,
        return_tensors="pt",
    ).to(device)  # Move inputs to the specified device

    # Generate text with the model
    generated_ids = model.generate(**model_inputs, max_new_tokens=max_new_tokens)

    # Trim the generated ids to remove the input ids
    trimmed_generated_ids = [
        out_ids[len(in_ids):] for in_ids, out_ids in zip(model_inputs.input_ids, generated_ids)
    ]

    # Decode the output text
    output_text = processor.batch_decode(
        trimmed_generated_ids,
        skip_special_tokens=True,
        clean_up_tokenization_spaces=False
    )

    return output_text[0]

# Mount Google Drive to access the file
drive.mount('/content/drive')

class TextQuestionLabelDataset(Dataset):
    def __init__(self, input_file):
        # Load data from a CSV file
        self.data = pd.read_csv(input_file)
        # print(self.data.head())  # 显示前 5 行数据


        # Extract questions and labels from the Input column
        #self.questions = self.data['Input'].apply(lambda x: re.search(r'Question: (.+?)\n', x).group(1)).tolist()
        self.questions = self.data['Input'].tolist()
        self.labels = self.data['Label'].tolist()

    def __len__(self):
        # Return the total number of samples
        return len(self.questions)

    def __getitem__(self, idx):
        # Return a single sample (question, label) given an index
        question = self.questions[idx]
        label = self.labels[idx]
        return question, label

input_file = '/content/drive/MyDrive/sample.csv'

# Initialize dataset
dataset = TextQuestionLabelDataset(input_file)

# Split the dataset for train, eval, and test (e.g., 10% for each)
dataset_length = len(dataset)
#train_size = int(0.1 * dataset_length)
train_size = 0
#eval_size = int(0.1 * dataset_length)
eval_size = 0
test_size = dataset_length - train_size - eval_size

#seed everything
seed = 42
torch.manual_seed(seed)
random.seed(seed)
np.random.seed(seed)

# train_dataset, eval_dataset, test_dataset = torch.utils.data.random_split(
#     dataset, [train_size, eval_size, test_size]
# )

train_dataset = torch.utils.data.Subset(dataset, range(0, train_size))
eval_dataset = torch.utils.data.Subset(dataset, range(train_size, train_size + eval_size))
test_dataset = torch.utils.data.Subset(dataset, range(train_size + eval_size, len(dataset)))

def generate_SM(que):
    sm = (
        "Select a model to answer the following question:\n"
        f"{que}\n"
        "Select a model only from the following model list: Segment-Video, Segment-MRI, "
        "Detect-Video, Overlaying, Surgical-VQA to answer the question.\n"
        "Generate a shortest prompt for the chosen model. "
        "Your response should be like Model: ? Prompt: ? and no other words."
    )
    return sm


# system_message = """ Select a model to answer the following question: What is the position of the instrument?
# Select model only from the following model list: Segment-Video, Segment-MRI, Detect-Video, Overlaying, Surgical-VQA to answer the question?
# Generate a shortest prompt for the chosen model. Your response should be like Model: ? Prompt: ? and no other words
# """


# system_message = """ You are an LLM agent which can call functions and corresponding prompt based on surgeons' query.
# The agent will be used in endonasal pituitary surgery to call visual models Segment-Video, Segment-MRI, Detect-Video, Overlaying, Surgical-VQA.
# There are 59 classes overall, including 4 phases, 15 steps, 18 instruments, 3 variations of instruments present in a frame, 5 positions of the instruments, and 14 operation notes in the annotation classes.
# The agent may call more than one model sequentially or in parallel based on query.
# Your task is to analyze the user's query, determine the intent, and return the name of the AI model to be invoked along with the corresponding prompt.
# If you receive the input like: "Question: Segment tumor from MRI and overlay on video?" The format of the answer should be like this: Model: Segmen-MRI|Overlaying
# Prompt: Segment tumor from MRI?|Overlay on video?" This is the format for the answers may need more than one model. The model options are Model Options: [Segment-Video, Segment-MRI, Detect-Video, Overlaying, Surgical-VQA].
# If you receive the input like: "Question: Segment Sella from Video?" The format of the answer should be like this: Model: Segment-Video
# Prompt: Segment Sella from video?" This is the format for the answers need only one model. The model options are Model Options:[Segment-Video, Segment-MRI, Detect-Video, Overlaying, Surgical-VQA].
# """
# system_message = """
# Your task is to analyze the user's query, determine the intent, and return the name of the AI model to be invoked along with the corresponding prompt.
# If you receive the input like: "Question: Segment tumor from MRI and overlay on video?" The format of the answer should be like this: Model: Segmen-MRI|Overlaying
# Prompt: Segment tumor from MRI?|Overlay on video?" This is the format for the answers may need more than one model. The model options are Model Options: [Segment-Video, Segment-MRI, Detect-Video, Overlaying, Surgical-VQA].
# If you receive the input like: "Question: Segment Sella from Video?" The format of the answer should be like this: Model: Segment-Video
# Prompt: Segment Sella from video?" This is the format for the answers need only one model. The model options are Model Options:[Segment-Video, Segment-MRI, Detect-Video, Overlaying, Surgical-VQA].
# """

# system_message="""
# Select models only from the following list:
# ['Segment-Video', 'Segment-MRI', 'Detect-Video', 'Overlaying', 'Surgical-VQA'].
# For each input question, determine the required models and generate corresponding prompts.

# Output Format:
# - For a single model:
#   Model: <ModelName>
#   Prompt: <CorrespondingPrompt>?

# - For multiple models:
#   Model: <Model1>|<Model2>
#   Prompt: <Prompt1>?|<Prompt2>?
# """

def format_data_test1(sample):
    return [
        {
            "role": "system",
            "content": [
                {
                    "type": "text",
                    "text": system_message
                }
            ],
        },
        # {
        #     "role": "user",
        #     "content": [

        #         {
        #             "type": "text",
        #             "text": sample[0],

        #         }
        #     ],
        # },
        {
            "role": "assistant",
            "content": [
                {
                    "type": "text",
                    "text": sample[1]
                }
            ],
        },
    ]

system_message = generate_SM(test_dataset[0][0])
print(test_dataset[0][0])
input1 = format_data_test1(test_dataset[0])
input2 = format_data_test1(test_dataset[2])
print(input1)
#print(input2)
# print("input: ", input)
# text_input = processor.apply_chat_template(
#         input[:2],  # Use the sample without the system message
#         tokenize=False,
#         add_generation_prompt=True
#     )
# print("text_input: ", text_input)
# input[:2]
output1 = generate_text_from_sample(model, processor, input1)
ans1 = input1[1]['content'][0]['text']
print("output1: ",output1)
print("answer1: ",ans1)
# print("--------------------------------------------")
# output2 = generate_text_from_sample(model, processor, input1)
# ans2 = input2[2]['content'][0]['text']
# print("output2: ",output2)
# print("answer2: ",ans2)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Question: Detect surgical instruments in the video?
# [{'role': 'system', 'content': [{'type': 'text', 'text': 'Select a model to answer the following question:\nQuestion: Detect surgical instruments in the video?\nSelect a model only from the following model list: Segment-Video, Segment-MRI, Detect-Video, Overlaying, Surgical-VQA to answer the question.\nGenerate a shortest prompt for the chosen model. Your response should be like Model: ? Prompt: ? and no other words.'}]}, {'role': 'assistant', 'content': [{'type': 'text', 'text': 'Model: Detect-Video\nPrompt: Detect instruments in the video?'}]}]
# output1:  Model: Detect-Video
# Prompt: Detect surgical instruments in the video.
# answer1:  Model: Detect-Video
# Prompt: Detect instruments in the video?

# %%
all_pred = []
all_ans = []

# %%
model.eval()
with torch.no_grad():
    for sample in test_dataset:
        output = generate_text_from_sample(model, processor, sample)
        ans = sample[1]['content'][0]['text']
        all_pred.append(output)
        all_ans.append(ans)

# %%
import os
import torch
import pickle
from google.colab import drive

drive.mount('/content/drive')
start_index = 0
# 设置保存路径
save_path = '/content/drive/My Drive/Sharing/single.pkl'

# 尝试加载之前的进度
if os.path.exists(save_path):
    with open(save_path, 'rb') as f:
        saved_data = pickle.load(f)
        start_index = saved_data['start_index']
        all_pred = saved_data['all_pred']
        all_ans = saved_data['all_ans']
        print(f"Resuming from index {start_index}")
else:
    start_index = 0
    all_pred = []
    all_ans = []
    print("Starting fresh")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Starting fresh

# %%
model.eval()
with torch.no_grad():
    for i, sample in enumerate(test_dataset):
        # 跳过已处理的样本
        if i < start_index:
            continue

        output = generate_text_from_sample(model, processor, sample)
        ans = sample[1]['content'][0]['text']
        all_pred.append(output)
        all_ans.append(ans)

        # 更新进度
        start_index = i + 1
        saved_data = {
            'start_index': start_index,
            'all_pred': all_pred,
            'all_ans': all_ans
        }

        # 保存到Google Drive
        with open(save_path, 'wb') as f:
            pickle.dump(saved_data, f)

        print(f"Processed sample {i+1}/{len(test_dataset)}")

print("All samples processed!")
# Out:
# Processed sample 13/5000
# Processed sample 14/5000
# Processed sample 15/5000
# Processed sample 16/5000
# Processed sample 17/5000
# Processed sample 18/5000
# Processed sample 19/5000
# Processed sample 20/5000
# Processed sample 21/5000
# Processed sample 22/5000
# Processed sample 23/5000
# Processed sample 24/5000
# Processed sample 25/5000
# Processed sample 26/5000
# Processed sample 27/5000
# Processed sample 28/5000
# Processed sample 29/5000
# Processed sample 30/5000
# Processed sample 31/5000
# Processed sample 32/5000
# Processed sample 33/5000
# Processed sample 34/5000
# Processed sample 35/5000
# Processed sample 36/5000
# Processed sample 37/5000
# Processed sample 38/5000
# Processed sample 39/5000
# Processed sample 40/5000
# Processed sample 41/5000
# Processed sample 42/5000
# Processed sample 43/5000
# Processed sample 44/5000
# Processed sample 45/5000
# Processed sample 46/5000
# Processed sample 47/5000
# Processed sample 48/5000
# Processed sample 49/5000
# Processed sample 50/5000
# Processed sample 51/5000
# Processed sample 52/5000
# Processed sample 53/5000
# Processed sample 54/5000
# Processed sample 55/5000
# Processed sample 56/5000
# Processed sample 57/5000
# Processed sample 58/5000
# Processed sample 59/5000
# Processed sample 60/5000
# Processed sample 1784/5000
# Processed sample 1785/5000
# Processed sample 1786/5000
# Processed sample 1787/5000
# Processed sample 1788/5000
# Processed sample 1789/5000
# Processed sample 1790/5000
# Processed sample 1791/5000
# Processed sample 1792/5000
# Processed sample 1793/5000
# Processed sample 1794/5000
# Processed sample 1795/5000
# Processed sample 1796/5000
# Processed sample 1797/5000
# Processed sample 1798/5000
# Processed sample 1799/5000
# Processed sample 1800/5000
# Processed sample 1801/5000
# Processed sample 1802/5000
# Processed sample 1803/5000
# Processed sample 1804/5000
# Processed sample 1805/5000
# Processed sample 1806/5000
# Processed sample 1807/5000
# Processed sample 1808/5000
# Processed sample 1809/5000
# Processed sample 1810/5000
# Processed sample 1811/5000
# Processed sample 1812/5000
# Processed sample 1813/5000
# Processed sample 1814/5000
# Processed sample 1815/5000
# Processed sample 1816/5000
# Processed sample 1817/5000
# Processed sample 1818/5000
# Processed sample 1819/5000
# Processed sample 1820/5000
# Processed sample 1821/5000
# Processed sample 1822/5000
# Processed sample 1823/5000
# Processed sample 1824/5000
# Processed sample 1825/5000
# Processed sample 1826/5000
# Processed sample 1827/5000
# Processed sample 1828/5000
# Processed sample 1829/5000
# ...
# Processed sample 2684/5000
# Processed sample 2685/5000
# Processed sample 2686/5000
# Processed sample 2687/5000
# Processed sample 2688/5000
# Processed sample 2689/5000
# Processed sample 2690/5000
# Processed sample 2691/5000
# Processed sample 2692/5000
# Processed sample 2693/5000
# Processed sample 2694/5000
# Processed sample 2695/5000
# Processed sample 2696/5000
# Processed sample 2697/5000
# Processed sample 2698/5000
# Processed sample 2699/5000
# Processed sample 2700/5000
# Processed sample 2701/5000
# Processed sample 2702/5000
# Processed sample 2703/5000
# Processed sample 2704/5000
# Processed sample 2705/5000
# Processed sample 2706/5000
# Processed sample 2707/5000
# Processed sample 2708/5000
# Processed sample 2709/5000
# Processed sample 2710/5000
# Processed sample 2711/5000
# Processed sample 2712/5000
# Processed sample 2713/5000
# Processed sample 2714/5000
# Processed sample 2715/5000
# Processed sample 2716/5000
# Processed sample 2717/5000
# Processed sample 2718/5000
# Processed sample 2719/5000
# Processed sample 2720/5000
# Processed sample 2721/5000
# Processed sample 2722/5000
# Processed sample 2723/5000
# Processed sample 2724/5000
# Processed sample 2725/5000
# Processed sample 2726/5000
# Processed sample 2727/5000
# Processed sample 2728/5000
# Processed sample 2729/5000
# Processed sample 2730/5000
# Processed sample 2731/5000
# Processed sample 2732/5000
# Processed sample 2733/5000
# Processed sample 2734/5000
# Processed sample 2735/5000
# Processed sample 2736/5000
# Processed sample 2737/5000
# Processed sample 2738/5000
# Processed sample 2739/5000
# Processed sample 2740/5000
# Processed sample 2741/5000
# Processed sample 2742/5000
# Processed sample 2743/5000
# Processed sample 2744/5000
# Processed sample 2745/5000
# Processed sample 2746/5000
# Processed sample 2747/5000
# Processed sample 2748/5000
# Processed sample 2749/5000
# Processed sample 2750/5000
# Processed sample 2751/5000
# Processed sample 2752/5000
# Processed sample 2753/5000
# Processed sample 2754/5000
# Processed sample 2755/5000
# Processed sample 2756/5000
# Processed sample 2757/5000
# Processed sample 2758/5000
# Processed sample 2759/5000
# Processed sample 2760/5000
# Processed sample 2761/5000
# Processed sample 2762/5000
# Processed sample 2763/5000
# Processed sample 2764/5000
# Processed sample 2765/5000
# Processed sample 2766/5000
# Processed sample 2767/5000
# Processed sample 2768/5000
# Processed sample 2769/5000
# Processed sample 2770/5000
# Processed sample 2771/5000
# Processed sample 2772/5000
# Processed sample 2773/5000
# Processed sample 2774/5000
# Processed sample 2775/5000
# Processed sample 2776/5000
# Processed sample 2777/5000
# Processed sample 2778/5000
# Processed sample 2779/5000
# Processed sample 2780/5000
# Processed sample 2781/5000
# Processed sample 2782/5000
# Processed sample 2783/5000
# Processed sample 2784/5000
# Processed sample 2785/5000
# Processed sample 2786/5000
# Processed sample 2787/5000
# Processed sample 2788/5000
# Processed sample 2789/5000
# Processed sample 2790/5000
# Processed sample 2791/5000
# Processed sample 2792/5000
# Processed sample 2793/5000
# Processed sample 2794/5000
# Processed sample 2795/5000
# Processed sample 2796/5000
# Processed sample 2797/5000
# Processed sample 2798/5000
# Processed sample 2799/5000
# Processed sample 2800/5000
# Processed sample 2801/5000
# Processed sample 2802/5000
# Processed sample 2803/5000
# Processed sample 2804/5000
# Processed sample 2805/5000
# Processed sample 2806/5000
# Processed sample 2807/5000
# Processed sample 2808/5000
# Processed sample 2809/5000
# Processed sample 2810/5000
# Processed sample 2811/5000
# Processed sample 2812/5000
# Processed sample 2813/5000
# Processed sample 2814/5000
# Processed sample 2815/5000
# Processed sample 2816/5000
# Processed sample 2817/5000
# Processed sample 2818/5000
# Processed sample 2819/5000
# Processed sample 2820/5000
# Processed sample 2821/5000
# Processed sample 2822/5000
# Processed sample 2823/5000
# Processed sample 2824/5000
# Processed sample 2825/5000
# Processed sample 2826/5000
# Processed sample 2827/5000
# Processed sample 2828/5000
# Processed sample 2829/5000
# Processed sample 2830/5000
# Processed sample 2831/5000
# Processed sample 2832/5000
# Processed sample 2833/5000
# Processed sample 2834/5000
# Processed sample 2835/5000
# Processed sample 2836/5000
# Processed sample 2837/5000
# Processed sample 2838/5000
# Processed sample 2839/5000
# Processed sample 2840/5000
# Processed sample 2841/5000
# Processed sample 2842/5000
# Processed sample 2843/5000
# Processed sample 2844/5000
# Processed sample 2845/5000
# Processed sample 2846/5000
# Processed sample 2847/5000
# Processed sample 2848/5000
# Processed sample 2849/5000
# Processed sample 2850/5000
# Processed sample 2851/5000
# Processed sample 2852/5000
# Processed sample 2853/5000
# Processed sample 2854/5000
# Processed sample 2855/5000
# Processed sample 2856/5000
# Processed sample 2857/5000
# Processed sample 2858/5000
# Processed sample 2859/5000
# Processed sample 2860/5000
# Processed sample 2861/5000
# Processed sample 2862/5000
# Processed sample 2863/5000
# Processed sample 2864/5000
# Processed sample 2865/5000
# Processed sample 2866/5000
# Processed sample 2867/5000
# Processed sample 2868/5000
# Processed sample 2869/5000
# Processed sample 2870/5000
# Processed sample 2871/5000
# Processed sample 2872/5000
# Processed sample 2873/5000
# Processed sample 2874/5000
# Processed sample 2875/5000
# Processed sample 2876/5000
# Processed sample 2877/5000
# Processed sample 2878/5000
# Processed sample 2879/5000
# Processed sample 2880/5000
# Processed sample 2881/5000
# Processed sample 2882/5000
# Processed sample 2883/5000
# Processed sample 2884/5000
# Processed sample 2885/5000
# Processed sample 2886/5000
# Processed sample 2887/5000
# Processed sample 2888/5000
# Processed sample 2889/5000
# Processed sample 2890/5000
# Processed sample 2891/5000
# Processed sample 2892/5000
# Processed sample 2893/5000
# Processed sample 2894/5000
# Processed sample 2895/5000
# Processed sample 2896/5000
# Processed sample 2897/5000
# Processed sample 2898/5000
# Processed sample 2899/5000
# Processed sample 2900/5000
# Processed sample 2901/5000
# Processed sample 2902/5000
# Processed sample 2903/5000
# Processed sample 2904/5000
# Processed sample 2905/5000
# Processed sample 2906/5000
# Processed sample 2907/5000
# Processed sample 2908/5000
# Processed sample 2909/5000
# Processed sample 2910/5000
# Processed sample 2911/5000
# Processed sample 2912/5000
# Processed sample 2913/5000
# Processed sample 2914/5000
# Processed sample 2915/5000
# Processed sample 2916/5000
# Processed sample 2917/5000
# Processed sample 2918/5000
# Processed sample 2919/5000
# Processed sample 2920/5000
# Processed sample 2921/5000
# Processed sample 2922/5000
# Processed sample 2923/5000
# Processed sample 2924/5000
# Processed sample 2925/5000
# Processed sample 2926/5000
# Processed sample 2927/5000
# Processed sample 2928/5000
# Processed sample 2929/5000
# Processed sample 2930/5000
# Processed sample 2931/5000
# Processed sample 2932/5000
# Processed sample 2933/5000
# Processed sample 2934/5000
# Processed sample 2935/5000
# Processed sample 2936/5000
# Processed sample 2937/5000
# Processed sample 2938/5000
# Processed sample 2939/5000
# Processed sample 2940/5000
# Processed sample 2941/5000
# Processed sample 2942/5000
# Processed sample 2943/5000
# Processed sample 2944/5000
# Processed sample 2945/5000
# Processed sample 2946/5000
# Processed sample 2947/5000
# Processed sample 2948/5000
# Processed sample 2949/5000
# Processed sample 2950/5000
# Processed sample 2951/5000
# Processed sample 2952/5000
# Processed sample 2953/5000
# Processed sample 2954/5000
# Processed sample 2955/5000
# Processed sample 2956/5000
# Processed sample 2957/5000
# Processed sample 2958/5000
# Processed sample 2959/5000
# Processed sample 2960/5000
# Processed sample 2961/5000
# Processed sample 2962/5000
# Processed sample 2963/5000
# Processed sample 2964/5000
# Processed sample 2965/5000
# Processed sample 2966/5000
# Processed sample 2967/5000
# Processed sample 2968/5000
# Processed sample 2969/5000
# Processed sample 2970/5000
# Processed sample 2971/5000
# Processed sample 2972/5000
# Processed sample 2973/5000
# Processed sample 2974/5000
# Processed sample 2975/5000
# Processed sample 2976/5000
# Processed sample 2977/5000
# Processed sample 2978/5000
# Processed sample 2979/5000
# Processed sample 2980/5000
# Processed sample 2981/5000
# Processed sample 2982/5000
# Processed sample 2983/5000
# Processed sample 2984/5000
# Processed sample 2985/5000
# Processed sample 2986/5000
# Processed sample 2987/5000
# Processed sample 2988/5000
# Processed sample 2989/5000
# Processed sample 2990/5000
# Processed sample 2991/5000
# Processed sample 2992/5000
# Processed sample 2993/5000
# Processed sample 2994/5000
# Processed sample 2995/5000
# Processed sample 2996/5000
# Processed sample 2997/5000
# Processed sample 2998/5000
# Processed sample 2999/5000
# Processed sample 3000/5000
# Processed sample 3001/5000
# Processed sample 3002/5000
# Processed sample 3003/5000
# Processed sample 3004/5000
# Processed sample 3005/5000
# Processed sample 3006/5000
# Processed sample 3007/5000
# Processed sample 3008/5000
# Processed sample 3009/5000
# Processed sample 3010/5000
# Processed sample 3011/5000
# Processed sample 3012/5000
# Processed sample 3013/5000
# Processed sample 3014/5000
# Processed sample 3015/5000
# Processed sample 3016/5000
# Processed sample 3017/5000
# Processed sample 3018/5000
# Processed sample 3019/5000
# Processed sample 3020/5000
# Processed sample 3021/5000
# Processed sample 3022/5000
# Processed sample 3023/5000
# Processed sample 3024/5000
# Processed sample 3025/5000
# Processed sample 3026/5000
# Processed sample 3027/5000
# Processed sample 3028/5000
# Processed sample 3029/5000
# Processed sample 3030/5000
# Processed sample 3031/5000
# Processed sample 3032/5000
# Processed sample 3033/5000
# Processed sample 3034/5000
# Processed sample 3035/5000
# Processed sample 3036/5000
# Processed sample 3037/5000
# Processed sample 3038/5000
# Processed sample 3039/5000
# Processed sample 3040/5000
# Processed sample 3041/5000
# Processed sample 3042/5000
# Processed sample 3043/5000
# Processed sample 3044/5000
# Processed sample 3045/5000
# Processed sample 3046/5000
# Processed sample 3047/5000
# Processed sample 3048/5000
# Processed sample 3049/5000
# Processed sample 3050/5000
# Processed sample 3051/5000
# Processed sample 3052/5000
# Processed sample 3053/5000
# Processed sample 3054/5000
# Processed sample 3055/5000
# Processed sample 3056/5000
# Processed sample 3057/5000
# Processed sample 3058/5000
# Processed sample 3059/5000
# Processed sample 3060/5000
# Processed sample 3061/5000
# Processed sample 3062/5000
# Processed sample 3063/5000
# Processed sample 3064/5000
# Processed sample 3065/5000
# Processed sample 3066/5000
# Processed sample 3067/5000
# Processed sample 3068/5000
# Processed sample 3069/5000
# Processed sample 3070/5000
# Processed sample 3071/5000
# Processed sample 3072/5000
# Processed sample 3073/5000
# Processed sample 3074/5000
# Processed sample 3075/5000
# Processed sample 3076/5000
# Processed sample 3077/5000
# Processed sample 3078/5000
# Processed sample 3079/5000
# Processed sample 3080/5000
# Processed sample 3081/5000
# Processed sample 3082/5000
# Processed sample 3083/5000
# Processed sample 3084/5000
# Processed sample 3085/5000
# Processed sample 3086/5000
# Processed sample 3087/5000
# Processed sample 3088/5000
# Processed sample 3089/5000
# Processed sample 3090/5000
# Processed sample 3091/5000
# Processed sample 3092/5000
# Processed sample 3093/5000
# Processed sample 3094/5000
# Processed sample 3095/5000
# Processed sample 3096/5000
# Processed sample 3097/5000
# Processed sample 3098/5000
# Processed sample 3099/5000
# Processed sample 3100/5000
# Processed sample 3101/5000
# Processed sample 3102/5000
# Processed sample 3103/5000
# Processed sample 3104/5000
# Processed sample 3105/5000
# Processed sample 3106/5000
# Processed sample 3107/5000
# Processed sample 3108/5000
# Processed sample 3109/5000
# Processed sample 3110/5000
# Processed sample 3111/5000
# Processed sample 3112/5000
# Processed sample 3113/5000
# Processed sample 3114/5000
# Processed sample 3115/5000
# Processed sample 3116/5000
# Processed sample 3117/5000
# Processed sample 3118/5000
# Processed sample 3119/5000
# Processed sample 3120/5000
# Processed sample 3121/5000
# Processed sample 3122/5000
# Processed sample 3123/5000
# Processed sample 3124/5000
# Processed sample 3125/5000
# Processed sample 3126/5000
# Processed sample 3127/5000
# Processed sample 3128/5000
# Processed sample 3129/5000
# Processed sample 3130/5000
# Processed sample 3131/5000
# Processed sample 3132/5000
# Processed sample 3133/5000
# Processed sample 3134/5000
# Processed sample 3135/5000
# Processed sample 3136/5000
# Processed sample 3137/5000
# Processed sample 3138/5000
# Processed sample 3139/5000
# Processed sample 3140/5000
# Processed sample 3141/5000
# Processed sample 3142/5000
# Processed sample 3143/5000
# Processed sample 3144/5000
# Processed sample 3145/5000
# Processed sample 3146/5000
# Processed sample 3147/5000
# Processed sample 3148/5000
# Processed sample 3149/5000
# Processed sample 3150/5000
# Processed sample 3151/5000
# Processed sample 3152/5000
# Processed sample 3153/5000
# Processed sample 3154/5000
# Processed sample 3155/5000
# Processed sample 3156/5000
# Processed sample 3157/5000
# Processed sample 3158/5000
# Processed sample 3159/5000
# Processed sample 3160/5000
# Processed sample 3161/5000
# Processed sample 3162/5000
# Processed sample 3163/5000
# Processed sample 3164/5000
# Processed sample 3165/5000
# Processed sample 3166/5000
# Processed sample 3167/5000
# Processed sample 3168/5000
# Processed sample 3169/5000
# Processed sample 3170/5000
# Processed sample 3171/5000
# Processed sample 3172/5000
# Processed sample 3173/5000
# Processed sample 3174/5000
# Processed sample 3175/5000
# Processed sample 3176/5000
# Processed sample 3177/5000
# Processed sample 3178/5000
# Processed sample 3179/5000
# Processed sample 3180/5000
# Processed sample 3181/5000
# Processed sample 3182/5000
# Processed sample 3183/5000
# Processed sample 3184/5000
# Processed sample 3185/5000
# Processed sample 3186/5000
# Processed sample 3187/5000
# Processed sample 3188/5000
# Processed sample 3189/5000
# Processed sample 3190/5000
# Processed sample 3191/5000
# Processed sample 3192/5000
# Processed sample 3193/5000
# Processed sample 3194/5000
# Processed sample 3195/5000
# Processed sample 3196/5000
# Processed sample 3197/5000
# Processed sample 3198/5000
# Processed sample 3199/5000
# Processed sample 3200/5000
# Processed sample 3201/5000
# Processed sample 3202/5000
# Processed sample 3203/5000
# Processed sample 3204/5000
# Processed sample 3205/5000
# Processed sample 3206/5000
# Processed sample 3207/5000
# Processed sample 3208/5000
# Processed sample 3209/5000
# Processed sample 3210/5000
# Processed sample 3211/5000
# Processed sample 3212/5000
# Processed sample 3213/5000
# Processed sample 3214/5000
# Processed sample 3215/5000
# Processed sample 3216/5000
# Processed sample 3217/5000
# Processed sample 3218/5000
# Processed sample 3219/5000
# Processed sample 3220/5000
# Processed sample 3221/5000
# Processed sample 3222/5000
# Processed sample 3223/5000
# Processed sample 3224/5000
# Processed sample 3225/5000
# Processed sample 3226/5000
# Processed sample 3227/5000
# Processed sample 3228/5000
# Processed sample 3229/5000
# Processed sample 3230/5000
# Processed sample 3231/5000
# Processed sample 3232/5000
# Processed sample 3233/5000
# Processed sample 3234/5000
# Processed sample 3235/5000
# Processed sample 3236/5000
# Processed sample 3237/5000
# Processed sample 3238/5000
# Processed sample 3239/5000
# Processed sample 3240/5000
# Processed sample 3241/5000
# Processed sample 3242/5000
# Processed sample 3243/5000
# Processed sample 3244/5000
# Processed sample 3245/5000
# Processed sample 3246/5000
# Processed sample 3247/5000
# Processed sample 3248/5000
# Processed sample 3249/5000
# Processed sample 3250/5000
# Processed sample 3251/5000
# Processed sample 3252/5000
# Processed sample 3253/5000
# Processed sample 3254/5000
# Processed sample 3255/5000
# Processed sample 3256/5000
# Processed sample 3257/5000
# Processed sample 3258/5000
# Processed sample 3259/5000
# Processed sample 3260/5000
# Processed sample 3261/5000
# Processed sample 3262/5000
# Processed sample 3263/5000
# Processed sample 3264/5000
# Processed sample 3265/5000
# Processed sample 3266/5000
# Processed sample 3267/5000
# Processed sample 3268/5000
# Processed sample 3269/5000
# Processed sample 3270/5000
# Processed sample 3271/5000
# Processed sample 3272/5000
# Processed sample 3273/5000
# Processed sample 3274/5000
# Processed sample 3275/5000

# %%
for i in range(len(all_pred)):
    print("pred:", all_pred[i])
    print("ans:", all_ans[i])
# Out:
# pred: Model: Segment-Video
# Prompt: Analyze and segment the Right Optic Protuberance from a given video.
# ans: Model: Segment-Video
# Prompt: Analyze right optic protuberance?
# pred: Model: Detect-Video
# Prompt: Detect micro doppler in the video and provide its coordinates.
# ans: Model: Detect-Video
# Prompt: Locate micro doppler in the video and provide its coordinates.?
# pred: Model: Segment-MRI
# Prompt: Display an overlay of MRI-based anatomy segmentation on the surgical field.
# ans: Model: Overlaying
# Prompt: Overlay anatomy segmentation with surgical scene.
# pred: Model: Segment-MRI
# Prompt: Segment the tumor margins from the given MRI data.
# ans: Model: Segment-MRI
# Prompt: Segment tumor margins from MRI.
# pred: Model: Segment-MRI
# Prompt: Segment the anatomy and tumor from an MRI image.
# ans: Model: Segment-MRI
# Prompt: Segment left carotid from MRI.
# pred: Model: Segment-Video
# Prompt: Analyze and segment Sella from a given video.
# ans: Model: Segment-Video
# Prompt: Segment sella accurately?
# pred: Model: Segment-Video
# Prompt: Identify the nasal cutting forceps in the video and mark their exact locations.
# ans: Model: Detect-Video
# Prompt: Mark the exact locations of nasal cutting forceps in the video.?
# pred: Model: Segment-Video
# Prompt: What are the key characteristics of instrument quantities in medical imaging and how do they impact the accuracy of diagnostic results?
# ans: Model: Surgical-VQA
# Prompt: what observation can be made about the instrument quantities?
# pred: Model: Segment-MRI
# Prompt: Explain the role of instrument positions in medical imaging procedures.
# ans: Model: Surgical-VQA
# Prompt: explain the role of the instrument positions in this step.
# pred: Model: Segment-Video
# Prompt: Segment the Left Optic Protuberance from the given video frames.
# ans: Model: Segment-Video
# Prompt: Find left optic protuberance?
# pred: Model: Segment-Video
# Prompt: What are the characteristics of the instruments?
# ans: Model: Surgical-VQA
# Prompt: what observation can be made about the instruments?
# pred: Model: Overlaying
# Prompt: Project preoperative imaging onto the live surgical feed.
# ans: Model: Overlaying
# Prompt: Overlay preoperative imaging with surgical scene.

# %%
import os
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')

# File Path
output_file_path = '/content/drive/My Drive/pre_ans.txt'

# Write data
with open(output_file_path, 'w') as file:
    for i in range(len(all_pred)):
        file.write(f"pred: {all_pred[i]}\n")
        file.write(f"ans: {all_ans[i]}\n")
        file.write("\n")  # 添加换行以便于阅读

print(f"file saved at: {output_file_path}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# file saved at: /content/drive/My Drive/pre_ans.txt

# %%
# 定义新的变量来存储提取的 Prompt 部分
all_pred_prompts = []
all_ans_prompts = []

# 提取 Prompt 部分的函数
def extract_prompt(entry):
    for line in entry.split('\n'):
        if line.startswith("Prompt:"):
            return line[len("Prompt: "):]  # 去掉 "Prompt: " 保留内容

# 提取 all_pred 和 all_ans 中的 Prompt 部分
all_pred_prompts = [extract_prompt(item) for item in all_pred]
all_ans_prompts = [extract_prompt(item) for item in all_ans]

# 打印结果验证
print("Extracted Prompts from all_pred:", all_pred_prompts)
print("Extracted Prompts from all_ans:", all_ans_prompts)
# Out:
# Extracted Prompts from all_pred: ['Analyze and segment the Right Optic Protuberance from a given video.', 'Detect micro doppler in the video and provide its coordinates.', 'Display an overlay of MRI-based anatomy segmentation on the surgical field.', 'Segment the tumor margins from the given MRI data.', 'Segment the anatomy and tumor from an MRI image.', 'Analyze and segment Sella from Video', 'Identify the nasal cutting forceps in the video and mark their exact locations.', 'What observation can be made about the instrument quantities?', 'Explain the role of instrument positions in the MRI segmentation process.', 'Segment the left optic protuberance from the video.']
# Extracted Prompts from all_ans: ['Analyze right optic protuberance?', 'Locate micro doppler in the video and provide its coordinates.?', 'Overlay anatomy segmentation with surgical scene.', 'Segment tumor margins from MRI.', 'Segment left carotid from MRI.', 'Segment sella accurately?', 'Mark the exact locations of nasal cutting forceps in the video.?', 'what observation can be made about the instrument quantities?', 'explain the role of the instrument positions in this step.', 'Find left optic protuberance?']

# %%
# !pip install rouge_score
rouge = evaluate.load("rouge")
rouge_results = rouge.compute(predictions= all_pred_prompts, references=all_ans_prompts)
print(rouge_results)
# Out:
# Collecting rouge_score
#   Downloading rouge_score-0.1.2.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from rouge_score) (1.4.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from rouge_score) (3.9.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from rouge_score) (1.26.4)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from rouge_score) (1.17.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->rouge_score) (8.1.8)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->rouge_score) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk->rouge_score) (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk->rouge_score) (4.67.1)
# Building wheels for collected packages: rouge_score
#   Building wheel for rouge_score (setup.py) ... done
#   Created wheel for rouge_score: filename=rouge_score-0.1.2-py3-none-any.whl size=24935 sha256=927e6fa66001e8d9f68f51cb60b5d521481b8d26e783a247ca8267821a0e6929
#   Stored in directory: /root/.cache/pip/wheels/5f/dd/89/461065a73be61a532ff8599a28e9beef17985c9e9c31e541b4
# Successfully built rouge_score
# Installing collected packages: rouge_score
# Successfully installed rouge_score-0.1.2
# Downloading builder script:   0%|          | 0.00/6.27k [00:00<?, ?B/s]
# {'rouge1': 0.6542063492063492, 'rouge2': 0.44156012846802317, 'rougeL': 0.6162698412698413, 'rougeLsum': 0.6187301587301588}

# %%
bleu_score = corpus_bleu(all_ans_prompts, all_pred_prompts, weights=(1.0, 0.0, 0.0, 0.0))
print(bleu_score)
# Out:
# 0.2835820895522388
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)

# %%
import nltk
nltk.download('wordnet')
from nltk.tokenize import word_tokenize
nltk.download('punkt_tab')
import warnings
warnings.filterwarnings("ignore", category=UserWarning)

m_score=0
for line in zip(all_ans_prompts, all_pred_prompts):
    ref = word_tokenize(line[0])
    hypo = word_tokenize(line[1])
    m_score += meteor_score([ref], hypo)
meteors = m_score/len(all_ans)
print(meteors)
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# 0.6671602507098766

# %%
import re

# Function to extract the "Model" part from a given text
def extract_model(text):
    match = re.search(r"Model:\s*(.*?)\n", text)
    return match.group(1) if match else ""

# Function to calculate exact match accuracy
def calculate_exact_match_accuracy(predictions, answers):
    # Extract and strip spaces from the models
    pred_models = [extract_model(pred).strip() for pred in predictions]
    true_models = [extract_model(ans).strip() for ans in answers]

    # Debug prints for checking values
    print(pred_models)
    print(true_models)

    correct_matches = sum(p == t for p, t in zip(pred_models, true_models))
    total = len(true_models)
    return correct_matches / total if total > 0 else 0

# Calculate exact match accuracy
accuracy = calculate_exact_match_accuracy(all_pred, all_ans)
print(f"Exact Match Accuracy: {accuracy * 100:.2f}%")
# Out:
# ['Segment-Video', 'Detect-Video', 'Segment-MRI', 'Segment-MRI', 'Segment-MRI', 'Segment-Video', 'Segment-Video', 'Segment-Video', 'Segment-MRI', 'Segment-Video']
# ['Segment-Video', 'Detect-Video', 'Overlaying', 'Segment-MRI', 'Segment-MRI', 'Segment-Video', 'Detect-Video', 'Surgical-VQA', 'Surgical-VQA', 'Segment-Video']
# Exact Match Accuracy: 60.00%
