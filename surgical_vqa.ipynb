# %% [markdown]
# <a href="https://colab.research.google.com/github/PeterHJY628/MyOwnExample/blob/main/surgical_vqa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip -q install "torch==2.4.0" tensorboard pillow torchvision accelerate huggingface_hub
# !pip -q install  --upgrade \
  "transformers==4.45.1" \
  "datasets==3.0.1" \
  "accelerate==0.34.2" \
  "evaluate==0.4.3" \
  "bitsandbytes==0.44.0" \
  "trl==0.11.1" \
  "peft==0.13.0" \
  "qwen_vl_utils"
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 797.3/797.3 MB 2.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.2/176.2 MB 5.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.4/209.4 MB 4.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 72.5 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchaudio 2.5.1+cu121 requires torch==2.5.1, but you have torch 2.4.0 which is incompatible.
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 2.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 89.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 471.6/471.6 kB 38.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 324.4/324.4 kB 31.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.0/84.0 kB 8.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 122.4/122.4 MB 7.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 318.4/318.4 kB 24.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.5/322.5 kB 29.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 11.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.6/177.6 kB 18.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 98.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.5/115.5 kB 10.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.8/33.8 MB 56.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 15.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 19.4 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.6.1 which is incompatible.
# torchaudio 2.5.1+cu121 requires torch==2.5.1, but you have torch 2.4.0 which is incompatible.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.environ['HF_HOME'] = '/home/sa5u24/VQA'
hf_home = os.path.expanduser(
    os.getenv("HF_HOME", os.path.join(os.getenv("XDG_CACHE_HOME", "~/.cache"), "huggingface"))
)
print(hf_home)

from huggingface_hub import login

# Replace 'your-hf-token-here' with your actual Hugging Face token
login(token="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")
# Out:
# /home/sa5u24/VQA

# %%
def generate_SM(que):
    sm = (
        "Select a model to answer the following question:\n"
        f"{que}\n"
        "Select a model only from the following model list: Segment-Video, Segment-MRI, "
        "Detect-Video, Overlaying, Surgical-VQA to answer the question.\n"
        "Generate a shortest prompt for the chosen model. "
        "Your response should be like Model: ? Prompt: ? and no other words."
    )
    return sm

def format_data(sample):
    system_message = generate_SM(sample[0])
    return [
        {
            "role": "system",
            "content": [
                {
                    "type": "text",
                    "text": system_message
                }
            ],
        },
        # {
        #     "role": "user",
        #     "content": [

        #         {
        #             "type": "text",
        #             "text": sample[0],

        #         }
        #     ],
        # },
        {
            "role": "assistant",
            "content": [
                {
                    "type": "text",
                    "text": sample[1]
                }
            ],
        },
    ]

#system_message = generate_SM(test_dataset[0][0])

# %%
from datasets import load_dataset

dataset_id = "HuggingFaceM4/ChartQA"
train_dataset, eval_dataset, test_dataset = load_dataset(dataset_id, split=['train[:10%]', 'val[:10%]', 'test[:10%]'])

train_dataset = [format_data(sample) for sample in train_dataset]
eval_dataset = [format_data(sample) for sample in eval_dataset]
test_dataset = [format_data(sample) for sample in test_dataset]

train_dataset[200], len(train_dataset), len(eval_dataset), len(test_dataset)
# Out:
# ([{'role': 'system',
#    'content': [{'type': 'text',
#      'text': 'You are a Vision Language Model specialized in interpreting visual data from chart images.\nYour task is to analyze the provided chart image and respond to queries with concise answers, usually a single word, number, or short phrase.\nThe charts include a variety of types (e.g., line charts, bar charts) and contain colors, labels, and text.\nFocus on delivering accurate, succinct answers based on the visual information. Avoid additional explanation unless absolutely necessary.'}]},
#   {'role': 'user',
#    'content': [{'type': 'text',
#      'text': 'Is the rightmost value of light brown graph 58?'}]},
#   {'role': 'assistant', 'content': [{'type': 'text', 'text': 'No'}]}],
#  2830,
#  192,
#  250)

# %%
import os
import re
import torch
import random
import numpy as np
from torch.utils.data import Dataset, DataLoader
import pandas as pd
from google.colab import drive

# Mount Google Drive to access the file
drive.mount('/content/drive')

class TextQuestionLabelDataset(Dataset):
    def __init__(self, input_file):
        # Load data from a CSV file
        self.data = pd.read_csv(input_file)
        #print(self.data.head())  # 显示前 5 行数据


        # Extract questions and labels from the Input column
        #self.questions = self.data['Input'].apply(lambda x: re.search(r'Question: (.+?)\n', x).group(1)).tolist()
        self.questions = self.data['Input'].tolist()
        self.labels = self.data['Label'].tolist()

    def __len__(self):
        # Return the total number of samples
        return len(self.questions)

    def __getitem__(self, idx):
        # Return a single sample (question, label) given an index
        question = self.questions[idx]
        label = self.labels[idx]
        return question, label

input_file = '/content/drive/MyDrive/Surgical_VQA.csv'

# Initialize dataset
dataset = TextQuestionLabelDataset(input_file)

# Split the dataset for train, eval, and test (e.g., 10% for each)
dataset_length = len(dataset)
#train_size = int(0.1 * dataset_length)
train_size = 0
#eval_size = int(0.1 * dataset_length)
eval_size = 0
test_size = dataset_length - train_size - eval_size
#seed everything
seed = 42
torch.manual_seed(seed)
random.seed(seed)
np.random.seed(seed)

# train_dataset, eval_dataset, test_dataset = torch.utils.data.random_split(
#     dataset, [train_size, eval_size, test_size]
# )

train_dataset = torch.utils.data.Subset(dataset, range(0, train_size))
eval_dataset = torch.utils.data.Subset(dataset, range(train_size, train_size + eval_size))
test_dataset = torch.utils.data.Subset(dataset, range(train_size + eval_size, len(dataset)))
#print(train_dataset[0])
train_dataset = [format_data(sample) for sample in train_dataset]
eval_dataset = [format_data(sample) for sample in eval_dataset]
test_dataset = [format_data(sample) for sample in test_dataset]

# Create DataLoaders for batching
# train_loader = DataLoader(train_dataset, batch_size=2, shuffle=True)
# eval_loader = DataLoader(eval_dataset, batch_size=2, shuffle=False)
# test_loader = DataLoader(test_dataset, batch_size=2, shuffle=False)
# test_dataset[0]
# test_dataset[0]
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import gc
import time

def clear_memory():
    # Delete variables if they exist in the current global scope
    if 'inputs' in globals(): del globals()['inputs']
    if 'model' in globals(): del globals()['model']
    if 'processor' in globals(): del globals()['processor']
    if 'trainer' in globals(): del globals()['trainer']
    if 'peft_model' in globals(): del globals()['peft_model']
    if 'bnb_config' in globals(): del globals()['bnb_config']
    time.sleep(2)

    # Garbage collection and clearing CUDA memory
    gc.collect()
    time.sleep(2)
    torch.cuda.empty_cache()
    torch.cuda.synchronize()
    time.sleep(2)
    gc.collect()
    time.sleep(2)

    print(f"GPU allocated memory: {torch.cuda.memory_allocated() / 1024**3:.2f} GB")
    print(f"GPU reserved memory: {torch.cuda.memory_reserved() / 1024**3:.2f} GB")



def generate_text_from_sample(model, processor, sample, max_new_tokens=1024, device="cuda"):
    # Prepare the text input by applying the chat template
    text_input = processor.apply_chat_template(
        sample[:1],  # Use the sample without the system message
        tokenize=False,
        add_generation_prompt=True
    )
    #print("Text Input:", text_input)


    # Process the visual input from the sample
    # image_inputs, _ = process_vision_info(sample)
    #image_inputs = sample[1]['content'][0]['image'].convert("RGB")
    image_data = sample[1]['content'][0].get('image')

    if image_data is not None:
        image_inputs = image_data.convert("RGB")
    else:
        # 提供一个默认值或适当的处理逻辑
        image_inputs = None
        #print("Warning: The 'image' field is None.")
    # Prepare the inputs for the model
    model_inputs = processor(
        text=[text_input],
        images=image_inputs,
        return_tensors="pt",
    ).to(device)  # Move inputs to the specified device

    # Generate text with the model
    generated_ids = model.generate(**model_inputs, max_new_tokens=max_new_tokens)

    # Trim the generated ids to remove the input ids
    trimmed_generated_ids = [
        out_ids[len(in_ids):] for in_ids, out_ids in zip(model_inputs.input_ids, generated_ids)
    ]

    # Decode the output text
    output_text = processor.batch_decode(
        trimmed_generated_ids,
        skip_special_tokens=True,
        clean_up_tokenization_spaces=False
    )

    return output_text[0]  # Return the first decoded output text

# %%
clear_memory()
# Out:
# GPU allocated memory: 0.01 GB
# GPU reserved memory: 0.02 GB

# %%
import evaluate
import torch
from nltk.translate.meteor_score import meteor_score, single_meteor_score
from nltk.translate.bleu_score import sentence_bleu, corpus_bleu
import requests
from torch import nn
from transformers import MllamaForConditionalGeneration, AutoProcessor, MllamaConfig, AutoModelForCausalLM
from typing import List, Optional, Tuple, Union
from PIL import Image
import matplotlib.pyplot as plt
from qwen_vl_utils import process_vision_info
from transformers import BitsAndBytesConfig



quantization_config = BitsAndBytesConfig(
    load_in_4bit=True,
    # low_cpu_mem_usage=True,
    # bnb_4bit_compute_dtype=torch.float16
)

model_id = "meta-llama/Llama-3.2-11B-Vision-Instruct"
processor = AutoProcessor.from_pretrained("meta-llama/Llama-3.2-11B-Vision-Instruct")
model = MllamaForConditionalGeneration.from_pretrained(
            model_id, torch_dtype=torch.bfloat16, device_map="auto", low_cpu_mem_usage=True,
            quantization_config=quantization_config,
        )
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# preprocessor_config.json:   0%|          | 0.00/437 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/55.8k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/5.07k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.09M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/454 [00:00<?, ?B/s]
# chat_template.json:   0%|          | 0.00/5.09k [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/89.4k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/5 [00:00<?, ?it/s]
# model-00001-of-00005.safetensors:   0%|          | 0.00/4.99G [00:00<?, ?B/s]
# model-00002-of-00005.safetensors:   0%|          | 0.00/4.97G [00:00<?, ?B/s]
# model-00003-of-00005.safetensors:   0%|          | 0.00/4.92G [00:00<?, ?B/s]
# model-00004-of-00005.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# model-00005-of-00005.safetensors:   0%|          | 0.00/1.47G [00:00<?, ?B/s]
# WARNING:accelerate.utils.modeling:The model weights are not tied. Please use the `tie_weights` method before using the `infer_auto_device` function.
# Loading checkpoint shards:   0%|          | 0/5 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/215 [00:00<?, ?B/s]

# %%
import os
import re
import torch
import random
import numpy as np
from torch.utils.data import Dataset, DataLoader
import pandas as pd
from google.colab import drive


def generate_text_from_sample(model, processor, sample, max_new_tokens=1024, device="cuda"):
    # Prepare the text input by applying the chat template
    text_input = processor.apply_chat_template(
        sample[:1],  # Use the sample without the system message
        tokenize=False,
        add_generation_prompt=True
    )
    #print("Text Input:", text_input)


    # Process the visual input from the sample
    # image_inputs, _ = process_vision_info(sample)
    #image_inputs = sample[1]['content'][0]['image'].convert("RGB")
    image_data = sample[1]['content'][0].get('image')

    if image_data is not None:
        image_inputs = image_data.convert("RGB")
    else:
        # 提供一个默认值或适当的处理逻辑
        image_inputs = None
        #print("Warning: The 'image' field is None.")
    # Prepare the inputs for the model
    model_inputs = processor(
        text=[text_input],
        images=image_inputs,
        return_tensors="pt",
    ).to(device)  # Move inputs to the specified device

    # Generate text with the model
    generated_ids = model.generate(**model_inputs, max_new_tokens=max_new_tokens)

    # Trim the generated ids to remove the input ids
    trimmed_generated_ids = [
        out_ids[len(in_ids):] for in_ids, out_ids in zip(model_inputs.input_ids, generated_ids)
    ]

    # Decode the output text
    output_text = processor.batch_decode(
        trimmed_generated_ids,
        skip_special_tokens=True,
        clean_up_tokenization_spaces=False
    )

    return output_text[0]

# Mount Google Drive to access the file
drive.mount('/content/drive')

class TextQuestionLabelDataset(Dataset):
    def __init__(self, input_file):
        # Load data from a CSV file
        self.data = pd.read_csv(input_file)
        # print(self.data.head())  # 显示前 5 行数据


        # Extract questions and labels from the Input column
        #self.questions = self.data['Input'].apply(lambda x: re.search(r'Question: (.+?)\n', x).group(1)).tolist()
        self.questions = self.data['Input'].tolist()
        self.labels = self.data['Label'].tolist()

    def __len__(self):
        # Return the total number of samples
        return len(self.questions)

    def __getitem__(self, idx):
        # Return a single sample (question, label) given an index
        question = self.questions[idx]
        label = self.labels[idx]
        return question, label

input_file = '/content/drive/MyDrive/sample.csv'

# Initialize dataset
dataset = TextQuestionLabelDataset(input_file)

# Split the dataset for train, eval, and test (e.g., 10% for each)
dataset_length = len(dataset)
#train_size = int(0.1 * dataset_length)
train_size = 0
#eval_size = int(0.1 * dataset_length)
eval_size = 0
test_size = dataset_length - train_size - eval_size

#seed everything
seed = 42
torch.manual_seed(seed)
random.seed(seed)
np.random.seed(seed)

# train_dataset, eval_dataset, test_dataset = torch.utils.data.random_split(
#     dataset, [train_size, eval_size, test_size]
# )

train_dataset = torch.utils.data.Subset(dataset, range(0, train_size))
eval_dataset = torch.utils.data.Subset(dataset, range(train_size, train_size + eval_size))
test_dataset = torch.utils.data.Subset(dataset, range(train_size + eval_size, len(dataset)))

def generate_SM(que):
    sm = (
        "Select a model to answer the following question:\n"
        f"{que}\n"
        "Select a model only from the following model list: Segment-Video, Segment-MRI, "
        "Detect-Video, Overlaying, Surgical-VQA to answer the question.\n"
        "Generate a shortest prompt for the chosen model. "
        "Your response should be like Model: ? Prompt: ? and no other words."
    )
    return sm


# system_message = """ Select a model to answer the following question: What is the position of the instrument?
# Select model only from the following model list: Segment-Video, Segment-MRI, Detect-Video, Overlaying, Surgical-VQA to answer the question?
# Generate a shortest prompt for the chosen model. Your response should be like Model: ? Prompt: ? and no other words
# """


# system_message = """ You are an LLM agent which can call functions and corresponding prompt based on surgeons' query.
# The agent will be used in endonasal pituitary surgery to call visual models Segment-Video, Segment-MRI, Detect-Video, Overlaying, Surgical-VQA.
# There are 59 classes overall, including 4 phases, 15 steps, 18 instruments, 3 variations of instruments present in a frame, 5 positions of the instruments, and 14 operation notes in the annotation classes.
# The agent may call more than one model sequentially or in parallel based on query.
# Your task is to analyze the user's query, determine the intent, and return the name of the AI model to be invoked along with the corresponding prompt.
# If you receive the input like: "Question: Segment tumor from MRI and overlay on video?" The format of the answer should be like this: Model: Segmen-MRI|Overlaying
# Prompt: Segment tumor from MRI?|Overlay on video?" This is the format for the answers may need more than one model. The model options are Model Options: [Segment-Video, Segment-MRI, Detect-Video, Overlaying, Surgical-VQA].
# If you receive the input like: "Question: Segment Sella from Video?" The format of the answer should be like this: Model: Segment-Video
# Prompt: Segment Sella from video?" This is the format for the answers need only one model. The model options are Model Options:[Segment-Video, Segment-MRI, Detect-Video, Overlaying, Surgical-VQA].
# """
# system_message = """
# Your task is to analyze the user's query, determine the intent, and return the name of the AI model to be invoked along with the corresponding prompt.
# If you receive the input like: "Question: Segment tumor from MRI and overlay on video?" The format of the answer should be like this: Model: Segmen-MRI|Overlaying
# Prompt: Segment tumor from MRI?|Overlay on video?" This is the format for the answers may need more than one model. The model options are Model Options: [Segment-Video, Segment-MRI, Detect-Video, Overlaying, Surgical-VQA].
# If you receive the input like: "Question: Segment Sella from Video?" The format of the answer should be like this: Model: Segment-Video
# Prompt: Segment Sella from video?" This is the format for the answers need only one model. The model options are Model Options:[Segment-Video, Segment-MRI, Detect-Video, Overlaying, Surgical-VQA].
# """

# system_message="""
# Select models only from the following list:
# ['Segment-Video', 'Segment-MRI', 'Detect-Video', 'Overlaying', 'Surgical-VQA'].
# For each input question, determine the required models and generate corresponding prompts.

# Output Format:
# - For a single model:
#   Model: <ModelName>
#   Prompt: <CorrespondingPrompt>?

# - For multiple models:
#   Model: <Model1>|<Model2>
#   Prompt: <Prompt1>?|<Prompt2>?
# """

def format_data_test1(sample):
    return [
        {
            "role": "system",
            "content": [
                {
                    "type": "text",
                    "text": system_message
                }
            ],
        },
        # {
        #     "role": "user",
        #     "content": [

        #         {
        #             "type": "text",
        #             "text": sample[0],

        #         }
        #     ],
        # },
        {
            "role": "assistant",
            "content": [
                {
                    "type": "text",
                    "text": sample[1]
                }
            ],
        },
    ]

system_message = generate_SM(test_dataset[0][0])
print(test_dataset[0][0])
input1 = format_data_test1(test_dataset[0])
input2 = format_data_test1(test_dataset[2])
print(input1)
#print(input2)
# print("input: ", input)
# text_input = processor.apply_chat_template(
#         input[:2],  # Use the sample without the system message
#         tokenize=False,
#         add_generation_prompt=True
#     )
# print("text_input: ", text_input)
# input[:2]
output1 = generate_text_from_sample(model, processor, input1)
ans1 = input1[1]['content'][0]['text']
print("output1: ",output1)
print("answer1: ",ans1)
# print("--------------------------------------------")
# output2 = generate_text_from_sample(model, processor, input1)
# ans2 = input2[2]['content'][0]['text']
# print("output2: ",output2)
# print("answer2: ",ans2)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Question: Detect surgical instruments in the video?
# [{'role': 'system', 'content': [{'type': 'text', 'text': 'Select a model to answer the following question:\nQuestion: Detect surgical instruments in the video?\nSelect a model only from the following model list: Segment-Video, Segment-MRI, Detect-Video, Overlaying, Surgical-VQA to answer the question.\nGenerate a shortest prompt for the chosen model. Your response should be like Model: ? Prompt: ? and no other words.'}]}, {'role': 'assistant', 'content': [{'type': 'text', 'text': 'Model: Detect-Video\nPrompt: Detect instruments in the video?'}]}]
# output1:  Model: Detect-Video
# Prompt: Detect surgical instruments in the video.
# answer1:  Model: Detect-Video
# Prompt: Detect instruments in the video?

# %%
all_pred = []
all_ans = []

# %%
model.eval()
with torch.no_grad():
    for sample in test_dataset:
        output = generate_text_from_sample(model, processor, sample)
        ans = sample[1]['content'][0]['text']
        all_pred.append(output)
        all_ans.append(ans)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-d26639addd90> in <cell line: 0>()
#       2 with torch.no_grad():
#       3     for sample in test_dataset:
# ----> 4         output = generate_text_from_sample(model, processor, sample)
#       5         ans = sample[1]['content'][0]['text']
#       6         all_pred.append(output)
#
# <ipython-input-6-b3f50f5f80ac> in generate_text_from_sample(model, processor, sample, max_new_tokens, device)
#      55
#      56     # Generate text with the model
# ---> 57     generated_ids = model.generate(**model_inputs, max_new_tokens=max_new_tokens)
#      58
#      59     # Trim the generated ids to remove the input ids
#
# /usr/local/lib/python3.11/dist-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     114     def decorate_context(*args, **kwargs):
#     115         with ctx_factory():
# --> 116             return func(*args, **kwargs)
#     117
#     118     return decorate_context
#
# /usr/local/lib/python3.11/dist-packages/transformers/generation/utils.py in generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, **kwargs)
#    2046
#    2047             # 12. run sample (it degenerates to greedy search when `generation_config.do_sample=False`)
# -> 2048             result = self._sample(
#    2049                 input_ids,
#    2050                 logits_processor=prepared_logits_processor,
#
# /usr/local/lib/python3.11/dist-packages/transformers/generation/utils.py in _sample(self, input_ids, logits_processor, stopping_criteria, generation_config, synced_gpus, streamer, **model_kwargs)
#    3006
#    3007             # forward pass to get next token
# -> 3008             outputs = self(**model_inputs, return_dict=True)
#    3009
#    3010             if synced_gpus and this_peer_finished:
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1551             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552         else:
# -> 1553             return self._call_impl(*args, **kwargs)
#    1554
#    1555     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1560                 or _global_backward_pre_hooks or _global_backward_hooks
#    1561                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562             return forward_call(*args, **kwargs)
#    1563
#    1564         try:
#
# /usr/local/lib/python3.11/dist-packages/accelerate/hooks.py in new_forward(module, *args, **kwargs)
#     168                 output = module._old_forward(*args, **kwargs)
#     169         else:
# --> 170             output = module._old_forward(*args, **kwargs)
#     171         return module._hf_hook.post_forward(module, output)
#     172
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/mllama/modeling_mllama.py in forward(self, input_ids, pixel_values, aspect_ratio_mask, aspect_ratio_ids, attention_mask, cross_attention_mask, cross_attention_states, position_ids, past_key_values, inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, return_dict, cache_position, num_logits_to_keep)
#    2186             full_text_row_masked_out_mask = full_text_row_masked_out_mask[:, :, cache_position]
#    2187
# -> 2188         outputs = self.language_model(
#    2189             input_ids=input_ids,
#    2190             attention_mask=attention_mask,
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1551             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552         else:
# -> 1553             return self._call_impl(*args, **kwargs)
#    1554
#    1555     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1560                 or _global_backward_pre_hooks or _global_backward_hooks
#    1561                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562             return forward_call(*args, **kwargs)
#    1563
#    1564         try:
#
# /usr/local/lib/python3.11/dist-packages/accelerate/hooks.py in new_forward(module, *args, **kwargs)
#     168                 output = module._old_forward(*args, **kwargs)
#     169         else:
# --> 170             output = module._old_forward(*args, **kwargs)
#     171         return module._hf_hook.post_forward(module, output)
#     172
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/mllama/modeling_mllama.py in forward(self, input_ids, attention_mask, position_ids, cross_attention_states, cross_attention_mask, full_text_row_masked_out_mask, past_key_values, inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, return_dict, cache_position, num_logits_to_keep)
#    1927
#    1928         # decoder outputs consists of (dec_features, layer_state, dec_hidden, dec_attn)
# -> 1929         outputs = self.model(
#    1930             input_ids=input_ids,
#    1931             cross_attention_states=cross_attention_states,
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1551             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552         else:
# -> 1553             return self._call_impl(*args, **kwargs)
#    1554
#    1555     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1560                 or _global_backward_pre_hooks or _global_backward_hooks
#    1561                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562             return forward_call(*args, **kwargs)
#    1563
#    1564         try:
#
# /usr/local/lib/python3.11/dist-packages/accelerate/hooks.py in new_forward(module, *args, **kwargs)
#     168                 output = module._old_forward(*args, **kwargs)
#     169         else:
# --> 170             output = module._old_forward(*args, **kwargs)
#     171         return module._hf_hook.post_forward(module, output)
#     172
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/mllama/modeling_mllama.py in forward(self, input_ids, attention_mask, position_ids, cross_attention_states, cross_attention_mask, full_text_row_masked_out_mask, past_key_values, inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict, cache_position)
#    1727                 )
#    1728             else:
# -> 1729                 layer_outputs = decoder_layer(
#    1730                     hidden_states,
#    1731                     cross_attention_states=cross_attention_states,
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1551             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552         else:
# -> 1553             return self._call_impl(*args, **kwargs)
#    1554
#    1555     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1560                 or _global_backward_pre_hooks or _global_backward_hooks
#    1561                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562             return forward_call(*args, **kwargs)
#    1563
#    1564         try:
#
# /usr/local/lib/python3.11/dist-packages/accelerate/hooks.py in new_forward(module, *args, **kwargs)
#     168                 output = module._old_forward(*args, **kwargs)
#     169         else:
# --> 170             output = module._old_forward(*args, **kwargs)
#     171         return module._hf_hook.post_forward(module, output)
#     172
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/mllama/modeling_mllama.py in forward(self, hidden_states, cross_attention_states, cross_attention_mask, attention_mask, full_text_row_masked_out_mask, position_ids, past_key_value, output_attentions, use_cache, cache_position, position_embeddings)
#     943
#     944         # Self Attention
# --> 945         hidden_states, self_attn_weights, present_key_value = self.self_attn(
#     946             hidden_states=hidden_states,
#     947             attention_mask=attention_mask,
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1551             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552         else:
# -> 1553             return self._call_impl(*args, **kwargs)
#    1554
#    1555     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1560                 or _global_backward_pre_hooks or _global_backward_hooks
#    1561                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562             return forward_call(*args, **kwargs)
#    1563
#    1564         try:
#
# /usr/local/lib/python3.11/dist-packages/accelerate/hooks.py in new_forward(module, *args, **kwargs)
#     168                 output = module._old_forward(*args, **kwargs)
#     169         else:
# --> 170             output = module._old_forward(*args, **kwargs)
#     171         return module._hf_hook.post_forward(module, output)
#     172
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/mllama/modeling_mllama.py in forward(self, hidden_states, attention_mask, position_embeddings, output_attentions, use_cache, past_key_value, cache_position, **kwargs)
#     851         is_causal = True if causal_mask is None and q_len > 1 else False
#     852
# --> 853         attn_output = torch.nn.functional.scaled_dot_product_attention(
#     854             query_states,
#     855             key_states,
#
# KeyboardInterrupt:

# %%
import os
import torch
import pickle
from google.colab import drive

drive.mount('/content/drive')
start_index = 0
# 设置保存路径
save_path = '/content/drive/My Drive/Sharing/Surgical_VQA_V.pkl'

# 尝试加载之前的进度
if os.path.exists(save_path):
    with open(save_path, 'rb') as f:
        saved_data = pickle.load(f)
        start_index = saved_data['start_index']
        all_pred = saved_data['all_pred']
        all_ans = saved_data['all_ans']
        print(f"Resuming from index {start_index}")
else:
    start_index = 0
    all_pred = []
    all_ans = []
    print("Starting fresh")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Starting fresh

# %%
model.eval()
with torch.no_grad():
    for i, sample in enumerate(test_dataset):
        # 跳过已处理的样本
        if i < start_index:
            continue

        output = generate_text_from_sample(model, processor, sample)
        ans = sample[1]['content'][0]['text']
        all_pred.append(output)
        all_ans.append(ans)

        # 更新进度
        start_index = i + 1
        saved_data = {
            'start_index': start_index,
            'all_pred': all_pred,
            'all_ans': all_ans
        }

        # 保存到Google Drive
        with open(save_path, 'wb') as f:
            pickle.dump(saved_data, f)

        print(f"Processed sample {i+1}/{len(test_dataset)}")

print("All samples processed!")
# Out:
# Processed sample 14/1000
# Processed sample 15/1000
# Processed sample 16/1000
# Processed sample 17/1000
# Processed sample 18/1000
# Processed sample 19/1000
# Processed sample 20/1000
# Processed sample 21/1000
# Processed sample 22/1000
# Processed sample 23/1000
# Processed sample 24/1000
# Processed sample 25/1000
# Processed sample 26/1000
# Processed sample 27/1000
# Processed sample 28/1000
# Processed sample 29/1000
# Processed sample 30/1000
# Processed sample 31/1000
# Processed sample 32/1000
# Processed sample 33/1000
# Processed sample 34/1000
# Processed sample 35/1000
# Processed sample 36/1000
# Processed sample 37/1000
# Processed sample 38/1000
# Processed sample 39/1000
# Processed sample 40/1000
# Processed sample 41/1000
# Processed sample 42/1000
# Processed sample 43/1000
# Processed sample 44/1000
# Processed sample 45/1000
# Processed sample 46/1000
# Processed sample 47/1000
# Processed sample 48/1000
# Processed sample 49/1000
# Processed sample 50/1000
# Processed sample 51/1000
# Processed sample 52/1000
# Processed sample 53/1000
# Processed sample 54/1000
# Processed sample 55/1000
# Processed sample 56/1000
# Processed sample 57/1000
# Processed sample 58/1000
# Processed sample 59/1000
# Processed sample 60/1000
# Processed sample 61/1000
# Processed sample 62/1000
# Processed sample 63/1000
# Processed sample 64/1000
# Processed sample 65/1000
# Processed sample 66/1000
# Processed sample 67/1000
# Processed sample 68/1000
# Processed sample 69/1000
# Processed sample 70/1000
# Processed sample 71/1000
# Processed sample 72/1000
# Processed sample 73/1000
# Processed sample 74/1000
# Processed sample 75/1000
# Processed sample 76/1000
# Processed sample 77/1000
# Processed sample 78/1000
# Processed sample 79/1000
# Processed sample 80/1000
# Processed sample 81/1000
# Processed sample 82/1000
# Processed sample 83/1000
# Processed sample 84/1000
# Processed sample 85/1000
# Processed sample 86/1000
# Processed sample 87/1000
# Processed sample 88/1000
# Processed sample 89/1000
# Processed sample 90/1000
# Processed sample 91/1000
# Processed sample 92/1000
# Processed sample 93/1000
# Processed sample 94/1000
# Processed sample 95/1000
# Processed sample 96/1000
# Processed sample 97/1000
# Processed sample 98/1000
# Processed sample 99/1000
# Processed sample 100/1000
# Processed sample 101/1000
# Processed sample 102/1000
# Processed sample 103/1000
# Processed sample 104/1000
# Processed sample 105/1000
# Processed sample 106/1000
# Processed sample 107/1000
# Processed sample 108/1000
# Processed sample 109/1000
# Processed sample 110/1000
# Processed sample 111/1000
# Processed sample 112/1000
# Processed sample 113/1000
# Processed sample 114/1000
# Processed sample 115/1000
# Processed sample 116/1000
# Processed sample 117/1000
# Processed sample 118/1000
# Processed sample 119/1000
# Processed sample 120/1000
# Processed sample 121/1000
# Processed sample 122/1000
# Processed sample 123/1000
# Processed sample 124/1000
# Processed sample 125/1000
# Processed sample 126/1000
# Processed sample 127/1000
# Processed sample 128/1000
# Processed sample 129/1000
# Processed sample 130/1000
# Processed sample 131/1000
# Processed sample 132/1000
# Processed sample 133/1000
# Processed sample 134/1000
# Processed sample 135/1000
# Processed sample 136/1000
# Processed sample 137/1000
# Processed sample 138/1000
# Processed sample 139/1000
# Processed sample 140/1000
# Processed sample 141/1000
# Processed sample 142/1000
# Processed sample 143/1000
# Processed sample 144/1000
# Processed sample 145/1000
# Processed sample 146/1000
# Processed sample 147/1000
# Processed sample 148/1000
# Processed sample 149/1000
# Processed sample 150/1000
# Processed sample 151/1000
# Processed sample 152/1000
# Processed sample 153/1000
# Processed sample 154/1000
# Processed sample 155/1000
# Processed sample 156/1000
# Processed sample 157/1000
# Processed sample 158/1000
# Processed sample 159/1000
# Processed sample 160/1000
# Processed sample 161/1000
# Processed sample 162/1000
# Processed sample 163/1000
# Processed sample 164/1000
# Processed sample 165/1000
# Processed sample 166/1000
# Processed sample 167/1000
# Processed sample 168/1000
# Processed sample 169/1000
# Processed sample 170/1000
# Processed sample 171/1000
# Processed sample 172/1000
# Processed sample 173/1000
# Processed sample 174/1000
# Processed sample 175/1000
# Processed sample 176/1000
# Processed sample 177/1000
# Processed sample 178/1000
# Processed sample 179/1000
# Processed sample 180/1000
# Processed sample 181/1000
# Processed sample 182/1000
# Processed sample 183/1000
# Processed sample 184/1000
# Processed sample 185/1000
# Processed sample 186/1000
# Processed sample 187/1000
# Processed sample 188/1000
# Processed sample 189/1000
# Processed sample 190/1000
# Processed sample 191/1000
# Processed sample 192/1000
# Processed sample 193/1000
# Processed sample 194/1000
# Processed sample 195/1000
# Processed sample 196/1000
# Processed sample 197/1000
# Processed sample 198/1000
# Processed sample 199/1000
# Processed sample 200/1000
# Processed sample 201/1000
# Processed sample 202/1000
# Processed sample 203/1000
# Processed sample 204/1000
# Processed sample 205/1000
# Processed sample 206/1000
# Processed sample 207/1000
# Processed sample 208/1000
# Processed sample 209/1000
# Processed sample 210/1000
# Processed sample 211/1000
# Processed sample 212/1000
# Processed sample 213/1000
# Processed sample 214/1000
# Processed sample 215/1000
# Processed sample 216/1000
# Processed sample 217/1000
# Processed sample 218/1000
# Processed sample 219/1000
# Processed sample 220/1000
# Processed sample 221/1000
# Processed sample 222/1000
# Processed sample 223/1000
# Processed sample 224/1000
# Processed sample 225/1000
# Processed sample 226/1000
# Processed sample 227/1000
# Processed sample 228/1000
# Processed sample 229/1000
# Processed sample 230/1000
# Processed sample 231/1000
# Processed sample 232/1000
# Processed sample 233/1000
# Processed sample 234/1000
# Processed sample 235/1000
# Processed sample 236/1000
# Processed sample 237/1000
# Processed sample 238/1000
# Processed sample 239/1000
# Processed sample 240/1000
# Processed sample 241/1000
# Processed sample 242/1000
# Processed sample 243/1000
# Processed sample 244/1000
# Processed sample 245/1000
# Processed sample 246/1000
# Processed sample 247/1000
# Processed sample 248/1000
# Processed sample 249/1000
# Processed sample 250/1000
# Processed sample 251/1000
# Processed sample 252/1000
# Processed sample 253/1000
# Processed sample 254/1000
# Processed sample 255/1000
# Processed sample 256/1000
# Processed sample 257/1000
# Processed sample 258/1000
# Processed sample 259/1000
# Processed sample 260/1000
# Processed sample 261/1000
# Processed sample 262/1000
# Processed sample 263/1000
# Processed sample 264/1000
# Processed sample 265/1000
# Processed sample 266/1000
# Processed sample 267/1000
# Processed sample 268/1000
# Processed sample 269/1000
# Processed sample 270/1000
# Processed sample 271/1000
# Processed sample 272/1000
# Processed sample 273/1000
# Processed sample 274/1000
# Processed sample 275/1000
# Processed sample 276/1000
# Processed sample 277/1000
# Processed sample 278/1000
# Processed sample 279/1000
# Processed sample 280/1000
# Processed sample 281/1000
# Processed sample 282/1000
# Processed sample 283/1000
# Processed sample 284/1000
# Processed sample 285/1000
# Processed sample 286/1000
# Processed sample 287/1000
# Processed sample 288/1000
# Processed sample 289/1000
# Processed sample 290/1000
# Processed sample 291/1000
# Processed sample 292/1000
# Processed sample 293/1000
# Processed sample 294/1000
# Processed sample 295/1000
# Processed sample 296/1000
# Processed sample 297/1000
# Processed sample 298/1000
# Processed sample 299/1000
# Processed sample 300/1000
# Processed sample 301/1000
# Processed sample 302/1000
# Processed sample 303/1000
# Processed sample 304/1000
# Processed sample 305/1000
# Processed sample 306/1000
# Processed sample 307/1000
# Processed sample 308/1000
# Processed sample 309/1000
# Processed sample 310/1000
# Processed sample 311/1000
# Processed sample 312/1000
# Processed sample 313/1000
# Processed sample 314/1000
# Processed sample 315/1000
# Processed sample 316/1000
# Processed sample 317/1000
# Processed sample 318/1000
# Processed sample 319/1000
# Processed sample 320/1000
# Processed sample 321/1000
# Processed sample 322/1000
# Processed sample 323/1000
# Processed sample 324/1000
# Processed sample 325/1000
# Processed sample 326/1000
# Processed sample 327/1000
# Processed sample 328/1000
# Processed sample 329/1000
# Processed sample 330/1000
# Processed sample 331/1000
# Processed sample 332/1000
# Processed sample 333/1000
# Processed sample 334/1000
# Processed sample 335/1000
# Processed sample 336/1000
# Processed sample 337/1000
# Processed sample 338/1000
# Processed sample 339/1000
# Processed sample 340/1000
# Processed sample 341/1000
# Processed sample 342/1000
# Processed sample 343/1000
# Processed sample 344/1000
# Processed sample 345/1000
# Processed sample 346/1000
# Processed sample 347/1000
# Processed sample 348/1000
# Processed sample 349/1000
# Processed sample 350/1000
# Processed sample 351/1000
# Processed sample 352/1000
# Processed sample 353/1000
# Processed sample 354/1000
# Processed sample 355/1000
# Processed sample 356/1000
# Processed sample 357/1000
# Processed sample 358/1000
# Processed sample 359/1000
# Processed sample 360/1000
# Processed sample 361/1000
# Processed sample 362/1000
# Processed sample 363/1000
# Processed sample 364/1000
# Processed sample 365/1000
# Processed sample 366/1000
# Processed sample 367/1000
# Processed sample 368/1000
# Processed sample 369/1000
# Processed sample 370/1000
# Processed sample 371/1000
# Processed sample 372/1000
# Processed sample 373/1000
# Processed sample 374/1000
# Processed sample 375/1000
# Processed sample 376/1000
# Processed sample 377/1000
# Processed sample 378/1000
# Processed sample 379/1000
# Processed sample 380/1000
# Processed sample 381/1000
# Processed sample 382/1000
# Processed sample 383/1000
# Processed sample 384/1000
# Processed sample 385/1000
# Processed sample 386/1000
# Processed sample 387/1000
# Processed sample 388/1000
# Processed sample 389/1000
# Processed sample 390/1000
# Processed sample 391/1000
# Processed sample 392/1000
# Processed sample 393/1000
# Processed sample 394/1000
# Processed sample 395/1000
# Processed sample 396/1000
# Processed sample 397/1000
# Processed sample 398/1000
# Processed sample 399/1000
# Processed sample 400/1000
# Processed sample 401/1000
# Processed sample 402/1000
# Processed sample 403/1000
# Processed sample 404/1000
# Processed sample 405/1000
# Processed sample 406/1000
# Processed sample 407/1000
# Processed sample 408/1000
# Processed sample 409/1000
# Processed sample 410/1000
# Processed sample 411/1000
# Processed sample 412/1000
# Processed sample 413/1000
# Processed sample 414/1000
# Processed sample 415/1000
# Processed sample 416/1000
# Processed sample 417/1000
# Processed sample 418/1000
# Processed sample 419/1000
# Processed sample 420/1000
# Processed sample 421/1000
# Processed sample 422/1000
# Processed sample 423/1000
# Processed sample 424/1000
# Processed sample 425/1000
# Processed sample 426/1000
# Processed sample 427/1000
# Processed sample 428/1000
# Processed sample 429/1000
# Processed sample 430/1000
# Processed sample 431/1000
# Processed sample 432/1000
# Processed sample 433/1000
# Processed sample 434/1000
# Processed sample 435/1000
# Processed sample 436/1000
# Processed sample 437/1000
# Processed sample 438/1000
# Processed sample 439/1000
# Processed sample 440/1000
# Processed sample 441/1000
# Processed sample 442/1000
# Processed sample 443/1000
# Processed sample 444/1000
# Processed sample 445/1000
# Processed sample 446/1000
# Processed sample 447/1000
# Processed sample 448/1000
# Processed sample 449/1000
# Processed sample 450/1000
# Processed sample 451/1000
# Processed sample 452/1000
# Processed sample 453/1000
# Processed sample 454/1000
# Processed sample 455/1000
# Processed sample 456/1000
# Processed sample 457/1000
# Processed sample 458/1000
# Processed sample 459/1000
# Processed sample 460/1000
# Processed sample 461/1000
# Processed sample 462/1000
# Processed sample 463/1000
# Processed sample 464/1000
# Processed sample 465/1000
# Processed sample 466/1000
# Processed sample 467/1000
# Processed sample 468/1000
# Processed sample 469/1000
# Processed sample 470/1000
# Processed sample 471/1000
# Processed sample 472/1000
# Processed sample 473/1000
# Processed sample 474/1000
# Processed sample 475/1000
# Processed sample 476/1000
# Processed sample 477/1000
# Processed sample 478/1000
# Processed sample 479/1000
# Processed sample 480/1000
# Processed sample 481/1000
# Processed sample 482/1000
# Processed sample 483/1000
# Processed sample 484/1000
# Processed sample 485/1000
# Processed sample 486/1000
# Processed sample 487/1000
# Processed sample 488/1000
# Processed sample 489/1000
# Processed sample 490/1000
# Processed sample 491/1000
# Processed sample 492/1000
# Processed sample 493/1000
# Processed sample 494/1000
# Processed sample 495/1000
# Processed sample 496/1000
# Processed sample 497/1000
# Processed sample 498/1000
# Processed sample 499/1000
# Processed sample 500/1000
# Processed sample 501/1000
# Processed sample 502/1000
# Processed sample 503/1000
# Processed sample 504/1000
# Processed sample 505/1000
# Processed sample 506/1000
# Processed sample 507/1000
# Processed sample 508/1000
# Processed sample 509/1000
# Processed sample 510/1000
# Processed sample 511/1000
# Processed sample 512/1000
# Processed sample 513/1000
# Processed sample 514/1000
# Processed sample 515/1000
# Processed sample 516/1000
# Processed sample 517/1000
# Processed sample 518/1000
# Processed sample 519/1000
# Processed sample 520/1000
# Processed sample 521/1000
# Processed sample 522/1000
# Processed sample 523/1000
# Processed sample 524/1000
# Processed sample 525/1000
# Processed sample 526/1000
# Processed sample 527/1000
# Processed sample 528/1000
# Processed sample 529/1000
# Processed sample 530/1000
# Processed sample 531/1000
# Processed sample 532/1000
# Processed sample 533/1000
# Processed sample 534/1000
# Processed sample 535/1000
# Processed sample 536/1000
# Processed sample 537/1000
# Processed sample 538/1000
# Processed sample 539/1000
# Processed sample 540/1000
# Processed sample 541/1000
# Processed sample 542/1000
# Processed sample 543/1000
# Processed sample 544/1000
# Processed sample 545/1000
# Processed sample 546/1000
# Processed sample 547/1000
# Processed sample 548/1000
# Processed sample 549/1000
# Processed sample 550/1000
# Processed sample 551/1000
# Processed sample 552/1000
# Processed sample 553/1000
# Processed sample 554/1000
# Processed sample 555/1000
# Processed sample 556/1000
# Processed sample 557/1000
# Processed sample 558/1000
# Processed sample 559/1000
# Processed sample 560/1000
# Processed sample 561/1000
# Processed sample 562/1000
# Processed sample 563/1000
# Processed sample 564/1000
# Processed sample 565/1000
# Processed sample 566/1000
# Processed sample 567/1000
# Processed sample 568/1000
# Processed sample 569/1000
# Processed sample 570/1000
# Processed sample 571/1000
# Processed sample 572/1000
# Processed sample 573/1000
# Processed sample 574/1000
# Processed sample 575/1000
# Processed sample 576/1000
# Processed sample 577/1000
# Processed sample 578/1000
# Processed sample 579/1000
# Processed sample 580/1000
# Processed sample 581/1000
# Processed sample 582/1000
# Processed sample 583/1000
# Processed sample 584/1000
# Processed sample 585/1000
# Processed sample 586/1000
# Processed sample 587/1000
# Processed sample 588/1000
# Processed sample 589/1000
# Processed sample 590/1000
# Processed sample 591/1000
# Processed sample 592/1000
# Processed sample 593/1000
# Processed sample 594/1000
# Processed sample 595/1000
# Processed sample 596/1000
# Processed sample 597/1000
# Processed sample 598/1000
# Processed sample 599/1000
# Processed sample 600/1000
# Processed sample 601/1000
# Processed sample 602/1000
# Processed sample 603/1000
# Processed sample 604/1000
# Processed sample 605/1000
# Processed sample 606/1000
# Processed sample 607/1000
# Processed sample 608/1000
# Processed sample 609/1000
# Processed sample 610/1000
# Processed sample 611/1000
# Processed sample 612/1000
# Processed sample 613/1000
# Processed sample 614/1000
# Processed sample 615/1000
# Processed sample 616/1000
# Processed sample 617/1000
# Processed sample 618/1000
# Processed sample 619/1000
# Processed sample 620/1000
# Processed sample 621/1000
# Processed sample 622/1000
# Processed sample 623/1000
# Processed sample 624/1000
# Processed sample 625/1000
# Processed sample 626/1000
# Processed sample 627/1000
# Processed sample 628/1000
# Processed sample 629/1000
# Processed sample 630/1000
# Processed sample 631/1000
# Processed sample 632/1000
# Processed sample 633/1000
# Processed sample 634/1000
# Processed sample 635/1000
# Processed sample 636/1000
# Processed sample 637/1000
# Processed sample 638/1000
# Processed sample 639/1000
# Processed sample 640/1000
# Processed sample 641/1000
# Processed sample 642/1000
# Processed sample 643/1000
# Processed sample 644/1000
# Processed sample 645/1000
# Processed sample 646/1000
# Processed sample 647/1000
# Processed sample 648/1000
# Processed sample 649/1000
# Processed sample 650/1000
# Processed sample 651/1000
# Processed sample 652/1000
# Processed sample 653/1000
# Processed sample 654/1000
# Processed sample 655/1000
# Processed sample 656/1000
# Processed sample 657/1000
# Processed sample 658/1000
# Processed sample 659/1000
# Processed sample 660/1000
# Processed sample 661/1000
# Processed sample 662/1000
# Processed sample 663/1000
# Processed sample 664/1000
# Processed sample 665/1000
# Processed sample 666/1000
# Processed sample 667/1000
# Processed sample 668/1000
# Processed sample 669/1000
# Processed sample 670/1000
# Processed sample 671/1000
# Processed sample 672/1000
# Processed sample 673/1000
# Processed sample 674/1000
# Processed sample 675/1000
# Processed sample 676/1000
# Processed sample 677/1000
# Processed sample 678/1000
# Processed sample 679/1000
# Processed sample 680/1000
# Processed sample 681/1000
# Processed sample 682/1000
# Processed sample 683/1000
# Processed sample 684/1000
# Processed sample 685/1000
# Processed sample 686/1000
# Processed sample 687/1000
# Processed sample 688/1000
# Processed sample 689/1000
# Processed sample 690/1000
# Processed sample 691/1000
# Processed sample 692/1000
# Processed sample 693/1000
# Processed sample 694/1000
# Processed sample 695/1000
# Processed sample 696/1000
# Processed sample 697/1000
# Processed sample 698/1000
# Processed sample 699/1000
# Processed sample 700/1000
# Processed sample 701/1000
# Processed sample 702/1000
# Processed sample 703/1000
# Processed sample 704/1000
# Processed sample 705/1000
# Processed sample 706/1000
# Processed sample 707/1000
# Processed sample 708/1000
# Processed sample 709/1000
# Processed sample 710/1000
# Processed sample 711/1000
# Processed sample 712/1000
# Processed sample 713/1000
# Processed sample 714/1000
# Processed sample 715/1000
# Processed sample 716/1000
# Processed sample 717/1000
# Processed sample 718/1000
# Processed sample 719/1000
# Processed sample 720/1000
# Processed sample 721/1000
# Processed sample 722/1000
# Processed sample 723/1000
# Processed sample 724/1000
# Processed sample 725/1000
# Processed sample 726/1000
# Processed sample 727/1000
# Processed sample 728/1000
# Processed sample 729/1000
# Processed sample 730/1000
# Processed sample 731/1000
# Processed sample 732/1000
# Processed sample 733/1000
# Processed sample 734/1000
# Processed sample 735/1000
# Processed sample 736/1000
# Processed sample 737/1000
# Processed sample 738/1000
# Processed sample 739/1000
# Processed sample 740/1000
# Processed sample 741/1000
# Processed sample 742/1000
# Processed sample 743/1000
# Processed sample 744/1000
# Processed sample 745/1000
# Processed sample 746/1000
# Processed sample 747/1000
# Processed sample 748/1000
# Processed sample 749/1000
# Processed sample 750/1000
# Processed sample 751/1000
# Processed sample 752/1000
# Processed sample 753/1000
# Processed sample 754/1000
# Processed sample 755/1000
# Processed sample 756/1000
# Processed sample 757/1000
# Processed sample 758/1000
# Processed sample 759/1000
# Processed sample 760/1000
# Processed sample 761/1000
# Processed sample 762/1000
# Processed sample 763/1000
# Processed sample 764/1000
# Processed sample 765/1000
# Processed sample 766/1000
# Processed sample 767/1000
# Processed sample 768/1000
# Processed sample 769/1000
# Processed sample 770/1000
# Processed sample 771/1000
# Processed sample 772/1000
# Processed sample 773/1000
# Processed sample 774/1000
# Processed sample 775/1000
# Processed sample 776/1000
# Processed sample 777/1000
# Processed sample 778/1000
# Processed sample 779/1000
# Processed sample 780/1000
# Processed sample 781/1000
# Processed sample 782/1000
# Processed sample 783/1000
# Processed sample 784/1000
# Processed sample 785/1000
# Processed sample 786/1000
# Processed sample 787/1000
# Processed sample 788/1000
# Processed sample 789/1000
# Processed sample 790/1000
# Processed sample 791/1000
# Processed sample 792/1000
# Processed sample 793/1000
# Processed sample 794/1000
# Processed sample 795/1000
# Processed sample 796/1000
# Processed sample 797/1000
# Processed sample 798/1000
# Processed sample 799/1000
# Processed sample 800/1000
# Processed sample 801/1000
# Processed sample 802/1000
# Processed sample 803/1000
# Processed sample 804/1000
# Processed sample 805/1000
# Processed sample 806/1000
# Processed sample 807/1000
# Processed sample 808/1000
# Processed sample 809/1000
# Processed sample 810/1000
# Processed sample 811/1000
# Processed sample 812/1000
# Processed sample 813/1000
# Processed sample 814/1000
# Processed sample 815/1000
# Processed sample 816/1000
# Processed sample 817/1000
# Processed sample 818/1000
# Processed sample 819/1000
# Processed sample 820/1000
# Processed sample 821/1000
# Processed sample 822/1000
# Processed sample 823/1000
# Processed sample 824/1000
# Processed sample 825/1000
# Processed sample 826/1000
# Processed sample 827/1000
# Processed sample 828/1000
# Processed sample 829/1000
# Processed sample 830/1000
# Processed sample 831/1000
# Processed sample 832/1000
# Processed sample 833/1000
# Processed sample 834/1000
# Processed sample 835/1000
# Processed sample 836/1000
# Processed sample 837/1000
# Processed sample 838/1000
# Processed sample 839/1000
# Processed sample 840/1000
# Processed sample 841/1000
# Processed sample 842/1000
# Processed sample 843/1000
# Processed sample 844/1000
# Processed sample 845/1000
# Processed sample 846/1000
# Processed sample 847/1000
# Processed sample 848/1000
# Processed sample 849/1000
# Processed sample 850/1000
# Processed sample 851/1000
# Processed sample 852/1000
# Processed sample 853/1000
# Processed sample 854/1000
# Processed sample 855/1000
# Processed sample 856/1000
# Processed sample 857/1000
# Processed sample 858/1000
# Processed sample 859/1000
# Processed sample 860/1000
# Processed sample 861/1000
# Processed sample 862/1000
# Processed sample 863/1000
# Processed sample 864/1000
# Processed sample 865/1000
# Processed sample 866/1000
# Processed sample 867/1000
# Processed sample 868/1000
# Processed sample 869/1000
# Processed sample 870/1000
# Processed sample 871/1000
# Processed sample 872/1000
# Processed sample 873/1000
# Processed sample 874/1000
# Processed sample 875/1000
# Processed sample 876/1000
# Processed sample 877/1000
# Processed sample 878/1000
# Processed sample 879/1000
# Processed sample 880/1000
# Processed sample 881/1000
# Processed sample 882/1000
# Processed sample 883/1000
# Processed sample 884/1000
# Processed sample 885/1000
# Processed sample 886/1000
# Processed sample 887/1000
# Processed sample 888/1000
# Processed sample 889/1000
# Processed sample 890/1000
# Processed sample 891/1000
# Processed sample 892/1000
# Processed sample 893/1000
# Processed sample 894/1000
# Processed sample 895/1000
# Processed sample 896/1000
# Processed sample 897/1000
# Processed sample 898/1000
# Processed sample 899/1000
# Processed sample 900/1000
# Processed sample 901/1000
# Processed sample 902/1000
# Processed sample 903/1000
# Processed sample 904/1000
# Processed sample 905/1000
# Processed sample 906/1000
# Processed sample 907/1000
# Processed sample 908/1000
# Processed sample 909/1000
# Processed sample 910/1000
# Processed sample 911/1000
# Processed sample 912/1000
# Processed sample 913/1000
# Processed sample 914/1000
# Processed sample 915/1000
# Processed sample 916/1000
# Processed sample 917/1000
# Processed sample 918/1000
# Processed sample 919/1000
# Processed sample 920/1000
# Processed sample 921/1000
# Processed sample 922/1000
# Processed sample 923/1000
# Processed sample 924/1000
# Processed sample 925/1000
# Processed sample 926/1000
# Processed sample 927/1000
# Processed sample 928/1000
# Processed sample 929/1000
# Processed sample 930/1000
# Processed sample 931/1000
# Processed sample 932/1000
# Processed sample 933/1000
# Processed sample 934/1000
# Processed sample 935/1000
# Processed sample 936/1000
# Processed sample 937/1000
# Processed sample 938/1000
# Processed sample 939/1000
# Processed sample 940/1000
# Processed sample 941/1000
# Processed sample 942/1000
# Processed sample 943/1000
# Processed sample 944/1000
# Processed sample 945/1000
# Processed sample 946/1000
# Processed sample 947/1000
# Processed sample 948/1000
# Processed sample 949/1000
# Processed sample 950/1000
# Processed sample 951/1000
# Processed sample 952/1000
# Processed sample 953/1000
# Processed sample 954/1000
# Processed sample 955/1000
# Processed sample 956/1000
# Processed sample 957/1000
# Processed sample 958/1000
# Processed sample 959/1000
# Processed sample 960/1000
# Processed sample 961/1000
# Processed sample 962/1000
# Processed sample 963/1000
# Processed sample 964/1000
# Processed sample 965/1000
# Processed sample 966/1000
# Processed sample 967/1000
# Processed sample 968/1000
# Processed sample 969/1000
# Processed sample 970/1000
# Processed sample 971/1000
# Processed sample 972/1000
# Processed sample 973/1000
# Processed sample 974/1000
# Processed sample 975/1000
# Processed sample 976/1000
# Processed sample 977/1000
# Processed sample 978/1000
# Processed sample 979/1000
# Processed sample 980/1000
# Processed sample 981/1000
# Processed sample 982/1000
# Processed sample 983/1000
# Processed sample 984/1000
# Processed sample 985/1000
# Processed sample 986/1000
# Processed sample 987/1000
# Processed sample 988/1000
# Processed sample 989/1000
# Processed sample 990/1000
# Processed sample 991/1000
# Processed sample 992/1000
# Processed sample 993/1000
# Processed sample 994/1000
# Processed sample 995/1000
# Processed sample 996/1000
# Processed sample 997/1000
# Processed sample 998/1000
# Processed sample 999/1000
# Processed sample 1000/1000
# All samples processed!

# %%
for i in range(len(all_pred)):
    print("pred:", all_pred[i])
    print("ans:", all_ans[i])
# Out:
# pred: Model: Segment-MRI
# Prompt: What is the position of the instruments in a typical MRI scan?
# ans: Model: Surgical-VQA
# Prompt: what is the position of the instruments?
# pred: Model: Segment-MRI
# Prompt: Identify the instrument quantities used in MRI imaging.
# ans: Model: Surgical-VQA
# Prompt: which instrument quantities is being used?
# pred: Model: Segment-MRI
# Prompt: Analyze the instruments in this phase.
# ans: Model: Surgical-VQA
# Prompt: analyze the instruments in this phase.
# pred: Model: Segment-VQA
# Prompt: Identify the instrument quantities.
# ans: Model: Surgical-VQA
# Prompt: can you identify the instrument quantities?
# pred: Model: Segment-MRI
# Prompt: Analyze the operation notes in this phase.
# ans: Model: Surgical-VQA
# Prompt: analyze the operation notes in this phase.
# pred: Model: Segment-MRI
# Prompt: Identify the phases of the human body from MRI images.
# ans: Model: Surgical-VQA
# Prompt: can you identify the phases?
# pred: Model: Segment-MRI
# Prompt: What is the operation note being used?
# ans: Model: Surgical-VQA
# Prompt: which operation notes is being used?
# pred: Model: Segment-MRI
# Prompt: What operation note is being used?
# ans: Model: Surgical-VQA
# Prompt: which operation notes is being used?
# pred: Model: Segment-Video
# Prompt: Analyze the steps taken in a video and make an observation about them.
# ans: Model: Surgical-VQA
# Prompt: what observation can be made about the steps?
# pred: Model: Segment-MRI
# Prompt: Identify instrument positions in the surgical scene from the MRI images.
# ans: Model: Surgical-VQA
# Prompt: locate the instrument positions in the surgical scene.
# pred: Model: Segment-MRI
# Prompt: Describe the instruments being used.
# ans: Model: Surgical-VQA
# Prompt: describe the instruments being used.
# pred: Model: Segment-MRI
# Prompt: Identify the instruments used in the MRI scan.
# ans: Model: Surgical-VQA
# Prompt: which instruments is being used?
# pred: Model: Segment-MRI
# Prompt: The position of the phases is a common reference point in MRI sequences, typically referring to the different stages of a pulse sequence, such as the repetition time (TR), echo time (TE), and the number of excitations (NEX).
# ans: Model: Surgical-VQA
# Prompt: what is the position of the phases?
# pred: Model: Segment-MRI
# Prompt: The position of the operation notes is in the MRI report.
# ans: Model: Surgical-VQA
# Prompt: what is the position of the operation notes?
# pred: Model: Segment-MRI
# Prompt: What is the position of the steps?
# ans: Model: Surgical-VQA
# Prompt: what is the position of the steps?
# pred: Model: Detect-Video
# Prompt: Identify the instruments in the surgical scene.
# ans: Model: Surgical-VQA
# Prompt: locate the instruments in the surgical scene.
# pred: Model: Segment-Video
# Prompt: What instrument quantities are present in the frame?
# ans: Model: Surgical-VQA
# Prompt: what instrument quantities is present in the frame?
# pred: Model: Segment-MRI
# Prompt: What are the phases present in the MRI frame?
# ans: Model: Surgical-VQA
# Prompt: what phases is present in the frame?
# pred: Model: Segment-MRI
# Prompt: Describe the steps present in the MRI frame.
# ans: Model: Surgical-VQA
# Prompt: what steps is present in the frame?
# pred: Model: Segment-MRI
# Prompt: Analyze the phases in this phase.
# ans: Model: Surgical-VQA
# Prompt: analyze the phases in this phase.
# pred: Model: Segment-Video
# Prompt: Find and highlight all instrument quantities in the surgical scene.
# ans: Model: Surgical-VQA
# Prompt: locate the instrument quantities in the surgical scene.
# pred: Model: Segment-MRI
# Prompt: Identify steps present in the MRI frame.
# ans: Model: Surgical-VQA
# Prompt: what steps is present in the frame?
# pred: Model: Detect-Video
# Prompt: Describe the current steps in a medical procedure.
# ans: Model: Surgical-VQA
# Prompt: what is the current steps?
# pred: Model: Segment-Video
# Prompt: Identify and locate all instruments in the surgical scene.
# ans: Model: Surgical-VQA
# Prompt: locate the instruments in the surgical scene.
# pred: Model: Segment-MRI
# Prompt: What are the current phases?
# ans: Model: Surgical-VQA
# Prompt: what is the current phases?
# pred: Model: Segment-MRI
# Prompt: Identify steps in a surgical scene from MRI images.
# ans: Model: Surgical-VQA
# Prompt: locate the steps in the surgical scene.
# pred: Model: Segment-MRI
# Prompt: Identify the phases of the MRI images.
# ans: Model: Surgical-VQA
# Prompt: can you identify the phases?
# pred: Model: Segment-MRI
# Prompt: Describe the phases being used.
# ans: Model: Surgical-VQA
# Prompt: describe the phases being used.
# pred: Model: Segment-Video
# Prompt: What are the typical instrument positions in a surgical setting?
# ans: Model: Surgical-VQA
# Prompt: what is the position of the instrument positions?
# pred: Model: Segment-Video
# Prompt: Identify and locate instruments in a surgical scene.
# ans: Model: Surgical-VQA
# Prompt: locate the instruments in the surgical scene.
# pred: Model: Segment-MRI
# Prompt: What can be observed about the instruments in an MRI environment?
# ans: Model: Surgical-VQA
# Prompt: what observation can be made about the instruments?
# pred: Model: Segment-Video
# Prompt: What instrument quantities are being used?
# ans: Model: Surgical-VQA
# Prompt: which instrument quantities is being used?
# pred: Model: Segment-MRI
# Prompt: What are the current instruments?
# ans: Model: Surgical-VQA
# Prompt: what is the current instruments?
# pred: Model: Segment-Video
# Prompt: Identify instruments present in the frame.
# ans: Model: Surgical-VQA
# Prompt: what instruments is present in the frame?
# pred: Model: Segment-MRI
# Prompt: Identify the instrument quantities.
# ans: Model: Surgical-VQA
# Prompt: can you identify the instrument quantities?
# pred: Model: Segment-MRI
# Prompt: Describe the operation notes being used.
# ans: Model: Surgical-VQA
# Prompt: describe the operation notes being used.
# pred: Model: Segment-MRI
# Prompt: Describe the steps being used.
# ans: Model: Surgical-VQA
# Prompt: which steps is being used?
# pred: Model: Segment-MRI
# Prompt: Describe the instrument positions.
# ans: Model: Surgical-VQA
# Prompt: describe the instrument positions being used.
# pred: Model: Segment-MRI
# Prompt: Identify instrument positions in MRI images.
# ans: Model: Surgical-VQA
# Prompt: can you identify the instrument positions?
# pred: Model: Segment-MRI
# Prompt: What observations can be made about the instruments?
# ans: Model: Surgical-VQA
# Prompt: what observation can be made about the instruments?
# pred: Model: Segment-MRI
# Prompt: Describe the steps used in the process of segmenting an MRI image.
# ans: Model: Surgical-VQA
# Prompt: which steps is being used?
# pred: Model: Segment-MRI
# Prompt: What instrument positions are being used?
# ans: Model: Surgical-VQA
# Prompt: which instrument positions is being used?
# pred: Model: Detect-Video
# Prompt: Identify instrument quantities in the surgical scene.
# ans: Model: Surgical-VQA
# Prompt: locate the instrument quantities in the surgical scene.
# pred: Model: Segment-MRI
# Prompt: Explain the role of phases in the segmentation process.
# ans: Model: Surgical-VQA
# Prompt: explain the role of the phases in this step.
# pred: Model: Segment-MRI
# Prompt: Identify the phases in the surgical scene.
# ans: Model: Surgical-VQA
# Prompt: locate the phases in the surgical scene.
# pred: Model: Segment-MRI
# Prompt: Describe the instruments being used in a medical context.
# ans: Model: Surgical-VQA
# Prompt: describe the instruments being used.
# pred: Model: Segment-MRI
# Prompt: Explain the role of the instruments in the MRI segmentation process.
# ans: Model: Surgical-VQA
# Prompt: explain the role of the instruments in this step.
# pred: Model: Segment-Video
# Prompt: What observation can be made about the instrument quantities?
# ans: Model: Surgical-VQA
# Prompt: what observation can be made about the instrument quantities?
# pred: Model: Segment-MRI
# Prompt: Which phases are being used?
# ans: Model: Surgical-VQA
# Prompt: which phases is being used?
# pred: Model: Segment-MRI
# Prompt: Locate the instrument positions in the surgical scene.
# ans: Model: Surgical-VQA
# Prompt: locate the instrument positions in the surgical scene.
# pred: Model: Segment-Video
# Prompt: Identify instruments in a surgical scene.
# ans: Model: Surgical-VQA
# Prompt: locate the instruments in the surgical scene.
# pred: Model: Segment-Video
# Prompt: What are the current instruments?
# ans: Model: Surgical-VQA
# Prompt: what is the current instruments?
# pred: Model: Segment-MRI
# Prompt: Analyze the instrument positions in this phase.
# ans: Model: Surgical-VQA
# Prompt: analyze the instrument positions in this phase.
# pred: Model: Segment-MRI
# Prompt: Analyze the instruments in this phase.
# ans: Model: Surgical-VQA
# Prompt: analyze the instruments in this phase.
# pred: Model: Segment-MRI
# Prompt: What are the general characteristics or features of the different phases that can be observed?
# ans: Model: Surgical-VQA
# Prompt: what observation can be made about the phases?
# pred: Model: Segment-Video
# Prompt: The position of the instrument positions.
# ans: Model: Surgical-VQA
# Prompt: what is the position of the instrument positions?
# pred: Model: Segment-Video
# Prompt: What instruments are present in the frame?
# ans: Model: Surgical-VQA
# Prompt: what instruments is present in the frame?
# pred: Model: Segment-MRI
# Prompt: Describe the operation notes being used.
# ans: Model: Surgical-VQA
# Prompt: describe the operation notes being used.
# pred: Model: Segment-Video
# Prompt: What can be observed about the steps?
# ans: Model: Surgical-VQA
# Prompt: what observation can be made about the steps?
# pred: Model: Segment-MRI
# Prompt: Analyze the instruments in this phase.
# ans: Model: Surgical-VQA
# Prompt: analyze the instruments in this phase.
# pred: Model: Segment-Video
# Prompt: What can be observed about the instrument quantities?
# ans: Model: Surgical-VQA
# Prompt: what observation can be made about the instrument quantities?
# pred: Model: Segment-MRI
# Prompt: Describe the current phases in the context of medical imaging.
# ans: Model: Surgical-VQA
# Prompt: what is the current phases?
# pred: Model: Segment-Video
# Prompt: What instrument positions are being used?
# ans: Model: Surgical-VQA
# Prompt: which instrument positions is being used?
# pred: Model: Segment-MRI
# Prompt: What is the position of the phases?
# ans: Model: Surgical-VQA
# Prompt: what is the position of the phases?
# pred: Model: Segment-MRI
# Prompt: Identify the operation notes.
# ans: Model: Surgical-VQA
# Prompt: can you identify the operation notes?
# pred: Model: Segment-MRI
# Prompt: What is the current operation notes?
# ans: Model: Surgical-VQA
# Prompt: what is the current operation notes?
# pred: Model: Segment-MRI
# Prompt: What are the phases being used?
# ans: Model: Surgical-VQA
# Prompt: which phases is being used?
# pred: Model: Segment-Video
# Prompt: What observation can be made about the instrument positions?
# ans: Model: Surgical-VQA
# Prompt: what observation can be made about the instrument positions?
# pred: Model: Overlaying
# Prompt: Describe the steps being used.
# ans: Model: Surgical-VQA
# Prompt: describe the steps being used.
# pred: Model: Segment-MRI
# Prompt: What are the positions of the instruments in the image?
# ans: Model: Surgical-VQA
# Prompt: what is the position of the instruments?
# pred: Model: Segment-Video
# Prompt: What is the position of the instrument positions?
# ans: Model: Surgical-VQA
# Prompt: what is the position of the instrument positions?
# pred: Model: Detect-Video
# Prompt: Analyze the steps in the video analysis phase.
# ans: Model: Surgical-VQA
# Prompt: analyze the steps in this phase.
# pred: Model: Segment-MRI
# Prompt: What phases are present in the MRI frame?
# ans: Model: Surgical-VQA
# Prompt: what phases is present in the frame?
# pred: Model: Detect-Video
# Prompt: Identify instruments in the surgical scene.
# ans: Model: Surgical-VQA
# Prompt: locate the instruments in the surgical scene.
# pred: Model: Segment-MRI
# Prompt: Explain the role of steps in the MRI segmentation process.
# ans: Model: Surgical-VQA
# Prompt: explain the role of the steps in this step.
# pred: Model: Segment-MRI
# Prompt: Identify steps in the surgical scene from a MRI image.
# ans: Model: Surgical-VQA
# Prompt: locate the steps in the surgical scene.
# pred: Model: Segment-MRI
# Prompt: Describe the instruments being used.
# ans: Model: Surgical-VQA
# Prompt: describe the instruments being used.
# pred: Model: Segment-MRI
# Prompt: Identify the instruments in the given medical image.
# ans: Model: Surgical-VQA
# Prompt: which instruments is being used?
# pred: Model: Segment-MRI
# Prompt: Analyze the phases in the MRI image.
# ans: Model: Surgical-VQA
# Prompt: analyze the phases in this phase.
# pred: Model: Segment-MRI
# Prompt: Explain the role of instruments in a medical imaging step, specifically in MRI segment.
# ans: Model: Surgical-VQA
# Prompt: explain the role of the instruments in this step.
# pred: Model: Segment-Video
# Prompt: Analyze the instrument quantities in this phase.
# ans: Model: Surgical-VQA
# Prompt: analyze the instrument quantities in this phase.
# pred: Model: Segment-Video
# Prompt: Analyze the operation notes for any notable patterns or abnormalities.
# ans: Model: Surgical-VQA
# Prompt: what observation can be made about the operation notes?
# pred: Model: Detect-Video
# Prompt: Locate the operation notes in the surgical scene.
# ans: Model: Surgical-VQA
# Prompt: locate the operation notes in the surgical scene.
# pred: Model: Segment-MRI
# Prompt: Describe the instrument quantities being used.
# ans: Model: Surgical-VQA
# Prompt: describe the instrument quantities being used.
# pred: Model: Detect-Video
# Prompt: Locate the phases in the surgical scene.
# ans: Model: Surgical-VQA
# Prompt: locate the phases in the surgical scene.
# pred: Model: Segment-Video
# Prompt: Get current instrument quantities.
# ans: Model: Surgical-VQA
# Prompt: what is the current instrument quantities?
# pred: Model: Segment-MRI
# Prompt: Explain the role of instruments in medical imaging segmentation tasks.
# ans: Model: Surgical-VQA
# Prompt: explain the role of the instruments in this step.
# pred: Model: Segment-MRI
# Prompt: Find the operation notes in the surgical scene.
# ans: Model: Surgical-VQA
# Prompt: locate the operation notes in the surgical scene.
# pred: Model: Overlaying
# Prompt: Analyze the steps in the phase.
# ans: Model: Surgical-VQA
# Prompt: analyze the steps in this phase.
# pred: Model: Segment-MRI
# Prompt: Analyze the instrument positions in this phase.
# ans: Model: Surgical-VQA
# Prompt: analyze the instrument positions in this phase.
# pred: Model: Segment-MRI
# Prompt: Describe instrument positions being used.
# ans: Model: Surgical-VQA
# Prompt: describe the instrument positions being used.
# pred: Model: Segment-MRI
# Prompt: The position of the phases in the context of medical imaging, particularly in MRI, refers to the distinct stages or states of the imaging process, such as acquisition, reconstruction, and analysis.
# ans: Model: Surgical-VQA
# Prompt: what is the position of the phases?
# pred: Model: Segment-MRI
# Prompt: Analyze the phases in this phase.
# ans: Model: Surgical-VQA
# Prompt: analyze the phases in this phase.
# pred: Model: Segment-Video
# Prompt: The position of the instrument is defined by the instrument's coordinates in the 3D space, typically measured in millimeters, and is usually represented as a 3D vector (x, y, z) or a 6-DOF (6 degrees of freedom) coordinate system that includes roll, pitch, yaw, and translation in x, y, and z axes.
# ans: Model: Surgical-VQA
# Prompt: what is the position of the instrument positions?
# pred: Model: Detect-Video
# Prompt: Analyze the steps in this phase.
# ans: Model: Surgical-VQA
# Prompt: analyze the steps in this phase.
# pred: Model: Segment-Video
# Prompt: Get current instrument quantities.
# ans: Model: Surgical-VQA
# Prompt: what is the current instrument quantities?
# pred: Model: Segment-MRI
# Prompt: Identify steps present in the MRI frame.
# ans: Model: Surgical-VQA
# Prompt: what steps is present in the frame?
# pred: Model: Segment-MRI
# Prompt: Identify phases in the surgical scene.
# ans: Model: Surgical-VQA
# Prompt: locate the phases in the surgical scene.
# pred: Model: Segment-MRI
# Prompt: Summarize the current operation notes.
# ans: Model: Surgical-VQA
# Prompt: what is the current operation notes?
# pred: Model: Segment-MRI
# Prompt: Identify instruments in the surgical scene.
# ans: Model: Surgical-VQA
# Prompt: locate the instruments in the surgical scene.
# pred: Model: Segment-MRI
# Prompt: Describe the position of instrument positions in medical imaging.
# ans: Model: Surgical-VQA
# Prompt: what is the position of the instrument positions?
# pred: Model: Detect-Video
# Prompt: Locate the operation notes in the surgical scene.
# ans: Model: Surgical-VQA
# Prompt: locate the operation notes in the surgical scene.
# pred: Model: Segment-Video
# Prompt: Identify instrument positions
# ans: Model: Surgical-VQA
# Prompt: can you identify the instrument positions?
# pred: Model: Segment-MRI
# Prompt: Describe the steps used in a medical imaging procedure.
# ans: Model: Surgical-VQA
# Prompt: which steps is being used?
# pred: Model: Segment-MRI
# Prompt: Identify instrument positions
# ans: Model: Surgical-VQA
# Prompt: can you identify the instrument positions?
# pred: Model: Segment-MRI
# Prompt: Describe the current steps in a medical MRI imaging process.
# ans: Model: Surgical-VQA
# Prompt: what is the current steps?
# pred: Model: Segment-Video
# Prompt: Identify the instrument quantities in the given video.
# ans: Model: Surgical-VQA
# Prompt: which instrument quantities is being used?
# pred: Model: Segment-Video
# Prompt: Analyze the instruments in this phase.
# ans: Model: Surgical-VQA
# Prompt: analyze the instruments in this phase.
# pred: Model: Segment-MRI
# Prompt: Identify phases present in the MRI frame.
# ans: Model: Surgical-VQA
# Prompt: what phases is present in the frame?
# pred: Model: Segment-MRI
# Prompt: Explain the role of instrument quantities in a medical MRI imaging process.
# ans: Model: Surgical-VQA
# Prompt: explain the role of the instrument quantities in this step.
# pred: Model: Segment-Video
# Prompt: What are the current instrument quantities?
# ans: Model: Surgical-VQA
# Prompt: what is the current instrument quantities?
# pred: Model: Segment-MRI
# Prompt: Describe the phases being used.
# ans: Model: Surgical-VQA
# Prompt: describe the phases being used.
# pred: Model: Segment-MRI
# Prompt: Analyze the instrument positions in the current phase.
# ans: Model: Surgical-VQA
# Prompt: analyze the instrument positions in this phase.
# pred: Model: Segment-MRI
# Prompt: Identify the phases.
# ans: Model: Surgical-VQA
# Prompt: can you identify the phases?
# pred: Model: Segment-Video
# Prompt: Get the current instrument positions.
# ans: Model: Surgical-VQA
# Prompt: what is the current instrument positions?
# pred: Model: Segment-MRI
# Prompt: What observations can be made about the instrument quantities?
# ans: Model: Surgical-VQA
# Prompt: what observation can be made about the instrument quantities?
# pred: Model: Segment-MRI
# Prompt: Describe the current steps.
# ans: Model: Surgical-VQA
# Prompt: what is the current steps?
# pred: Model: Segment-MRI
# Prompt: What are the current instruments?
# ans: Model: Surgical-VQA
# Prompt: what is the current instruments?
# pred: Model: Segment-MRI
# Prompt: Find instrument quantities in the MRI images of a surgical scene.
# ans: Model: Surgical-VQA
# Prompt: locate the instrument quantities in the surgical scene.
# pred: Model: Segment-MRI
# Prompt: What are the current instruments?
# ans: Model: Surgical-VQA
# Prompt: what is the current instruments?
# pred: Model: Segment-MRI
# Prompt: Identify the steps in a process.
# ans: Model: Surgical-VQA
# Prompt: can you identify the steps?
# pred: Model: Segment-Video
# Prompt: Analyze the instrument positions in this phase.
# ans: Model: Surgical-VQA
# Prompt: analyze the instrument positions in this phase.
# pred: Model: Segment-MRI
# Prompt: Locate the instrument quantities in the surgical scene.
# ans: Model: Surgical-VQA
# Prompt: locate the instrument quantities in the surgical scene.
# pred: Model: Segment-MRI
# Prompt: Identify the instrument positions
# ans: Model: Surgical-VQA
# Prompt: can you identify the instrument positions?
# pred: Model: Segment-MRI
# Prompt: Display the current operation notes.
# ans: Model: Surgical-VQA
# Prompt: what is the current operation notes?
# pred: Model: Segment-MRI
# Prompt: What operation notes are present in the MRI frame?
# ans: Model: Surgical-VQA
# Prompt: what operation notes is present in the frame?
# pred: Model: Detect-Video
# Prompt: Identify the steps in the surgical scene.
# ans: Model: Surgical-VQA
# Prompt: locate the steps in the surgical scene.
# pred: Model: Detect-Video
# Prompt: Analyze the phases in this phase.
# ans: Model: Surgical-VQA
# Prompt: analyze the phases in this phase.
# pred: Model: Segment-MRI
# Prompt: Analyze the instrument positions in this phase.
# ans: Model: Surgical-VQA
# Prompt: analyze the instrument positions in this phase.
# pred: Model: Segment-Video
# Prompt: What are the current instrument quantities?
# ans: Model: Surgical-VQA
# Prompt: what is the current instrument quantities?
# pred: Model: Segment-MRI
# Prompt: Identify the phases present in the MRI frame.
# ans: Model: Surgical-VQA
# Prompt: what phases is present in the frame?
# pred: Model: Segment-MRI
# Prompt: What are the current phases?
# ans: Model: Surgical-VQA
# Prompt: what is the current phases?
# pred: Model: Segment-MRI
# Prompt: Describe the instrument quantities being used.
# ans: Model: Surgical-VQA
# Prompt: describe the instrument quantities being used.
# pred: Model: Segment-Video
# Prompt: Describe the instrument positions being used.
# ans: Model: Surgical-VQA
# Prompt: describe the instrument positions being used.
# pred: Model: Segment-Video
# Prompt: Analyze the instruments in this phase.
# ans: Model: Surgical-VQA
# Prompt: analyze the instruments in this phase.
# pred: Model: Segment-Video
# Prompt: What observations can be made about the instrument quantities?
# ans: Model: Surgical-VQA
# Prompt: what observation can be made about the instrument quantities?
# pred: Model: Segment-MRI
# Prompt: Identify the phases.
# ans: Model: Surgical-VQA
# Prompt: can you identify the phases?
# pred: Model: Segment-MRI
# Prompt: Analyze the phases in this phase.
# ans: Model: Surgical-VQA
# Prompt: analyze the phases in this phase.
# pred: Model: Segment-MRI
# Prompt: What is the position of the instrument quantities in MRI segmentation?
# ans: Model: Surgical-VQA
# Prompt: what is the position of the instrument quantities?
# pred: Model: Segment-Video
# Prompt: What are the current instruments?
# ans: Model: Surgical-VQA
# Prompt: what is the current instruments?
# pred: Model: Segment-MRI
# Prompt: Identify the instrument being used.
# ans: Model: Surgical-VQA
# Prompt: which instruments is being used?
# pred: Model: Surgical-VQA
# Prompt: Identify the operation notes.
# ans: Model: Surgical-VQA
# Prompt: can you identify the operation notes?
# pred: Model: Segment-Video
# Prompt: What are the current instruments?
# ans: Model: Surgical-VQA
# Prompt: what is the current instruments?
# pred: Model: Segment-MRI
# Prompt: Identify the operation notes.
# ans: Model: Surgical-VQA
# Prompt: can you identify the operation notes?
# pred: Model: Segment-MRI
# Prompt: Analyze the instrument positions in this phase.
# ans: Model: Surgical-VQA
# Prompt: analyze the instrument positions in this phase.
# pred: Model: Surgical-VQA
# Prompt: Identify the operation notes.
# ans: Model: Surgical-VQA
# Prompt: can you identify the operation notes?
# pred: Model: Segment-Video
# Prompt: What are the current instrument quantities?
# ans: Model: Surgical-VQA
# Prompt: what is the current instrument quantities?
# pred: Model: Segment-MRI
# Prompt: Describe the instrument quantities being used.
# ans: Model: Surgical-VQA
# Prompt: describe the instrument quantities being used.
# pred: Model: Segment-MRI
# Prompt: Explain the role of phases in the MRI segmentation process.
# ans: Model: Surgical-VQA
# Prompt: explain the role of the phases in this step.
# pred: Model: Segment-Video
# Prompt: What are the current instruments?
# ans: Model: Surgical-VQA
# Prompt: what is the current instruments?
# pred: Model: Segment-MRI
# Prompt: Analyze the instrument quantities in this phase.
# ans: Model: Surgical-VQA
# Prompt: analyze the instrument quantities in this phase.
# pred: Model: Segment-MRI
# Prompt: Analyze the instruments in this phase.
# ans: Model: Surgical-VQA
# Prompt: analyze the instruments in this phase.
# pred: Model: Detect-Video
# Prompt: Locate the instrument quantities in the surgical scene.
# ans: Model: Surgical-VQA
# Prompt: locate the instrument quantities in the surgical scene.
# pred: Model: Segment-MRI
# Prompt: What are the current steps?
# ans: Model: Surgical-VQA
# Prompt: what is the current steps?
# pred: Model: Segment-MRI
# Prompt: The operation notes are located in the patient's medical record, typically found in the radiology section, and are used to document the details of the procedure, including the type of surgery, any complications, and the patient's response to treatment.
# ans: Model: Surgical-VQA
# Prompt: what is the position of the operation notes?
# pred: Model: Detect-Video
# Prompt: Locate the instruments in the surgical scene.
# ans: Model: Surgical-VQA
# Prompt: locate the instruments in the surgical scene.
# pred: Model: Segment-MRI
# Prompt: What are the current instrument quantities?
# ans: Model: Surgical-VQA
# Prompt: what is the current instrument quantities?
# pred: Model: Segment-Video
# Prompt: Locate instrument quantities in the surgical scene.
# ans: Model: Surgical-VQA
# Prompt: locate the instrument quantities in the surgical scene.
# pred: Model: Segment-Video
# Prompt: Identify the instrument quantities in the surgical scene.
# ans: Model: Surgical-VQA
# Prompt: locate the instrument quantities in the surgical scene.
# pred: Model: Segment-MRI
# Prompt: Describe the phases of a typical MRI scan.
# ans: Model: Surgical-VQA
# Prompt: what observation can be made about the phases?
# pred: Model: Segment-MRI
# Prompt: The position of the operation notes is in the MRI segment.
# ans: Model: Surgical-VQA
# Prompt: what is the position of the operation notes?
# pred: Model: Surgical-VQA
# Prompt: Analyze the operation notes in this phase.
# ans: Model: Surgical-VQA
# Prompt: analyze the operation notes in this phase.
# pred: Model: Segment-Video
# Prompt: What observations can be made about the instrument positions?
# ans: Model: Surgical-VQA
# Prompt: what observation can be made about the instrument positions?
# pred: Model: Segment-MRI
# Prompt: Describe the current steps.
# ans: Model: Surgical-VQA
# Prompt: what is the current steps?
# pred: Model: Overlaying
# Prompt: Describe the steps being used.
# ans: Model: Surgical-VQA
# Prompt: describe the steps being used.
# pred: Model: Detect-Video
# Prompt: Identify the instruments in the surgical scene.
# ans: Model: Surgical-VQA
# Prompt: locate the instruments in the surgical scene.
# pred: Model: Segment-MRI
# Prompt: What are the positions of the instruments in the MRI image?
# ans: Model: Surgical-VQA
# Prompt: what is the position of the instruments?
# pred: Model: Segment-MRI
# Prompt: What is the position of the operation notes?
# ans: Model: Surgical-VQA
# Prompt: what is the position of the operation notes?
# pred: Model: Segment-Video
# Prompt: What observations can be made about the phases?
# ans: Model: Surgical-VQA
# Prompt: what observation can be made about the phases?
# pred: Model: Segment-MRI
# Prompt: What observations can be made about the instruments?
# ans: Model: Surgical-VQA
# Prompt: what observation can be made about the instruments?
# pred: Model: Segment-MRI
# Prompt: What observation can be made about the steps?
# ans: Model: Surgical-VQA
# Prompt: what observation can be made about the steps?
# pred: Model: Segment-MRI
# Prompt: Describe the steps being used.
# ans: Model: Surgical-VQA
# Prompt: describe the steps being used.
# pred: Model: Segment-Video
# Prompt: What are the instrument positions?
# ans: Model: Surgical-VQA
# Prompt: what is the position of the instrument positions?
# pred: Model: Segment-Video
# Prompt: What observations can be made about the instrument quantities?
# ans: Model: Surgical-VQA
# Prompt: what observation can be made about the instrument quantities?
# pred: Model: Segment-Video
# Prompt: Describe the instrument positions being used.
# ans: Model: Surgical-VQA
# Prompt: describe the instrument positions being used.
# pred: Model: Segment-Video
# Prompt: What is the position of the instrument quantities?
# ans: Model: Surgical-VQA
# Prompt: what is the position of the instrument quantities?
# pred: Model: Segment-MRI
# Prompt: What operation note is being used?
# ans: Model: Surgical-VQA
# Prompt: which operation notes is being used?
# pred: Model: Segment-MRI
# Prompt: Analyze the phases in this phase.
# ans: Model: Surgical-VQA
# Prompt: analyze the phases in this phase.
# pred: Model: Segment-MRI
# Prompt: Identify the phases.
# ans: Model: Surgical-VQA
# Prompt: can you identify the phases?
# pred: Model: Segment-Video
# Prompt: What are the current instrument quantities?
# ans: Model: Surgical-VQA
# Prompt: what is the current instrument quantities?
# pred: Model: Segment-MRI
# Prompt: Explain the role of phases in the segmentation process of MRI images.
# ans: Model: Surgical-VQA
# Prompt: explain the role of the phases in this step.
# pred: Model: Segment-MRI
# Prompt: Identify the operation notes.
# ans: Model: Surgical-VQA
# Prompt: can you identify the operation notes?
# pred: Model: Segment-Video
# Prompt: What is the position of the operation notes?
# ans: Model: Surgical-VQA
# Prompt: what is the position of the operation notes?
# pred: Model: Segment-MRI
# Prompt: Identify the steps in the surgical scene from a given MRI image.
# ans: Model: Surgical-VQA
# Prompt: locate the steps in the surgical scene.
# pred: Model: Segment-Video
# Prompt: Describe the instruments being used.
# ans: Model: Surgical-VQA
# Prompt: describe the instruments being used.
# pred: Model: Segment-MRI
# Prompt: Describe the steps present in the MRI frame.
# ans: Model: Surgical-VQA
# Prompt: what steps is present in the frame?
# pred: Model: Overlaying
# Prompt: Analyze the steps in the overlaying phase.
# ans: Model: Surgical-VQA
# Prompt: analyze the steps in this phase.
# pred: Model: Segment-MRI
# Prompt: What type of operation notes is being used?
# ans: Model: Surgical-VQA
# Prompt: which operation notes is being used?
# pred: Model: Segment-Video
# Prompt: What observations can be made about the instrument positions?
# ans: Model: Surgical-VQA
# Prompt: what observation can be made about the instrument positions?
# pred: Model: Segment-MRI
# Prompt: What instrument quantities are used?
# ans: Model: Surgical-VQA
# Prompt: which instrument quantities is being used?
# pred: Model: Segment-MRI
# Prompt: Explain the role of the steps in this step.
# ans: Model: Surgical-VQA
# Prompt: explain the role of the steps in this step.
# pred: Model: Segment-MRI
# Prompt: Locate the operation notes in the surgical scene.
# ans: Model: Surgical-VQA
# Prompt: locate the operation notes in the surgical scene.
# pred: Model: Segment-Video
# Prompt: What observations can be made about the instruments?
# ans: Model: Surgical-VQA
# Prompt: what observation can be made about the instruments?
# pred: Model: Segment-MRI
# Prompt: Analyze the phases in this phase.
# ans: Model: Surgical-VQA
# Prompt: analyze the phases in this phase.
# pred: Model: Segment-Video
# Prompt: What operation notes are present in the frame?
# ans: Model: Surgical-VQA
# Prompt: what operation notes is present in the frame?
# pred: Model: Segment-MRI
# Prompt: Describe the instruments being used in a medical MRI scan.
# ans: Model: Surgical-VQA
# Prompt: describe the instruments being used.
# pred: Model: Segment-MRI
# Prompt: Describe the phases used in MRI imaging.
# ans: Model: Surgical-VQA
# Prompt: describe the phases being used.
# pred: Model: Segment-Video
# Prompt: What instrument positions are present in the frame?
# ans: Model: Surgical-VQA
# Prompt: what instrument positions is present in the frame?
# pred: Model: Segment-Video
# Prompt: What instrument quantities are used?
# ans: Model: Surgical-VQA
# Prompt: which instrument quantities is being used?
# pred: Model: Segment-Video
# Prompt: What is the position of the instrument quantities?
# ans: Model: Surgical-VQA
# Prompt: what is the position of the instrument quantities?
# pred: Model: Segment-MRI
# Prompt: Identify the instruments.
# ans: Model: Surgical-VQA
# Prompt: can you identify the instruments?
# pred: Model: Segment-MRI
# Prompt: Identify steps in the surgical scene from an MRI image.
# ans: Model: Surgical-VQA
# Prompt: locate the steps in the surgical scene.
# pred: Model: Segment-MRI
# Prompt: Identify the phases in the surgical scene from MRI images.
# ans: Model: Surgical-VQA
# Prompt: locate the phases in the surgical scene.
# pred: Model: Segment-Video
# Prompt: What are the current instrument quantities?
# ans: Model: Surgical-VQA
# Prompt: what is the current instrument quantities?
# pred: Model: Segment-MRI
# Prompt: Describe the phases being used.
# ans: Model: Surgical-VQA
# Prompt: describe the phases being used.
# pred: Model: Segment-MRI
# Prompt: What observation can be made about the instrument quantities?
# ans: Model: Surgical-VQA
# Prompt: what observation can be made about the instrument quantities?
# pred: Model: Surgical-VQA
# Prompt: Explain the role of operation notes in a surgical operation.
# ans: Model: Surgical-VQA
# Prompt: explain the role of the operation notes in this step.
# pred: Model: Segment-Video
# Prompt: Describe the instrument quantities being used.
# ans: Model: Surgical-VQA
# Prompt: describe the instrument quantities being used.
# pred: Model: Segment-MRI
# Prompt: What are the general characteristics or observations that can be made about the phases of a medical imaging study?
# ans: Model: Surgical-VQA
# Prompt: what observation can be made about the phases?
# pred: Model: Segment-MRI
# Prompt: What are the phases being used?
# ans: Model: Surgical-VQA
# Prompt: which phases is being used?
# pred: Model: Segment-MRI
# Prompt: Explain the role of the phases in a MRI segmentation process.
# ans: Model: Surgical-VQA
# Prompt: explain the role of the phases in this step.
# pred: Model: Segment-MRI
# Prompt: Identify the phases present in the given MRI frame.
# ans: Model: Surgical-VQA
# Prompt: what phases is present in the frame?
# pred: Model: Segment-MRI
# Prompt: The current operation notes are not provided, but I can describe a general template for operation notes.
# ans: Model: Surgical-VQA
# Prompt: what is the current operation notes?
# pred: Model: Segment-MRI
# Prompt: What steps are being used?
# ans: Model: Surgical-VQA
# Prompt: which steps is being used?
# pred: Model: Segment-MRI
# Prompt: Analyze the operation notes in this phase.
# ans: Model: Surgical-VQA
# Prompt: analyze the operation notes in this phase.
# pred: Model: Segment-MRI
# Prompt: Analyze the instrument quantities in this phase.
# ans: Model: Surgical-VQA
# Prompt: analyze the instrument quantities in this phase.
# pred: Model: Detect-Video
# Prompt: Analyze the phases in this phase.
# ans: Model: Surgical-VQA
# Prompt: analyze the phases in this phase.
# pred: Model: Segment-Video
# Prompt: Determine the instrument position.
# ans: Model: Surgical-VQA
# Prompt: which instrument positions is being used?
# pred: Model: Segment-MRI
# Prompt: Explain the role of instrument positions in MRI-based surgical procedures.
# ans: Model: Surgical-VQA
# Prompt: explain the role of the instrument positions in this step.
# pred: Model: Segment-Video
# Prompt: Identify the instruments visible within the frame.
# ans: Model: Surgical-VQA
# Prompt: what instruments is present in the frame?
# pred: Model: Segment-Video
# Prompt: What instruments are present in the frame?
# ans: Model: Surgical-VQA
# Prompt: what instrument positions is present in the frame?
# pred: Model: Segment-MRI
# Prompt: Explain the role of instrument positions in a MRI-based segmentation process.
# ans: Model: Surgical-VQA
# Prompt: explain the role of the instrument positions in this step.
# pred: Model: Segment-MRI
# Prompt: Identify the positions of surgical instruments in the MRI images.
# ans: Model: Surgical-VQA
# Prompt: locate the instrument positions in the surgical scene.
# pred: Model: Segment-Video
# Prompt: What instruments are present in the frame?
# ans: Model: Surgical-VQA
# Prompt: what instrument positions is present in the frame?
# pred: Model: Segment-MRI
# Prompt: Describe the phases being used.
# ans: Model: Surgical-VQA
# Prompt: describe the phases being used.
# pred: Model: Segment-MRI
# Prompt: The position of the instrument quantities refers to the location and orientation of surgical instruments within the body during a medical procedure, as visualized through MRI imaging.
# ans: Model: Surgical-VQA
# Prompt: what is the position of the instrument quantities?
# pred: Model: Surgical-VQA
# Prompt: Explain the role of the operation notes in surgical procedures.
# ans: Model: Surgical-VQA
# Prompt: explain the role of the operation notes in this step.
# pred: Model: Segment-Video
# Prompt: What are the positions of the instruments in the video?
# ans: Model: Surgical-VQA
# Prompt: what is the position of the instruments?
# pred: Model: Detect-Video
# Prompt: Identify the instruments in the surgical scene.
# ans: Model: Surgical-VQA
# Prompt: locate the instruments in the surgical scene.
# pred: Model: Segment-MRI
# Prompt: Identify the instruments being used in the MRI scan.
# ans: Model: Surgical-VQA
# Prompt: which instruments is being used?
# pred: Model: Segment-Video
# Prompt: What observations can be made about the phases?
# ans: Model: Surgical-VQA
# Prompt: what observation can be made about the phases?
# pred: Model: Segment-Video
# Prompt: What are the key characteristics of the instruments in the video?
# ans: Model: Surgical-VQA
# Prompt: what observation can be made about the instruments?
# pred: Model: Segment-MRI
# Prompt: Analyze the instrument quantities in this phase.
# ans: Model: Surgical-VQA
# Prompt: analyze the instrument quantities in this phase.
# pred: Model: Segment-MRI
# Prompt: Describe the steps being used.
# ans: Model: Surgical-VQA
# Prompt: describe the steps being used.
# pred: Model: Segment-MRI
# Prompt: Analyze the operation notes in this phase.
# ans: Model: Surgical-VQA
# Prompt: analyze the operation notes in this phase.
# pred: Model: Segment-Video
# Prompt: Identify the instrument positions.
# ans: Model: Surgical-VQA
# Prompt: can you identify the instrument positions?
# pred: Model: Segment-MRI
# Prompt: What are the current instruments?
# ans: Model: Surgical-VQA
# Prompt: what is the current instruments?
# pred: Model: Segment-MRI
# Prompt: What instruments are present in the MRI frame?
# ans: Model: Surgical-VQA
# Prompt: what instruments is present in the frame?
# pred: Model: Segment-MRI
# Prompt: What is the position of the operation notes?
# ans: Model: Surgical-VQA
# Prompt: what is the position of the operation notes?
# pred: Model: Segment-MRI
# Prompt: Describe the current phases.
# ans: Model: Surgical-VQA
# Prompt: what is the current phases?
# pred: Model: Segment-MRI
# Prompt: Identify instrument positions in a medical MRI image.
# ans: Model: Surgical-VQA
# Prompt: can you identify the instrument positions?
# pred: Model: Segment-VQA
# Prompt: Identify instruments in the surgical scene.
# ans: Model: Surgical-VQA
# Prompt: locate the instruments in the surgical scene.
# pred: Model: Segment-MRI
# Prompt: Describe the operation notes.
# ans: Model: Surgical-VQA
# Prompt: describe the operation notes being used.
# pred: Model: Segment-MRI
# Prompt: Identify the operation notes.
# ans: Model: Surgical-VQA
# Prompt: can you identify the operation notes?
# pred: Model: Segment-MRI
# Prompt: What are the current instrument quantities?
# ans: Model: Surgical-VQA
# Prompt: what is the current instrument quantities?
# pred: Model: Segment-MRI
# Prompt: Locate the steps in the surgical scene.
# ans: Model: Surgical-VQA
# Prompt: locate the steps in the surgical scene.
# pred: Model: Segment-MRI
# Prompt: Identify the phases present in the given MRI frame.
# ans: Model: Surgical-VQA
# Prompt: what phases is present in the frame?
# pred: Model: Segment-MRI
# Prompt: Identify and locate the instruments in the surgical scene.
# ans: Model: Surgical-VQA
# Prompt: locate the instruments in the surgical scene.
# pred: Model: Segment-Video
# Prompt: What is the position of the instrument quantities?
# ans: Model: Surgical-VQA
# Prompt: what is the position of the instrument quantities?
# pred: Model: Segment-MRI
# Prompt: Identify the operation note.
# ans: Model: Surgical-VQA
# Prompt: which operation notes is being used?
# pred: Model: Segment-Video
# Prompt: What instruments are being used in the image?
# ans: Model: Surgical-VQA
# Prompt: which instrument positions is being used?
# pred: Model: Segment-MRI
# Prompt: What type of operation note is being used?
# ans: Model: Surgical-VQA
# Prompt: which operation notes is being used?
# pred: Model: Segment-MRI
# Prompt: Explain the role of instruments in a step of a medical procedure involving MRI imaging.
# ans: Model: Surgical-VQA
# Prompt: explain the role of the instruments in this step.
# pred: Model: Segment-MRI
# Prompt: What observation can be made about the steps?
# ans: Model: Surgical-VQA
# Prompt: what observation can be made about the steps?
# pred: Model: Segment-Video
# Prompt: What instrument quantities are used?
# ans: Model: Surgical-VQA
# Prompt: which instrument quantities is being used?
# pred: Model: Detect-Video
# Prompt: Locate the instrument quantities in the surgical scene.
# ans: Model: Surgical-VQA
# Prompt: locate the instrument quantities in the surgical scene.
# pred: Model: Segment-MRI
# Prompt: Describe the operation notes.
# ans: Model: Surgical-VQA
# Prompt: describe the operation notes being used.
# pred: Model: Segment-MRI
# Prompt: Describe the characteristics and differences between the various phases.
# ans: Model: Surgical-VQA
# Prompt: what observation can be made about the phases?
# pred: Model: Segment-MRI
# Prompt: What observation can be made about the phases?
# ans: Model: Surgical-VQA
# Prompt: what observation can be made about the phases?
# pred: Model: Segment-MRI
# Prompt: Describe the steps being used.
# ans: Model: Surgical-VQA
# Prompt: which steps is being used?
# pred: Model: Segment-MRI
# Prompt: Describe the current operation notes.
# ans: Model: Surgical-VQA
# Prompt: what is the current operation notes?
# pred: Model: Segment-MRI
# Prompt: Identify the instrument being used in the image.
# ans: Model: Surgical-VQA
# Prompt: which instruments is being used?
# pred: Model: Segment-Video
# Prompt: What observations can be made about the instrument positions?
# ans: Model: Surgical-VQA
# Prompt: what observation can be made about the instrument positions?
# pred: Model: Segment-MRI
# Prompt: What operation notes are present in the MRI frame?
# ans: Model: Surgical-VQA
# Prompt: what operation notes is present in the frame?
# pred: Model: Segment-MRI
# Prompt: Explain the role of instrument quantities in the context of MRI segmentation.
# ans: Model: Surgical-VQA
# Prompt: explain the role of the instrument quantities in this step.
# pred: Model: Segment-Video
# Prompt: Describe the position of the instrument in a surgical setting.
# ans: Model: Surgical-VQA
# Prompt: what is the position of the instrument positions?
# pred: Model: Segment-MRI
# Prompt: What observation can be made about the operation notes?
# ans: Model: Surgical-VQA
# Prompt: what observation can be made about the operation notes?
# pred: Model: Segment-MRI
# Prompt: Describe the instrument quantities being used.
# ans: Model: Surgical-VQA
# Prompt: describe the instrument quantities being used.
# pred: Model: Segment-MRI
# Prompt: Describe the instruments being used.
# ans: Model: Surgical-VQA
# Prompt: describe the instruments being used.
# pred: Model: Segment-Video
# Prompt: Identify instrument positions.
# ans: Model: Surgical-VQA
# Prompt: can you identify the instrument positions?
# pred: Model: Segment-MRI
# Prompt: Determine the position of the instruments in a medical MRI scan.
# ans: Model: Surgical-VQA
# Prompt: what is the position of the instruments?
# pred: Model: Segment-MRI
# Prompt: Describe the instrument quantities being used.
# ans: Model: Surgical-VQA
# Prompt: describe the instrument quantities being used.
# pred: Model: Segment-MRI
# Prompt: Explain the role of the instrument positions in medical imaging segmentation tasks using MRI.
# ans: Model: Surgical-VQA
# Prompt: explain the role of the instrument positions in this step.
# pred: Model: Segment-MRI
# Prompt: Analyze the operation notes for any observations.
# ans: Model: Surgical-VQA
# Prompt: what observation can be made about the operation notes?
# pred: Model: Segment-MRI
# Prompt: Describe the operation notes being used.
# ans: Model: Surgical-VQA
# Prompt: describe the operation notes being used.
# pred: Model: Segment-MRI
# Prompt: What are the phases present in the MRI frame?
# ans: Model: Surgical-VQA
# Prompt: what phases is present in the frame?
# pred: Model: Segment-MRI
# Prompt: Identify the operation notes from MRI images.
# ans: Model: Surgical-VQA
# Prompt: can you identify the operation notes?
# pred: Model: Segment-MRI
# Prompt: Explain the role of the steps in this step.
# ans: Model: Surgical-VQA
# Prompt: explain the role of the steps in this step.
# pred: Model: Segment-MRI
# Prompt: Identify the phases.
# ans: Model: Surgical-VQA
# Prompt: can you identify the phases?
# pred: Model: Segment-MRI
# Prompt: What instrument positions are being used?
# ans: Model: Surgical-VQA
# Prompt: which instrument positions is being used?
# pred: Model: Segment-MRI
# Prompt: What is the position of the steps?
# ans: Model: Surgical-VQA
# Prompt: what is the position of the steps?
# pred: Model: Overlaying
# Prompt: Describe the steps being used.
# ans: Model: Surgical-VQA
# Prompt: describe the steps being used.
# pred: Model: Segment-MRI
# Prompt: Locate the operation notes in the surgical scene.
# ans: Model: Surgical-VQA
# Prompt: locate the operation notes in the surgical scene.
# pred: Model: Segment-Video
# Prompt: What observation can be made about the instrument positions?
# ans: Model: Surgical-VQA
# Prompt: what observation can be made about the instrument positions?
# pred: Model: Segment-MRI
# Prompt: Explain the role of instrument positions in a MRI-guided surgical procedure.
# ans: Model: Surgical-VQA
# Prompt: explain the role of the instrument positions in this step.
# pred: Model: Segment-MRI
# Prompt: What observation can be made about the steps?
# ans: Model: Surgical-VQA
# Prompt: what observation can be made about the steps?
# pred: Model: Segment-MRI
# Prompt: What are the positions of the phases in MRI?
# ans: Model: Surgical-VQA
# Prompt: what is the position of the phases?
# pred: Model: Segment-MRI
# Prompt: Identify the operation notes from the provided MRI scan images.
# ans: Model: Surgical-VQA
# Prompt: can you identify the operation notes?
# pred: Model: Segment-MRI
# Prompt: What operation notes are present in the MRI frame?
# ans: Model: Surgical-VQA
# Prompt: what operation notes is present in the frame?
# pred: Model: Segment-MRI
# Prompt: Analyze the phases in this phase.
# ans: Model: Surgical-VQA
# Prompt: analyze the phases in this phase.
# pred: Model: Segment-MRI
# Prompt: Analyze the steps in the MRI segmentation phase.
# ans: Model: Surgical-VQA
# Prompt: analyze the steps in this phase.
# pred: Model: Segment-MRI
# Prompt: Identify instrument quantities in a medical MRI image.
# ans: Model: Surgical-VQA
# Prompt: can you identify the instrument quantities?
# pred: Model: Segment-MRI
# Prompt: Describe the steps involved in the segmentation phase of MRI image analysis.
# ans: Model: Surgical-VQA
# Prompt: analyze the steps in this phase.
# pred: Model: Segment-MRI
# Prompt: What instrument quantities are present in the MRI frame?
# ans: Model: Surgical-VQA
# Prompt: what instrument quantities is present in the frame?
# pred: Model: Segment-MRI
# Prompt: What is the name of the operation being performed from the MRI operation notes?
# ans: Model: Surgical-VQA
# Prompt: which operation notes is being used?
# pred: Model: Segment-MRI
# Prompt: Explain the role of the steps in this step.
# ans: Model: Surgical-VQA
# Prompt: explain the role of the steps in this step.
# pred: Model: Detect-Video
# Prompt: Identify the steps in the surgical scene.
# ans: Model: Surgical-VQA
# Prompt: locate the steps in the surgical scene.
# pred: Model: Segment-VQA
# Prompt: Find the operation notes in the surgical scene.
# ans: Model: Surgical-VQA
# Prompt: locate the operation notes in the surgical scene.
# pred: Model: Segment-MRI
# Prompt: What are the characteristics and functions of the instruments used in MRI imaging?
# ans: Model: Surgical-VQA
# Prompt: what observation can be made about the instruments?
# pred: Model: Segment-MRI
# Prompt: What are the typical positions of the phases in the MRI imaging process?
# ans: Model: Surgical-VQA
# ...
# Prompt: Get the current operation notes.
# ans: Model: Surgical-VQA
# Prompt: what is the current operation notes?
# pred: Model: Segment-Video
# Prompt: What are the current instrument quantities?
# ans: Model: Surgical-VQA
# Prompt: what is the current instrument quantities?
# pred: Model: Segment-Video
# Prompt: What instruments are present in the frame?
# ans: Model: Surgical-VQA
# Prompt: what instruments is present in the frame?
# pred: Model: Segment-MRI
# Prompt: What instruments are typically used in a typical MRI scan?
# ans: Model: Surgical-VQA
# Prompt: which instruments is being used?
# pred: Model: Segment-MRI
# Prompt: Analyze the instrument positions in this phase.
# ans: Model: Surgical-VQA
# Prompt: analyze the instrument positions in this phase.
# pred: Model: Segment-Video
# Prompt: What instrument quantities are being used?
# ans: Model: Surgical-VQA
# Prompt: which instrument quantities is being used?
# pred: Model: Segment-MRI
# Prompt: Explain the role of the phases in this step.
# ans: Model: Surgical-VQA
# Prompt: explain the role of the phases in this step.
# pred: Model: Segment-Video
# Prompt: What instrument quantities are present in the frame?
# ans: Model: Surgical-VQA
# Prompt: what instrument quantities is present in the frame?
# pred: Model: Segment-MRI
# Prompt: Identify the instruments in the MRI image.
# ans: Model: Surgical-VQA
# Prompt: can you identify the instruments?
# pred: Model: Segment-Video
# Prompt: What instrument positions are present in the frame?
# ans: Model: Surgical-VQA
# Prompt: what instrument positions is present in the frame?
# pred: Model: Segment-MRI
# Prompt: Explain the role of instrument positions in the MRI segmenting process.
# ans: Model: Surgical-VQA
# Prompt: explain the role of the instrument positions in this step.
# pred: Model: Segment-MRI
# Prompt: Determine the position of the instruments.
# ans: Model: Surgical-VQA
# Prompt: what is the position of the instruments?
# pred: Model: Segment-VQA
# Prompt: Identify instruments in the surgical scene.
# ans: Model: Surgical-VQA
# Prompt: locate the instruments in the surgical scene.
# pred: Model: Segment-MRI
# Prompt: What instruments are used in MRI?
# ans: Model: Surgical-VQA
# Prompt: which instruments is being used?
# pred: Model: Segment-Video
# Prompt: What are the positions of the instruments?
# ans: Model: Surgical-VQA
# Prompt: what is the position of the instruments?
# pred: Model: Segment-Video
# Prompt: Identify the instrument positions present in the frame.
# ans: Model: Surgical-VQA
# Prompt: what instrument positions is present in the frame?
# pred: Model: Segment-VQA
# Prompt: What observation can be made about the instrument positions?
# ans: Model: Surgical-VQA
# Prompt: what observation can be made about the instrument positions?
# pred: Model: Segment-Video
# Prompt: What are the current instruments?
# ans: Model: Surgical-VQA
# Prompt: what is the current instruments?
# pred: Model: Segment-MRI
# Prompt: Identify instrument quantities.
# ans: Model: Surgical-VQA
# Prompt: can you identify the instrument quantities?
# pred: Model: Segment-Video
# Prompt: Describe the instruments being used.
# ans: Model: Surgical-VQA
# Prompt: describe the instruments being used.
# pred: Model: Segment-MRI
# Prompt: Describe the steps in the MRI segmentation phase.
# ans: Model: Surgical-VQA
# Prompt: analyze the steps in this phase.
# pred: Model: Segment-Video
# Prompt: Locate the instrument quantities in the surgical scene.
# ans: Model: Surgical-VQA
# Prompt: locate the instrument quantities in the surgical scene.
# pred: Model: Segment-MRI
# Prompt: Identify the steps being used.
# ans: Model: Surgical-VQA
# Prompt: which steps is being used?
# pred: Model: Segment-MRI
# Prompt: Identify instrument quantities.
# ans: Model: Surgical-VQA
# Prompt: can you identify the instrument quantities?
# pred: Model: Segment-Video
# Prompt: What instruments are present in the frame?
# ans: Model: Surgical-VQA
# Prompt: what instruments is present in the frame?
# pred: Model: Segment-MRI
# Prompt: What is the position of the operation notes?
# ans: Model: Surgical-VQA
# Prompt: what is the position of the operation notes?
# pred: Model: Segment-MRI
# Prompt: Analyze the phases in this phase.
# ans: Model: Surgical-VQA
# Prompt: analyze the phases in this phase.
# pred: Model: Segment-MRI
# Prompt: Identify the instrument quantities being used.
# ans: Model: Surgical-VQA
# Prompt: which instrument quantities is being used?
# pred: Model: Segment-MRI
# Prompt: Identify the type of operation note.
# ans: Model: Surgical-VQA
# Prompt: which operation notes is being used?
# pred: Model: Segment-MRI
# Prompt: Describe the operation notes.
# ans: Model: Surgical-VQA
# Prompt: describe the operation notes being used.
# pred: Model: Segment-MRI
# Prompt: Describe the position of the phases in the human body.
# ans: Model: Surgical-VQA
# Prompt: what is the position of the phases?
# pred: Model: Segment-MRI
# Prompt: Analyze the instrument quantities in this phase.
# ans: Model: Surgical-VQA
# Prompt: analyze the instrument quantities in this phase.
# pred: Model: Segment-MRI
# Prompt: Describe the current medical instruments.
# ans: Model: Surgical-VQA
# Prompt: what is the current instruments?
# pred: Model: Segment-MRI
# Prompt: Analyze the instrument quantities in this phase.
# ans: Model: Surgical-VQA
# Prompt: analyze the instrument quantities in this phase.
# pred: Model: Segment-Video
# Prompt: Analyze the positions of instruments in a medical video to identify any notable patterns or irregularities.
# ans: Model: Surgical-VQA
# Prompt: what observation can be made about the instrument positions?
# pred: Model: Segment-MRI
# Prompt: Analyze the steps in the MRI segmentation phase.
# ans: Model: Surgical-VQA
# Prompt: analyze the steps in this phase.
# pred: Model: Segment-MRI
# Prompt: Explain the role of instrument quantities in medical imaging segmentation tasks.
# ans: Model: Surgical-VQA
# Prompt: explain the role of the instrument quantities in this step.
# pred: Model: Segment-Video
# Prompt: Get current instrument positions.
# ans: Model: Surgical-VQA
# Prompt: what is the current instrument positions?
# pred: Model: Overlaying
# Prompt: Describe the steps being used.
# ans: Model: Surgical-VQA
# Prompt: describe the steps being used.
# pred: Model: Segment-MRI
# Prompt: What are the current phases?
# ans: Model: Surgical-VQA
# Prompt: what is the current phases?
# pred: Model: Segment-MRI
# Prompt: What instrument quantities are being used?
# ans: Model: Surgical-VQA
# Prompt: which instrument quantities is being used?
# pred: Model: Segment-VQA
# Prompt: Identify the instruments.
# ans: Model: Surgical-VQA
# Prompt: can you identify the instruments?
# pred: Model: Segment-MRI
# Prompt: Describe the steps involved in image segmentation in MRI scans.
# ans: Model: Surgical-VQA
# Prompt: analyze the steps in this phase.
# pred: Model: Segment-Video
# Prompt: Identify the phases present in the given frame.
# ans: Model: Surgical-VQA
# Prompt: what phases is present in the frame?
# pred: Model: Segment-MRI
# Prompt: Describe the operation notes being used.
# ans: Model: Surgical-VQA
# Prompt: describe the operation notes being used.
# pred: Model: Segment-MRI
# Prompt: What observation can be made about the phases?
# ans: Model: Surgical-VQA
# Prompt: what observation can be made about the phases?
# pred: Model: Segment-Video
# Prompt: Identify and locate instruments in a surgical scene.
# ans: Model: Surgical-VQA
# Prompt: locate the instruments in the surgical scene.
# pred: Model: Segment-Video
# Prompt: What is the position of the instruments?
# ans: Model: Surgical-VQA
# Prompt: what is the position of the instruments?
# pred: Model: Segment-Video
# Prompt: Analyze the instruments in this phase.
# ans: Model: Surgical-VQA
# Prompt: analyze the instruments in this phase.
# pred: Model: Segment-MRI
# Prompt: What observation can be made about the instrument positions?
# ans: Model: Surgical-VQA
# Prompt: what observation can be made about the instrument positions?
# pred: Model: Surgical-VQA
# Prompt: What observation can be made about the operation notes?
# ans: Model: Surgical-VQA
# Prompt: what observation can be made about the operation notes?
# pred: Model: Segment-Video
# Prompt: Identify the instrument being used.
# ans: Model: Surgical-VQA
# Prompt: which instruments is being used?
# pred: Model: Segment-MRI
# Prompt: Explain the role of instruments in the MRI segmentation process.
# ans: Model: Surgical-VQA
# Prompt: explain the role of the instruments in this step.
# pred: Model: Segment-MRI
# Prompt: Analyze the operation notes for any notable observations.
# ans: Model: Surgical-VQA
# Prompt: what observation can be made about the operation notes?
# pred: Model: Segment-MRI
# Prompt: What are the current instruments?
# ans: Model: Surgical-VQA
# Prompt: what is the current instruments?
# pred: Model: Segment-MRI
# Prompt: What are the current instruments?
# ans: Model: Surgical-VQA
# Prompt: what is the current instruments?
# pred: Model: Segment-MRI
# Prompt: Explain the role of the steps in this step.
# ans: Model: Surgical-VQA
# Prompt: explain the role of the steps in this step.
# pred: Model: Segment-Video
# Prompt: What observations can be made about the instruments?
# ans: Model: Surgical-VQA
# Prompt: what observation can be made about the instruments?
# pred: Model: Segment-Video
# Prompt: Locate the operation notes in the surgical scene.
# ans: Model: Surgical-VQA
# Prompt: locate the operation notes in the surgical scene.
# pred: Model: Segment-MRI
# Prompt: Analyze the operation notes in this phase.
# ans: Model: Surgical-VQA
# Prompt: analyze the operation notes in this phase.
# pred: Model: Segment-Video
# Prompt: What instruments are present in the frame?
# ans: Model: Surgical-VQA
# Prompt: what instruments is present in the frame?
# pred: Model: Segment-MRI
# Prompt: What is the position of the phases in MRI?
# ans: Model: Surgical-VQA
# Prompt: what is the position of the phases?
# pred: Model: Segment-Video
# Prompt: Describe the instrument quantities being used.
# ans: Model: Surgical-VQA
# Prompt: describe the instrument quantities being used.
# pred: Model: Segment-MRI
# Prompt: Explain the role of instruments in the MRI imaging process.
# ans: Model: Surgical-VQA
# Prompt: explain the role of the instruments in this step.
# pred: Model: Segment-MRI
# Prompt: Identify phases in the surgical scene from an MRI image.
# ans: Model: Surgical-VQA
# Prompt: locate the phases in the surgical scene.
# pred: Model: Segment-MRI
# Prompt: What are some key characteristics or patterns that can be observed in instrument quantities, such as precision, accuracy, or reliability?
# ans: Model: Surgical-VQA
# Prompt: what observation can be made about the instrument quantities?
# pred: Model: Segment-Video
# Prompt: Determine the instrument position in a video.
# ans: Model: Surgical-VQA
# Prompt: which instrument positions is being used?
# pred: Model: Segment-MRI
# Prompt: Explain the role of instrument quantities in the MRI segmentation process.
# ans: Model: Surgical-VQA
# Prompt: explain the role of the instrument quantities in this step.
# pred: Model: Detect-Video
# Prompt: Find the operation notes in the surgical scene.
# ans: Model: Surgical-VQA
# Prompt: locate the operation notes in the surgical scene.
# pred: Model: Segment-Video
# Prompt: What are the typical instrument positions in medical procedures?
# ans: Model: Surgical-VQA
# Prompt: what is the position of the instrument positions?
# pred: Model: Segment-MRI
# Prompt: Identify the operation notes.
# ans: Model: Surgical-VQA
# Prompt: can you identify the operation notes?
# pred: Model: Segment-Vision
# Prompt: Find the operation notes in the surgical scene.
# ans: Model: Surgical-VQA
# Prompt: locate the operation notes in the surgical scene.
# pred: Model: Segment-Video
# Prompt: Identify instruments in the surgical scene.
# ans: Model: Surgical-VQA
# Prompt: locate the instruments in the surgical scene.
# pred: Model: Segment-MRI
# Prompt: Identify the steps.
# ans: Model: Surgical-VQA
# Prompt: can you identify the steps?
# pred: Model: Segment-Video
# Prompt: What is the position of the instrument quantities?
# ans: Model: Surgical-VQA
# Prompt: what is the position of the instrument quantities?
# pred: Model: Segment-MRI
# Prompt: What are the current steps?
# ans: Model: Surgical-VQA
# Prompt: what is the current steps?
# pred: Model: Segment-Video
# Prompt: Identify the instrument positions.
# ans: Model: Surgical-VQA
# Prompt: can you identify the instrument positions?
# pred: Model: Segment-MRI
# Prompt: Identify the operation notes from the MRI images.
# ans: Model: Surgical-VQA
# Prompt: can you identify the operation notes?
# pred: Model: Segment-Video
# Prompt: What are the current instrument quantities?
# ans: Model: Surgical-VQA
# Prompt: what is the current instrument quantities?
# pred: Model: Segment-Video
# Prompt: What observations can be made about the instruments?
# ans: Model: Surgical-VQA
# Prompt: what observation can be made about the instruments?
# pred: Model: Segment-Video
# Prompt: Get the current instrument positions.
# ans: Model: Surgical-VQA
# Prompt: what is the current instrument positions?
# pred: Model: Segment-Video
# Prompt: What observations can be made about the instrument positions?
# ans: Model: Surgical-VQA
# Prompt: what observation can be made about the instrument positions?
# pred: Model: Segment-MRI
# Prompt: Identify the steps.
# ans: Model: Surgical-VQA
# Prompt: can you identify the steps?
# pred: Model: Segment-MRI
# Prompt: What is the position of the operation notes?
# ans: Model: Surgical-VQA
# Prompt: what is the position of the operation notes?
# pred: Model: Segment-MRI
# Prompt: Analyze the phases in the MRI images.
# ans: Model: Surgical-VQA
# Prompt: analyze the phases in this phase.
# pred: Model: Segment-Video
# Prompt: What are the current instrument quantities?
# ans: Model: Surgical-VQA
# Prompt: what is the current instrument quantities?
# pred: Model: Segment-MRI
# Prompt: Explain the role of the operation notes in the context of MRI image segmentation.
# ans: Model: Surgical-VQA
# Prompt: explain the role of the operation notes in this step.
# pred: Model: Segment-Video
# Prompt: What is the position of the instrument quantities?
# ans: Model: Surgical-VQA
# Prompt: what is the position of the instrument quantities?
# pred: Model: Segment-Video
# Prompt: What instrument quantities are present in the frame?
# ans: Model: Surgical-VQA
# Prompt: what instrument quantities is present in the frame?
# pred: Model: Segment-MRI
# Prompt: Identify the instrument positions
# ans: Model: Surgical-VQA
# Prompt: can you identify the instrument positions?
# pred: Model: Segment-Video
# Prompt: What are some key observations about the instrument quantities in a surgical video?
# ans: Model: Surgical-VQA
# Prompt: what observation can be made about the instrument quantities?
# pred: Model: Segment-MRI
# Prompt: Analyze the instruments in this phase.
# ans: Model: Surgical-VQA
# Prompt: analyze the instruments in this phase.
# pred: Model: Segment-MRI
# Prompt: Analyze the instruments in this phase.
# ans: Model: Surgical-VQA
# Prompt: analyze the instruments in this phase.
# pred: Model: Segment-MRI
# Prompt: What are the distinct phases that can be observed in MRI images?
# ans: Model: Surgical-VQA
# Prompt: what observation can be made about the phases?
# pred: Model: Segment-MRI
# Prompt: Explain the role of the instruments in the segmentation process of MRI images.
# ans: Model: Surgical-VQA
# Prompt: explain the role of the instruments in this step.
# pred: Model: Segment-MRI
# Prompt: Identify the instrument quantities.
# ans: Model: Surgical-VQA
# Prompt: can you identify the instrument quantities?
# pred: Model: Segment-MRI
# Prompt: Explain the role of instruments in medical imaging procedures, specifically focusing on MRI segmentations.
# ans: Model: Surgical-VQA
# Prompt: explain the role of the instruments in this step.
# pred: Model: Segment-Video
# Prompt: Identify the instrument position.
# ans: Model: Surgical-VQA
# Prompt: which instrument positions is being used?
# pred: Model: Segment-MRI
# Prompt: The operation notes are typically located at the end of the medical report and provide a summary of the surgical procedure.
# ans: Model: Surgical-VQA
# Prompt: what is the position of the operation notes?
# pred: Model: Segment-Video
# Prompt: What are the current instruments?
# ans: Model: Surgical-VQA
# Prompt: what is the current instruments?

# %%
import os
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')

# File Path
output_file_path = '/content/drive/My Drive/svqa_v.txt'

# Write data
with open(output_file_path, 'w') as file:
    for i in range(len(all_pred)):
        file.write(f"pred: {all_pred[i]}\n")
        file.write(f"ans: {all_ans[i]}\n")
        file.write("\n")  # 添加换行以便于阅读

print(f"file saved at: {output_file_path}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# file saved at: /content/drive/My Drive/svqa_v.txt

# %%
# 定义新的变量来存储提取的 Prompt 部分
all_pred_prompts = []
all_ans_prompts = []

# 提取 Prompt 部分的函数
def extract_prompt(entry):
    for line in entry.split('\n'):
        if line.startswith("Prompt:"):
            return line[len("Prompt: "):]  # 去掉 "Prompt: " 保留内容

# 提取 all_pred 和 all_ans 中的 Prompt 部分
all_pred_prompts = [extract_prompt(item) for item in all_pred]
all_ans_prompts = [extract_prompt(item) for item in all_ans]

# 打印结果验证
print("Extracted Prompts from all_pred:", all_pred_prompts)
print("Extracted Prompts from all_ans:", all_ans_prompts)
# Out:
# Extracted Prompts from all_pred: ['What is the position of the instruments in a typical MRI scan?', 'Identify the instrument quantities used in MRI imaging.', 'Analyze the instruments in this phase.', 'Identify the instrument quantities.', 'Analyze the operation notes in this phase.', 'Identify the phases of the human body from MRI images.', 'What is the operation note being used?', 'What operation note is being used?', 'Analyze the steps taken in a video and make an observation about them.', 'Identify instrument positions in the surgical scene from the MRI images.', 'Describe the instruments being used.', 'Identify the instruments used in the MRI scan.', 'The position of the phases is a common reference point in MRI sequences, typically referring to the different stages of a pulse sequence, such as the repetition time (TR), echo time (TE), and the number of excitations (NEX).', 'The position of the operation notes is in the MRI report.', 'What is the position of the steps?', 'Identify the instruments in the surgical scene.', 'What instrument quantities are present in the frame?', 'What are the phases present in the MRI frame?', 'Describe the steps present in the MRI frame.', 'Analyze the phases in this phase.', 'Find and highlight all instrument quantities in the surgical scene.', 'Identify steps present in the MRI frame.', 'Describe the current steps in a medical procedure.', 'Identify and locate all instruments in the surgical scene.', 'What are the current phases?', 'Identify steps in a surgical scene from MRI images.', 'Identify the phases of the MRI images.', 'Describe the phases being used.', 'What are the typical instrument positions in a surgical setting?', 'Identify and locate instruments in a surgical scene.', 'What can be observed about the instruments in an MRI environment?', 'What instrument quantities are being used?', 'What are the current instruments?', 'Identify instruments present in the frame.', 'Identify the instrument quantities.', 'Describe the operation notes being used.', 'Describe the steps being used.', 'Describe the instrument positions.', 'Identify instrument positions in MRI images.', 'What observations can be made about the instruments?', 'Describe the steps used in the process of segmenting an MRI image.', 'What instrument positions are being used?', 'Identify instrument quantities in the surgical scene.', 'Explain the role of phases in the segmentation process.', 'Identify the phases in the surgical scene.', 'Describe the instruments being used in a medical context.', 'Explain the role of the instruments in the MRI segmentation process.', 'What observation can be made about the instrument quantities?', 'Which phases are being used?', 'Locate the instrument positions in the surgical scene.', 'Identify instruments in a surgical scene.', 'What are the current instruments?', 'Analyze the instrument positions in this phase.', 'Analyze the instruments in this phase.', 'What are the general characteristics or features of the different phases that can be observed?', 'The position of the instrument positions.', 'What instruments are present in the frame?', 'Describe the operation notes being used.', 'What can be observed about the steps?', 'Analyze the instruments in this phase.', 'What can be observed about the instrument quantities?', 'Describe the current phases in the context of medical imaging.', 'What instrument positions are being used?', 'What is the position of the phases?', 'Identify the operation notes.', 'What is the current operation notes?', 'What are the phases being used?', 'What observation can be made about the instrument positions?', 'Describe the steps being used.', 'What are the positions of the instruments in the image?', 'What is the position of the instrument positions?', 'Analyze the steps in the video analysis phase.', 'What phases are present in the MRI frame?', 'Identify instruments in the surgical scene.', 'Explain the role of steps in the MRI segmentation process.', 'Identi ...
# Extracted Prompts from all_ans: ['what is the position of the instruments?', 'which instrument quantities is being used?', 'analyze the instruments in this phase.', 'can you identify the instrument quantities?', 'analyze the operation notes in this phase.', 'can you identify the phases?', 'which operation notes is being used?', 'which operation notes is being used?', 'what observation can be made about the steps?', 'locate the instrument positions in the surgical scene.', 'describe the instruments being used.', 'which instruments is being used?', 'what is the position of the phases?', 'what is the position of the operation notes?', 'what is the position of the steps?', 'locate the instruments in the surgical scene.', 'what instrument quantities is present in the frame?', 'what phases is present in the frame?', 'what steps is present in the frame?', 'analyze the phases in this phase.', 'locate the instrument quantities in the surgical scene.', 'what steps is present in the frame?', 'what is the current steps?', 'locate the instruments in the surgical scene.', 'what is the current phases?', 'locate the steps in the surgical scene.', 'can you identify the phases?', 'describe the phases being used.', 'what is the position of the instrument positions?', 'locate the instruments in the surgical scene.', 'what observation can be made about the instruments?', 'which instrument quantities is being used?', 'what is the current instruments?', 'what instruments is present in the frame?', 'can you identify the instrument quantities?', 'describe the operation notes being used.', 'which steps is being used?', 'describe the instrument positions being used.', 'can you identify the instrument positions?', 'what observation can be made about the instruments?', 'which steps is being used?', 'which instrument positions is being used?', 'locate the instrument quantities in the surgical scene.', 'explain the role of the phases in this step.', 'locate the phases in the surgical scene.', 'describe the instruments being used.', 'explain the role of the instruments in this step.', 'what observation can be made about the instrument quantities?', 'which phases is being used?', 'locate the instrument positions in the surgical scene.', 'locate the instruments in the surgical scene.', 'what is the current instruments?', 'analyze the instrument positions in this phase.', 'analyze the instruments in this phase.', 'what observation can be made about the phases?', 'what is the position of the instrument positions?', 'what instruments is present in the frame?', 'describe the operation notes being used.', 'what observation can be made about the steps?', 'analyze the instruments in this phase.', 'what observation can be made about the instrument quantities?', 'what is the current phases?', 'which instrument positions is being used?', 'what is the position of the phases?', 'can you identify the operation notes?', 'what is the current operation notes?', 'which phases is being used?', 'what observation can be made about the instrument positions?', 'describe the steps being used.', 'what is the position of the instruments?', 'what is the position of the instrument positions?', 'analyze the steps in this phase.', 'what phases is present in the frame?', 'locate the instruments in the surgical scene.', 'explain the role of the steps in this step.', 'locate the steps in the surgical scene.', 'describe the instruments being used.', 'which instruments is being used?', 'analyze the phases in this phase.', 'explain the role of the instruments in this step.', 'analyze the instrument quantities in this phase.', 'what observation can be made about the operation notes?', 'locate the operation notes in the surgical scene.', 'describe the instrument quantities being used.', 'locate the phases in the surgical scene.', 'what is the current instrument quantities?', 'explain the role of the instruments in this step.', 'locate the operation notes in the surgical scene.', 'analyze the step ...

# %%
# !pip install rouge_score
rouge = evaluate.load("rouge")
rouge_results = rouge.compute(predictions= all_pred_prompts, references=all_ans_prompts)
print(rouge_results)
# Out:
# Collecting rouge_score
#   Downloading rouge_score-0.1.2.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: absl-py in /usr/local/lib/python3.11/dist-packages (from rouge_score) (1.4.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.11/dist-packages (from rouge_score) (3.9.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from rouge_score) (1.26.4)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.11/dist-packages (from rouge_score) (1.17.0)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk->rouge_score) (8.1.8)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from nltk->rouge_score) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.11/dist-packages (from nltk->rouge_score) (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from nltk->rouge_score) (4.67.1)
# Building wheels for collected packages: rouge_score
#   Building wheel for rouge_score (setup.py) ... done
#   Created wheel for rouge_score: filename=rouge_score-0.1.2-py3-none-any.whl size=24935 sha256=c7630f87fd068c6bb0b9c37380c1a178a8621c7187b24d6406343ea1a708eaa9
#   Stored in directory: /root/.cache/pip/wheels/1e/19/43/8a442dc83660ca25e163e1bd1f89919284ab0d0c1475475148
# Successfully built rouge_score
# Installing collected packages: rouge_score
# Successfully installed rouge_score-0.1.2
# Downloading builder script:   0%|          | 0.00/6.27k [00:00<?, ?B/s]
# {'rouge1': 0.759106071832303, 'rouge2': 0.6309449724085615, 'rougeL': 0.7539034934808027, 'rougeLsum': 0.7537893757669449}

# %%
bleu_score = corpus_bleu(all_ans_prompts, all_pred_prompts, weights=(1.0, 0.0, 0.0, 0.0))
print(bleu_score)
# Out:
# 0.307551957720781
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)

# %%
import nltk
nltk.download('wordnet')
from nltk.tokenize import word_tokenize
nltk.download('punkt_tab')
import warnings
warnings.filterwarnings("ignore", category=UserWarning)

m_score=0
for line in zip(all_ans_prompts, all_pred_prompts):
    ref = word_tokenize(line[0])
    hypo = word_tokenize(line[1])
    m_score += meteor_score([ref], hypo)
meteors = m_score/len(all_ans)
print(meteors)
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# 0.7372884506654849

# %%
import re

# Function to extract the "Model" part from a given text
def extract_model(text):
    match = re.search(r"Model:\s*(.*?)\n", text)
    return match.group(1) if match else ""

# Function to calculate exact match accuracy
def calculate_exact_match_accuracy(predictions, answers):
    # Extract and strip spaces from the models
    pred_models = [extract_model(pred).strip() for pred in predictions]
    true_models = [extract_model(ans).strip() for ans in answers]

    # Debug prints for checking values
    print(pred_models)
    print(len(pred_models))
    print(true_models)
    print(len(true_models))

    correct_matches = sum(p == t for p, t in zip(pred_models, true_models))
    total = len(true_models)
    return correct_matches / total if total > 0 else 0

# Calculate exact match accuracy
accuracy = calculate_exact_match_accuracy(all_pred, all_ans)
print(f"Exact Match Accuracy: {accuracy * 100:.2f}%")
# Out:
# ['Segment-MRI', 'Segment-MRI', 'Segment-MRI', 'Segment-VQA', 'Segment-MRI', 'Segment-MRI', 'Segment-MRI', 'Segment-MRI', 'Segment-Video', 'Segment-MRI', 'Segment-MRI', 'Segment-MRI', 'Segment-MRI', 'Segment-MRI', 'Segment-MRI', 'Detect-Video', 'Segment-Video', 'Segment-MRI', 'Segment-MRI', 'Segment-MRI', 'Segment-Video', 'Segment-MRI', 'Detect-Video', 'Segment-Video', 'Segment-MRI', 'Segment-MRI', 'Segment-MRI', 'Segment-MRI', 'Segment-Video', 'Segment-Video', 'Segment-MRI', 'Segment-Video', 'Segment-MRI', 'Segment-Video', 'Segment-MRI', 'Segment-MRI', 'Segment-MRI', 'Segment-MRI', 'Segment-MRI', 'Segment-MRI', 'Segment-MRI', 'Segment-MRI', 'Detect-Video', 'Segment-MRI', 'Segment-MRI', 'Segment-MRI', 'Segment-MRI', 'Segment-Video', 'Segment-MRI', 'Segment-MRI', 'Segment-Video', 'Segment-Video', 'Segment-MRI', 'Segment-MRI', 'Segment-MRI', 'Segment-Video', 'Segment-Video', 'Segment-MRI', 'Segment-Video', 'Segment-MRI', 'Segment-Video', 'Segment-MRI', 'Segment-Video', 'Segment-MRI', 'Segment-MRI', 'Segment-MRI', 'Segment-MRI', 'Segment-Video', 'Overlaying', 'Segment-MRI', 'Segment-Video', 'Detect-Video', 'Segment-MRI', 'Detect-Video', 'Segment-MRI', 'Segment-MRI', 'Segment-MRI', 'Segment-MRI', 'Segment-MRI', 'Segment-MRI', 'Segment-Video', 'Segment-Video', 'Detect-Video', 'Segment-MRI', 'Detect-Video', 'Segment-Video', 'Segment-MRI', 'Segment-MRI', 'Overlaying', 'Segment-MRI', 'Segment-MRI', 'Segment-MRI', 'Segment-MRI', 'Segment-Video', 'Detect-Video', 'Segment-Video', 'Segment-MRI', 'Segment-MRI', 'Segment-MRI', 'Segment-MRI', 'Segment-MRI', 'Detect-Video', 'Segment-Video', 'Segment-MRI', 'Segment-MRI', 'Segment-MRI', 'Segment-Video', 'Segment-Video', 'Segment-MRI', 'Segment-MRI', 'Segment-Video', 'Segment-MRI', 'Segment-MRI', 'Segment-MRI', 'Segment-Video', 'Segment-MRI', 'Segment-MRI', 'Segment-MRI', 'Segment-MRI', 'Segment-MRI', 'Segment-MRI', 'Segment-Video', 'Segment-MRI', 'Segment-MRI', 'Segment-MRI', 'Segment-MRI', 'Detect-Video', 'Detect-Video', 'Segment-MRI', 'Segment-Video', 'Segment-MRI', 'Segment-MRI', 'Segment-MRI', 'Segment-Video', 'Segment-Video', 'Segment-Video', 'Segment-MRI', 'Segment-MRI', 'Segment-MRI', 'Segment-Video', 'Segment-MRI', 'Surgical-VQA', 'Segment-Video', 'Segment-MRI', 'Segment-MRI', 'Surgical-VQA', 'Segment-Video', 'Segment-MRI', 'Segment-MRI', 'Segment-Video', 'Segment-MRI', 'Segment-MRI', 'Detect-Video', 'Segment-MRI', 'Segment-MRI', 'Detect-Video', 'Segment-MRI', 'Segment-Video', 'Segment-Video', 'Segment-MRI', 'Segment-MRI', 'Surgical-VQA', 'Segment-Video', 'Segment-MRI', 'Overlaying', 'Detect-Video', 'Segment-MRI', 'Segment-MRI', 'Segment-Video', 'Segment-MRI', 'Segment-MRI', 'Segment-MRI', 'Segment-Video', 'Segment-Video', 'Segment-Video', 'Segment-Video', 'Segment-MRI', 'Segment-MRI', 'Segment-MRI', 'Segment-Video', 'Segment-MRI', 'Segment-MRI', 'Segment-Video', 'Segment-MRI', 'Segment-Video', 'Segment-MRI', 'Overlaying', 'Segment-MRI', 'Segment-Video', 'Segment-MRI', 'Segment-MRI', 'Segment-MRI', 'Segment-Video', 'Segment-MRI', 'Segment-Video', 'Segment-MRI', 'Segment-MRI', 'Segment-Video', 'Segment-Video', 'Segment-Video', 'Segment-MRI', 'Segment-MRI', 'Segment-MRI', 'Segment-Video', 'Segment-MRI', 'Segment-MRI', 'Surgical-VQA', 'Segment-Video', 'Segment-MRI', 'Segment-MRI', 'Segment-MRI', 'Segment-MRI', 'Segment-MRI', 'Segment-MRI', 'Segment-MRI', 'Segment-MRI', 'Detect-Video', 'Segment-Video', 'Segment-MRI', 'Segment-Video', 'Segment-Video', 'Segment-MRI', 'Segment-MRI', 'Segment-Video', 'Segment-MRI', 'Segment-MRI', 'Surgical-VQA', 'Segment-Video', 'Detect-Video', 'Segment-MRI', 'Segment-Video', 'Segment-Video', 'Segment-MRI', 'Segment-MRI', 'Segment-MRI', 'Segment-Video', 'Segment-MRI', 'Segment-MRI', 'Segment-MRI', 'Segment-MRI', 'Segment-MRI', 'Segment-VQA', 'Segment-MRI', 'Segment-MRI', 'Segment-MRI', 'Segment-MRI', 'Segment-MRI', 'Segment-MRI', 'Segment-Video', 'Segment-MRI', 'Segment-Video', 'Segment-MRI', 'Segment-MRI', 'Segment-MRI', 'Segment-Video', 'Detect-Video', 'Segmen ...
# 1000
# ['Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', 'Surgical-VQA', ...
# 1000
# Exact Match Accuracy: 1.90%
