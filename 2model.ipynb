# %% [markdown]
# <a href="https://colab.research.google.com/github/PeterHJY628/MyOwnExample/blob/main/2model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip -q install "torch==2.4.0" tensorboard pillow torchvision accelerate huggingface_hub
# !pip -q install  --upgrade \
  "transformers==4.45.1" \
  "datasets==3.0.1" \
  "accelerate==0.34.2" \
  "evaluate==0.4.3" \
  "bitsandbytes==0.44.0" \
  "trl==0.11.1" \
  "peft==0.13.0" \
  "qwen_vl_utils"
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 797.3/797.3 MB 2.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.2/176.2 MB 6.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.4/209.4 MB 5.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 43.6 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchaudio 2.5.1+cu121 requires torch==2.5.1, but you have torch 2.4.0 which is incompatible.
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 2.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 61.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 471.6/471.6 kB 37.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 324.4/324.4 kB 28.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.0/84.0 kB 8.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 122.4/122.4 MB 8.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 318.4/318.4 kB 19.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.5/322.5 kB 20.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 3.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.6/177.6 kB 7.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 30.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.5/115.5 kB 9.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.8/33.8 MB 41.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 11.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 18.9 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.6.1 which is incompatible.
# torchaudio 2.5.1+cu121 requires torch==2.5.1, but you have torch 2.4.0 which is incompatible.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.environ['HF_HOME'] = '/home/sa5u24/VQA'
hf_home = os.path.expanduser(
    os.getenv("HF_HOME", os.path.join(os.getenv("XDG_CACHE_HOME", "~/.cache"), "huggingface"))
)
print(hf_home)

from huggingface_hub import login

# Replace 'your-hf-token-here' with your actual Hugging Face token
login(token="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")
# Out:
# /home/sa5u24/VQA

# %%
def generate_SM(que):
    sm = (
        "Select models to answer the following question:\n"
        f"{que}\n"
        "Select models only from the following model list: 'Segment-Video, Segment-MRI, Detect-Instrument, Overlaying, Surgical-VQA' to answer the question.\n"
        "Generate corresponding shortest prompts for chosen models.\n"
        "Your response should only have two lines and be like: 'Model: ?| ?\nPrompt: ?| ?' and no other words."
    )
    return sm

def format_data(sample):
    system_message = generate_SM(sample[0])
    return [
        {
            "role": "system",
            "content": [
                {
                    "type": "text",
                    "text": system_message
                }
            ],
        },
        # {
        #     "role": "user",
        #     "content": [

        #         {
        #             "type": "text",
        #             "text": sample[0],

        #         }
        #     ],
        # },
        {
            "role": "assistant",
            "content": [
                {
                    "type": "text",
                    "text": sample[1]
                }
            ],
        },
    ]

#system_message = generate_SM(test_dataset[0][0])

# %%
from datasets import load_dataset

dataset_id = "HuggingFaceM4/ChartQA"
train_dataset, eval_dataset, test_dataset = load_dataset(dataset_id, split=['train[:10%]', 'val[:10%]', 'test[:10%]'])

train_dataset = [format_data(sample) for sample in train_dataset]
eval_dataset = [format_data(sample) for sample in eval_dataset]
test_dataset = [format_data(sample) for sample in test_dataset]

train_dataset[200], len(train_dataset), len(eval_dataset), len(test_dataset)
# Out:
# ([{'role': 'system',
#    'content': [{'type': 'text',
#      'text': 'You are a Vision Language Model specialized in interpreting visual data from chart images.\nYour task is to analyze the provided chart image and respond to queries with concise answers, usually a single word, number, or short phrase.\nThe charts include a variety of types (e.g., line charts, bar charts) and contain colors, labels, and text.\nFocus on delivering accurate, succinct answers based on the visual information. Avoid additional explanation unless absolutely necessary.'}]},
#   {'role': 'user',
#    'content': [{'type': 'text',
#      'text': 'Is the rightmost value of light brown graph 58?'}]},
#   {'role': 'assistant', 'content': [{'type': 'text', 'text': 'No'}]}],
#  2830,
#  192,
#  250)

# %%
import os
import re
import torch
import random
import numpy as np
from torch.utils.data import Dataset, DataLoader
import pandas as pd
from google.colab import drive

# Mount Google Drive to access the file
drive.mount('/content/drive')

class TextQuestionLabelDataset(Dataset):
    def __init__(self, input_file):
        # Load data from a CSV file
        self.data = pd.read_csv(input_file)
        #print(self.data.head())  # 显示前 5 行数据


        # Extract questions and labels from the Input column
        #self.questions = self.data['Input'].apply(lambda x: re.search(r'Question: (.+?)\n', x).group(1)).tolist()
        self.questions = self.data['Input'].tolist()
        self.labels = self.data['Label'].tolist()

    def __len__(self):
        # Return the total number of samples
        return len(self.questions)

    def __getitem__(self, idx):
        # Return a single sample (question, label) given an index
        question = self.questions[idx]
        label = self.labels[idx]
        return question, label

input_file = '/content/drive/MyDrive/two-model.csv'

# Initialize dataset
dataset = TextQuestionLabelDataset(input_file)

# Split the dataset for train, eval, and test (e.g., 10% for each)
dataset_length = len(dataset)
#train_size = int(0.1 * dataset_length)
train_size = 0
#eval_size = int(0.1 * dataset_length)
eval_size = 0
test_size = dataset_length - train_size - eval_size
#seed everything
seed = 42
torch.manual_seed(seed)
random.seed(seed)
np.random.seed(seed)

# train_dataset, eval_dataset, test_dataset = torch.utils.data.random_split(
#     dataset, [train_size, eval_size, test_size]
# )

train_dataset = torch.utils.data.Subset(dataset, range(0, train_size))
eval_dataset = torch.utils.data.Subset(dataset, range(train_size, train_size + eval_size))
test_dataset = torch.utils.data.Subset(dataset, range(train_size + eval_size, len(dataset)))
#print(train_dataset[0])
train_dataset = [format_data(sample) for sample in train_dataset]
eval_dataset = [format_data(sample) for sample in eval_dataset]
test_dataset = [format_data(sample) for sample in test_dataset]

# Create DataLoaders for batching
# train_loader = DataLoader(train_dataset, batch_size=2, shuffle=True)
# eval_loader = DataLoader(eval_dataset, batch_size=2, shuffle=False)
# test_loader = DataLoader(test_dataset, batch_size=2, shuffle=False)
# test_dataset[0]
# test_dataset[0]
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import gc
import time

def clear_memory():
    # Delete variables if they exist in the current global scope
    if 'inputs' in globals(): del globals()['inputs']
    if 'model' in globals(): del globals()['model']
    if 'processor' in globals(): del globals()['processor']
    if 'trainer' in globals(): del globals()['trainer']
    if 'peft_model' in globals(): del globals()['peft_model']
    if 'bnb_config' in globals(): del globals()['bnb_config']
    time.sleep(2)

    # Garbage collection and clearing CUDA memory
    gc.collect()
    time.sleep(2)
    torch.cuda.empty_cache()
    torch.cuda.synchronize()
    time.sleep(2)
    gc.collect()
    time.sleep(2)

    print(f"GPU allocated memory: {torch.cuda.memory_allocated() / 1024**3:.2f} GB")
    print(f"GPU reserved memory: {torch.cuda.memory_reserved() / 1024**3:.2f} GB")



def generate_text_from_sample(model, processor, sample, max_new_tokens=1024, device="cuda"):
    # Prepare the text input by applying the chat template
    text_input = processor.apply_chat_template(
        sample[:1],  # Use the sample without the system message
        tokenize=False,
        add_generation_prompt=True
    )
    #print("Text Input:", text_input)


    # Process the visual input from the sample
    # image_inputs, _ = process_vision_info(sample)
    #image_inputs = sample[1]['content'][0]['image'].convert("RGB")
    image_data = sample[1]['content'][0].get('image')

    if image_data is not None:
        image_inputs = image_data.convert("RGB")
    else:
        # 提供一个默认值或适当的处理逻辑
        image_inputs = None
        #print("Warning: The 'image' field is None.")
    # Prepare the inputs for the model
    model_inputs = processor(
        text=[text_input],
        images=image_inputs,
        return_tensors="pt",
    ).to(device)  # Move inputs to the specified device

    # Generate text with the model
    generated_ids = model.generate(**model_inputs, max_new_tokens=max_new_tokens)

    # Trim the generated ids to remove the input ids
    trimmed_generated_ids = [
        out_ids[len(in_ids):] for in_ids, out_ids in zip(model_inputs.input_ids, generated_ids)
    ]

    # Decode the output text
    output_text = processor.batch_decode(
        trimmed_generated_ids,
        skip_special_tokens=True,
        clean_up_tokenization_spaces=False
    )

    return output_text[0]  # Return the first decoded output text

# %%
clear_memory()
# Out:
# GPU allocated memory: 0.01 GB
# GPU reserved memory: 0.02 GB

# %%
import evaluate
import torch
from nltk.translate.meteor_score import meteor_score, single_meteor_score
from nltk.translate.bleu_score import sentence_bleu, corpus_bleu
import requests
from torch import nn
from transformers import MllamaForConditionalGeneration, AutoProcessor, MllamaConfig, AutoModelForCausalLM
from typing import List, Optional, Tuple, Union
from PIL import Image
import matplotlib.pyplot as plt
from qwen_vl_utils import process_vision_info
from transformers import BitsAndBytesConfig



quantization_config = BitsAndBytesConfig(
    load_in_4bit=True,
    # low_cpu_mem_usage=True,
    # bnb_4bit_compute_dtype=torch.float16
)

model_id = "meta-llama/Llama-3.2-11B-Vision-Instruct"
processor = AutoProcessor.from_pretrained("meta-llama/Llama-3.2-11B-Vision-Instruct")
model = MllamaForConditionalGeneration.from_pretrained(
            model_id, torch_dtype=torch.bfloat16, device_map="auto", low_cpu_mem_usage=True,
            quantization_config=quantization_config,
        )
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# preprocessor_config.json:   0%|          | 0.00/437 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/55.8k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/5.07k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.09M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/454 [00:00<?, ?B/s]
# chat_template.json:   0%|          | 0.00/5.09k [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/89.4k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/5 [00:00<?, ?it/s]
# model-00001-of-00005.safetensors:   0%|          | 0.00/4.99G [00:00<?, ?B/s]
# model-00002-of-00005.safetensors:   0%|          | 0.00/4.97G [00:00<?, ?B/s]
# model-00003-of-00005.safetensors:   0%|          | 0.00/4.92G [00:00<?, ?B/s]
# model-00004-of-00005.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# model-00005-of-00005.safetensors:   0%|          | 0.00/1.47G [00:00<?, ?B/s]
# WARNING:accelerate.utils.modeling:The model weights are not tied. Please use the `tie_weights` method before using the `infer_auto_device` function.
# Loading checkpoint shards:   0%|          | 0/5 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/215 [00:00<?, ?B/s]

# %%
import os
import re
import torch
import random
import numpy as np
from torch.utils.data import Dataset, DataLoader
import pandas as pd
from google.colab import drive


def generate_text_from_sample(model, processor, sample, max_new_tokens=1024, device="cuda"):
    # Prepare the text input by applying the chat template
    text_input = processor.apply_chat_template(
        sample[:1],  # Use the sample without the system message
        tokenize=False,
        add_generation_prompt=True
    )
    #print("Text Input:", text_input)


    # Process the visual input from the sample
    # image_inputs, _ = process_vision_info(sample)
    #image_inputs = sample[1]['content'][0]['image'].convert("RGB")
    image_data = sample[1]['content'][0].get('image')

    if image_data is not None:
        image_inputs = image_data.convert("RGB")
    else:
        # 提供一个默认值或适当的处理逻辑
        image_inputs = None
        #print("Warning: The 'image' field is None.")
    # Prepare the inputs for the model
    model_inputs = processor(
        text=[text_input],
        images=image_inputs,
        return_tensors="pt",
    ).to(device)  # Move inputs to the specified device

    # Generate text with the model
    generated_ids = model.generate(**model_inputs, max_new_tokens=max_new_tokens)

    # Trim the generated ids to remove the input ids
    trimmed_generated_ids = [
        out_ids[len(in_ids):] for in_ids, out_ids in zip(model_inputs.input_ids, generated_ids)
    ]

    # Decode the output text
    output_text = processor.batch_decode(
        trimmed_generated_ids,
        skip_special_tokens=True,
        clean_up_tokenization_spaces=False
    )

    return output_text[0]

# Mount Google Drive to access the file
drive.mount('/content/drive')

class TextQuestionLabelDataset(Dataset):
    def __init__(self, input_file):
        # Load data from a CSV file
        self.data = pd.read_csv(input_file)
        # print(self.data.head())  # 显示前 5 行数据


        # Extract questions and labels from the Input column
        #self.questions = self.data['Input'].apply(lambda x: re.search(r'Question: (.+?)\n', x).group(1)).tolist()
        self.questions = self.data['Input'].tolist()
        self.labels = self.data['Label'].tolist()

    def __len__(self):
        # Return the total number of samples
        return len(self.questions)

    def __getitem__(self, idx):
        # Return a single sample (question, label) given an index
        question = self.questions[idx]
        label = self.labels[idx]
        return question, label

input_file = '/content/drive/MyDrive/t_2m_10s.csv'

# Initialize dataset
dataset = TextQuestionLabelDataset(input_file)

# Split the dataset for train, eval, and test (e.g., 10% for each)
dataset_length = len(dataset)
#train_size = int(0.1 * dataset_length)
train_size = 0
#eval_size = int(0.1 * dataset_length)
eval_size = 0
test_size = dataset_length - train_size - eval_size

#seed everything
seed = 42
torch.manual_seed(seed)
random.seed(seed)
np.random.seed(seed)

# train_dataset, eval_dataset, test_dataset = torch.utils.data.random_split(
#     dataset, [train_size, eval_size, test_size]
# )

train_dataset = torch.utils.data.Subset(dataset, range(0, train_size))
eval_dataset = torch.utils.data.Subset(dataset, range(train_size, train_size + eval_size))
test_dataset = torch.utils.data.Subset(dataset, range(train_size + eval_size, len(dataset)))

def generate_SM(que):
    sm = (
        "Select models to answer the following question:\n"
        f"{que}\n"
        "Select models only from the following model list: Segment-Video, Segment-MRI, Detect-Video, Overlaying, Surgical-VQA to answer the question.\n"
        "Generate shortest prompts for each chosen model.\n"
        "Your response should be like: 'Model: ?| ?\nPrompt: ?| ?' and no other words."
    )
    return sm


# system_message = """ Select a model to answer the following question: What is the position of the instrument?
# Select model only from the following model list: Segment-Video, Segment-MRI, Detect-Video, Overlaying, Surgical-VQA to answer the question?
# Generate a shortest prompt for the chosen model. Your response should be like Model: ? Prompt: ? and no other words
# """


# system_message = """ You are an LLM agent which can call functions and corresponding prompt based on surgeons' query.
# The agent will be used in endonasal pituitary surgery to call visual models Segment-Video, Segment-MRI, Detect-Video, Overlaying, Surgical-VQA.
# There are 59 classes overall, including 4 phases, 15 steps, 18 instruments, 3 variations of instruments present in a frame, 5 positions of the instruments, and 14 operation notes in the annotation classes.
# The agent may call more than one model sequentially or in parallel based on query.
# Your task is to analyze the user's query, determine the intent, and return the name of the AI model to be invoked along with the corresponding prompt.
# If you receive the input like: "Question: Segment tumor from MRI and overlay on video?" The format of the answer should be like this: Model: Segmen-MRI|Overlaying
# Prompt: Segment tumor from MRI?|Overlay on video?" This is the format for the answers may need more than one model. The model options are Model Options: [Segment-Video, Segment-MRI, Detect-Video, Overlaying, Surgical-VQA].
# If you receive the input like: "Question: Segment Sella from Video?" The format of the answer should be like this: Model: Segment-Video
# Prompt: Segment Sella from video?" This is the format for the answers need only one model. The model options are Model Options:[Segment-Video, Segment-MRI, Detect-Video, Overlaying, Surgical-VQA].
# """
# system_message = """
# Your task is to analyze the user's query, determine the intent, and return the name of the AI model to be invoked along with the corresponding prompt.
# If you receive the input like: "Question: Segment tumor from MRI and overlay on video?" The format of the answer should be like this: Model: Segmen-MRI|Overlaying
# Prompt: Segment tumor from MRI?|Overlay on video?" This is the format for the answers may need more than one model. The model options are Model Options: [Segment-Video, Segment-MRI, Detect-Video, Overlaying, Surgical-VQA].
# If you receive the input like: "Question: Segment Sella from Video?" The format of the answer should be like this: Model: Segment-Video
# Prompt: Segment Sella from video?" This is the format for the answers need only one model. The model options are Model Options:[Segment-Video, Segment-MRI, Detect-Video, Overlaying, Surgical-VQA].
# """

# system_message="""
# Select models only from the following list:
# ['Segment-Video', 'Segment-MRI', 'Detect-Video', 'Overlaying', 'Surgical-VQA'].
# For each input question, determine the required models and generate corresponding prompts.

# Output Format:
# - For a single model:
#   Model: <ModelName>
#   Prompt: <CorrespondingPrompt>?

# - For multiple models:
#   Model: <Model1>|<Model2>
#   Prompt: <Prompt1>?|<Prompt2>?
# """

def format_data_test1(sample):
    return [
        {
            "role": "system",
            "content": [
                {
                    "type": "text",
                    "text": system_message
                }
            ],
        },
        # {
        #     "role": "user",
        #     "content": [

        #         {
        #             "type": "text",
        #             "text": sample[0],

        #         }
        #     ],
        # },
        {
            "role": "assistant",
            "content": [
                {
                    "type": "text",
                    "text": sample[1]
                }
            ],
        },
    ]

system_message = generate_SM(test_dataset[0][0])
print(test_dataset[0][0])
input1 = format_data_test1(test_dataset[0])
input2 = format_data_test1(test_dataset[2])
print(input1)
#print(input2)
# print("input: ", input)
# text_input = processor.apply_chat_template(
#         input[:2],  # Use the sample without the system message
#         tokenize=False,
#         add_generation_prompt=True
#     )
# print("text_input: ", text_input)
# input[:2]
output1 = generate_text_from_sample(model, processor, input1)
ans1 = input1[1]['content'][0]['text']
print("output1: ",output1)
print("answer1: ",ans1)
# print("--------------------------------------------")
# output2 = generate_text_from_sample(model, processor, input1)
# ans2 = input2[2]['content'][0]['text']
# print("output2: ",output2)
# print("answer2: ",ans2)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Question: Detect instruments near the Left Carotid and segment the anatomy?
# [{'role': 'system', 'content': [{'type': 'text', 'text': "Select models to answer the following question:\nQuestion: Detect instruments near the Left Carotid and segment the anatomy?\nSelect models only from the following model list: Segment-Video, Segment-MRI, Detect-Video, Overlaying, Surgical-VQA to answer the question.\nGenerate shortest prompts for each chosen model.\nYour response should be like: 'Model: ?| ?\nPrompt: ?| ?' and no other words."}]}, {'role': 'assistant', 'content': [{'type': 'text', 'text': 'Model: Detect-Video|Segment-Video\nPrompt: Detect instruments near Left Carotid?|Segment anatomy from video?'}]}]
# output1:  Model: Segment-MRI| Segment-Video
# Prompt: Segment the anatomy near the Left Carotid in an MRI image| Use a video segmentation model to segment the anatomy near the Left Carotid.
# answer1:  Model: Detect-Video|Segment-Video
# Prompt: Detect instruments near Left Carotid?|Segment anatomy from video?

# %%
all_pred = []
all_ans = []

# %%
model.eval()
with torch.no_grad():
    for sample in test_dataset:
        output = generate_text_from_sample(model, processor, sample)
        ans = sample[1]['content'][0]['text']
        all_pred.append(output)
        all_ans.append(ans)

# %%
import os
import torch
import pickle
from google.colab import drive

drive.mount('/content/drive')
start_index = 0
# 设置保存路径
save_path = '/content/drive/My Drive/Sharing/two-model.pkl'

# 尝试加载之前的进度
if os.path.exists(save_path):
    with open(save_path, 'rb') as f:
        saved_data = pickle.load(f)
        start_index = saved_data['start_index']
        all_pred = saved_data['all_pred']
        all_ans = saved_data['all_ans']
        print(f"Resuming from index {start_index}")
else:
    start_index = 0
    all_pred = []
    all_ans = []
    print("Starting fresh")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Resuming from index 834

# %%
model.eval()
with torch.no_grad():
    for i, sample in enumerate(test_dataset):
        # 跳过已处理的样本
        if i < start_index:
            continue

        output = generate_text_from_sample(model, processor, sample)
        ans = sample[1]['content'][0]['text']
        all_pred.append(output)
        all_ans.append(ans)

        # 更新进度
        start_index = i + 1
        saved_data = {
            'start_index': start_index,
            'all_pred': all_pred,
            'all_ans': all_ans
        }

        # 保存到Google Drive
        with open(save_path, 'wb') as f:
            pickle.dump(saved_data, f)

        print(f"Processed sample {i+1}/{len(test_dataset)}")

print("All samples processed!")
# Out:
# Processed sample 835/2500
# Processed sample 836/2500
# Processed sample 837/2500
# Processed sample 838/2500
# Processed sample 839/2500
# Processed sample 840/2500
# Processed sample 841/2500
# Processed sample 842/2500
# Processed sample 843/2500
# Processed sample 844/2500
# Processed sample 845/2500
# Processed sample 846/2500
# Processed sample 847/2500
# Processed sample 848/2500
# Processed sample 849/2500
# Processed sample 850/2500
# Processed sample 851/2500
# Processed sample 852/2500
# Processed sample 853/2500
# Processed sample 854/2500
# Processed sample 855/2500
# Processed sample 856/2500
# Processed sample 857/2500
# Processed sample 858/2500
# Processed sample 859/2500
# Processed sample 860/2500
# Processed sample 861/2500
# Processed sample 862/2500
# Processed sample 863/2500
# Processed sample 2424/2500
# Processed sample 2425/2500
# Processed sample 2426/2500
# Processed sample 2427/2500
# Processed sample 2428/2500
# Processed sample 2429/2500
# Processed sample 2430/2500
# Processed sample 2431/2500
# Processed sample 2432/2500
# Processed sample 2433/2500
# Processed sample 2434/2500
# Processed sample 2435/2500
# Processed sample 2436/2500
# Processed sample 2437/2500
# Processed sample 2438/2500
# Processed sample 2439/2500
# Processed sample 2440/2500
# Processed sample 2441/2500
# Processed sample 2442/2500
# Processed sample 2443/2500
# Processed sample 2444/2500
# Processed sample 2445/2500
# Processed sample 2446/2500
# Processed sample 2447/2500
# Processed sample 2448/2500
# Processed sample 2449/2500
# Processed sample 2450/2500
# Processed sample 2451/2500
# Processed sample 2452/2500
# Processed sample 2453/2500
# Processed sample 2454/2500
# Processed sample 2455/2500
# Processed sample 2456/2500
# Processed sample 2457/2500
# Processed sample 2458/2500
# Processed sample 2459/2500
# Processed sample 2460/2500
# Processed sample 2461/2500
# Processed sample 2462/2500
# Processed sample 2463/2500
# Processed sample 2464/2500
# Processed sample 2465/2500
# Processed sample 2466/2500
# Processed sample 2467/2500
# Processed sample 2468/2500
# Processed sample 2469/2500
# Processed sample 2470/2500
# Processed sample 2471/2500
# Processed sample 2472/2500
# Processed sample 2473/2500
# Processed sample 2474/2500
# Processed sample 2475/2500
# Processed sample 2476/2500
# Processed sample 2477/2500
# Processed sample 2478/2500
# Processed sample 2479/2500
# Processed sample 2480/2500
# Processed sample 2481/2500
# Processed sample 2482/2500
# Processed sample 2483/2500
# Processed sample 2484/2500
# Processed sample 2485/2500
# Processed sample 2486/2500
# Processed sample 2487/2500
# Processed sample 2488/2500
# Processed sample 2489/2500
# Processed sample 2490/2500
# Processed sample 2491/2500
# Processed sample 2492/2500
# Processed sample 2493/2500
# Processed sample 2494/2500
# Processed sample 2495/2500
# Processed sample 2496/2500
# Processed sample 2497/2500
# Processed sample 2498/2500
# Processed sample 2499/2500
# Processed sample 2500/2500
# All samples processed!

# %%
for i in range(len(all_pred)):
    print("pred:", all_pred[i])
    print("ans:", all_ans[i])
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
# pred: Model: Segment-MRI
# Prompt: Extract left carotid artery information from MRI scans.
# ans: Model: Segment-MRI
# Prompt: Segment left carotid from MRI.
# pred: Model: Segment-MRI
# Prompt: Display an overlay of anatomy segmentation on the surgical field.
# ans: Model: Overlaying
# Prompt: Overlay anatomy segmentation with surgical scene.
# pred: Model: Overlaying
# Prompt: Integrate preoperative imaging with the current surgical view.
# ans: Model: Overlaying
# Prompt: Overlay preoperative imaging with surgical scene.
# pred: Model: Detect-Video
# Prompt: Locate micro doppler in the video and provide its coordinates.
# ans: Model: Detect-Video
# Prompt: Locate micro doppler in the video and provide its coordinates.?
# pred: Model: Detect-Video
# Prompt: Detect all dural scissors in the video and provide their bounding boxes.
# ans: Model: Detect-Video
# Prompt: Provide bounding boxes for all dural scissors detected in the video.?
# pred: Model: Segment-MRI
# Prompt: What are the steps being used?
# ans: Model: Surgical-VQA
# Prompt: which steps is being used?
# pred: Model: Segment-Video
# Prompt: Identify instances where ring curette is actively used in the video.
# ans: Model: Detect-Video
# Prompt: Identify instances where ring curette is actively used in the video.?
# pred: Model: Segment-MRI
# Prompt: What are the current steps in a typical MRI imaging process?
# ans: Model: Surgical-VQA
# Prompt: what is the current steps?
# pred: Model: Segment-MRI
# Prompt: Identify the instrument positions
# ans: Model: Surgical-VQA
# Prompt: can you identify the instrument positions?
# pred: Model: Segment-Video
# Prompt: Segment the anatomical structure of Clival Recess from a given video.
# ans: Model: Segment-Video
# Prompt: Extract clival recess?
# pred: Model: Overlaying
# Prompt: Project MRI imaging onto the live surgical feed.
# ans: Model: Overlaying
# Prompt: Overlay diagnosis MRI with surgical scene.
# pred: Model: Segment-MRI
# Prompt: Perform tumor segmentation on MRI images.
# ans: Model: Segment-MRI
# Prompt: Segment tumor from MRI.
# pred: Model: Segment-MRI
# Prompt: Identify and segment the optic protuberances in MRI images.
# ans: Model: Segment-MRI
# Prompt: Segment optic protuberances from MRI.
# pred: Model: Detect-Video
# Prompt: Detect and highlight all irrigation syringe in the video.
# ans: Model: Detect-Video
# Prompt: Detect and highlight all irrigation syringe in the video.?
# pred: Model: Detect-Video
# Prompt: Detect and label retractable knife with timestamps in the video.
# ans: Model: Detect-Video
# Prompt: Detect and label retractable knife with timestamps in the video.?
# pred: Model: Segment-MRI
# Prompt: Segment the sella from MRI data.
# ans: Model: Segment-MRI
# Prompt: Segment sella from MRI.
# pred: Model: Detect-Video
# Prompt: Identify instruments in the surgical scene.
# ans: Model: Surgical-VQA
# Prompt: locate the instruments in the surgical scene.
# pred: Model: Overlaying
# Prompt: Generate an overlay of diagnosis MRI and surgical scene.
# ans: Model: Overlaying
# Prompt: Overlay preoperative imaging with surgical scene.
# pred: Model: Segment-MRI
# Prompt: The operation note is being used.
# ans: Model: Surgical-VQA
# Prompt: which operation notes is being used?
# pred: Model: Segment-MRI
# Prompt: Segment the detailed anatomy and tumor structure in MRI images.
# ans: Model: Segment-MRI
# Prompt: Segment anatomy and tumor from MRI.
# pred: Model: Segment-MRI
# Prompt: Identify the operation notes.
# ans: Model: Surgical-VQA
# Prompt: which operation notes is being used?
# pred: Model: Overlaying
# Prompt: Overlay preoperative imaging with a 3D model of the organ or area of interest and highlight anatomical structures.
# ans: Model: Overlaying
# Prompt: Overlay preoperative imaging with surgical scene.
# pred: Model: Overlaying
# Prompt: Combine diagnosis MRI and surgical visuals into an overlay.
# ans: Model: Overlaying
# Prompt: Overlay diagnosis MRI with surgical scene.
# pred: Model: Segment-Video
# Prompt: Project tumor segmentation onto live surgical feed.
# ans: Model: Overlaying
# Prompt: Overlay tumor segmentation with surgical scene.
# pred: Model: Segment-MRI
# Prompt: Segment anatomy and tumor from MRI images.
# ans: Model: Segment-MRI
# Prompt: Segment left carotid from MRI.
# pred: Model: Detect-Video
# Prompt: Detect and highlight all freer elevator in the video.
# ans: Model: Detect-Video
# Prompt: Detect and highlight all freer elevator in the video.?
# pred: Model: Segment-Video
# Prompt: Overlay the tumor segmentation on the surgical video.
# ans: Model: Overlaying
# Prompt: Overlay tumor segmentation with surgical scene.
# pred: Model: Detect-Video
# Prompt: Detect and label nasal cutting forceps with timestamps in the video.
# ans: Model: Detect-Video
# Prompt: Detect and label nasal cutting forceps with timestamps in the video.?
# pred: Model: Segment-Video
# Prompt: Identify and mark the exact locations of kerrisons in the video.
# ans: Model: Detect-Video
# Prompt: Mark the exact locations of kerrisons in the video.?
# pred: Model: Segment-MRI
# Prompt: Segment the pituitary region from the provided MRI image.
# ans: Model: Segment-MRI
# Prompt: Segment pituitary region from MRI.
# pred: Model: Segment-MRI
# Prompt: Segment the pituitary region from MRI data.
# ans: Model: Segment-MRI
# Prompt: Segment pituitary region from MRI.
# pred: Model: Overlaying
# Prompt: Integrate preoperative imaging with the current surgical view.
# ans: Model: Overlaying
# Prompt: Overlay preoperative imaging with surgical scene.
# pred: Model: Overlaying
# Prompt: Show an overlay of preoperative imaging and the surgical frame.
# ans: Model: Overlaying
# Prompt: Overlay preoperative imaging with surgical scene.
# pred: Model: Overlaying
# Prompt: Display an overlay of diagnosis MRI on the surgical field.
# ans: Model: Overlaying
# Prompt: Overlay diagnosis MRI with surgical scene.
# pred: Model: Segment-MRI
# Prompt: Identify and segment the optic protuberances in MRI images.
# ans: Model: Segment-MRI
# Prompt: Segment optic protuberances from MRI.
# pred: Model: Segment-Video
# Prompt: Segment the left optic protuberance from a given video frame.
# ans: Model: Segment-Video
# Prompt: Identify left optic protuberance?
# pred: Model: Segment-MRI
# Prompt: Segment the anatomy and tumor from a given MRI image.
# ans: Model: Segment-MRI
# Prompt: Segment anatomical structures from MRI.
# pred: Model: Segment-MRI
# Prompt: Identify the phases.
# ans: Model: Surgical-VQA
# Prompt: can you identify the phases?
# pred: Model: Segment-Video
# Prompt: Generate a map of all spatula dissector positions in the video.
# ans: Model: Detect-Video
# Prompt: Generate a map of all spatula dissector positions in the video.?
# pred: Model: Segment-Video
# Prompt: Overlay MRI diagnosis onto the surgical video.
# ans: Model: Overlaying
# Prompt: Overlay diagnosis MRI with surgical scene.
# pred: Model: Segment-MRI
# Prompt: Segment the anatomy and tumor from MRI images.
# ans: Model: Segment-MRI
# Prompt: Segment sella from MRI.
# pred: Model: Segment-MRI
# Prompt: Identify and segment the left carotid in MRI images.
# ans: Model: Segment-MRI
# Prompt: Segment left carotid from MRI.
# pred: Model: Segment-MRI
# Prompt: Identify the steps being used.
# ans: Model: Surgical-VQA
# Prompt: which steps is being used?
# pred: Model: Segment-MRI
# Prompt: Describe the instrument quantities being used.
# ans: Model: Surgical-VQA
# Prompt: describe the instrument quantities being used.
# pred: Model: Segment-MRI
# Prompt: Analyze and segment the Clival Recess from a given MRI image.
# ans: Model: Segment-Video
# Prompt: Detect clival recess?
# pred: Model: Surgical-VQA
# Prompt: Explain the role of operation notes in a surgical procedure.
# ans: Model: Surgical-VQA
# Prompt: explain the role of the operation notes in this step.
# pred: Model: Segment-MRI
# Prompt: Combine tumor segmentation with MRI visuals into an overlay.
# ans: Model: Overlaying
# Prompt: Overlay tumor segmentation with surgical scene.
# pred: Model: Segment-Video
# Prompt: Segment the right optic protuberance from a given video.
# ans: Model: Segment-Video
# Prompt: Segment right optic protuberance accurately?
# pred: Model: Segment-Video
# Prompt: Segment the regions involving surgical drill in the video.
# ans: Model: Detect-Video
# Prompt: Segment the regions involving surgical drill in the video.?
# pred: Model: Overlaying
# Prompt: Overlay the tumor segmentation data onto the current surgical scene.
# ans: Model: Overlaying
# Prompt: Overlay tumor segmentation with surgical scene.
# pred: Model: Segment-MRI
# Prompt: What are the observations that can be made about the phases in MRI images?
# ans: Model: Surgical-VQA
# Prompt: what observation can be made about the phases?
# pred: Model: Overlaying
# Prompt: Merge the real-time MRI images with surgical video.
# ans: Model: Overlaying
# Prompt: Overlay diagnosis MRI with surgical scene.
# pred: Model: Segment-MRI
# Prompt: Integrate anatomical segmentation from MRI images into the current surgical view.
# ans: Model: Overlaying
# Prompt: Overlay anatomy segmentation with surgical scene.
# pred: Model: Segment-Video
# Prompt: Analyze and segment the Left Optic Protuberance from the given video.
# ans: Model: Segment-Video
# Prompt: Precise segmentation of left optic protuberance?
# pred: Model: Segment-Video
# Prompt: What are the current instrument quantities?
# ans: Model: Surgical-VQA
# Prompt: what is the current instrument quantities?
# pred: Model: Segment-MRI
# Prompt: Identify and segment the sella in MRI images.
# ans: Model: Segment-MRI
# Prompt: Segment sella from MRI.
# pred: Model: Segment-Video
# Prompt: Segment the left carotid artery from the video.
# ans: Model: Segment-Video
# Prompt: Locate left carotid?
# pred: Model: Segment-MRI
# Prompt: Overlay diagnosis MRI and highlight anatomical structures
# ans: Model: Overlaying
# Prompt: Overlay diagnosis MRI with surgical scene.
# pred: Model: Overlaying
# Prompt: Overlay preoperative imaging and highlight anatomical structures.
# ans: Model: Overlaying
# Prompt: Overlay preoperative imaging with surgical scene.
# pred: Model: Overlaying
# Prompt: Overlay preoperative imaging on surgical video.
# ans: Model: Overlaying
# Prompt: Overlay preoperative imaging with surgical scene.
# pred: Model: Segment-Video
# Prompt: Overlay anatomy segmentation on the surgical video.
# ans: Model: Overlaying
# Prompt: Overlay anatomy segmentation with surgical scene.
# pred: Model: Segment-MRI
# Prompt: Segment the anatomy and tumor from MRI images.
# ans: Model: Segment-MRI
# Prompt: Segment optic protuberances from MRI.
# pred: Model: Segment-Video
# Prompt: Analyze and segment the left carotid artery from a video.
# ans: Model: Segment-Video
# Prompt: Segment left carotid?
# pred: Model: Segment-MRI
# Prompt: Segment the sella region from an MRI image.
# ans: Model: Segment-MRI
# Prompt: Segment sella from MRI.
# pred: Model: Detect-Video
# Prompt: Track the movement of a stealth pointer across multiple video frames using computer vision techniques.
# ans: Model: Detect-Video
# Prompt: Track the movement of stealth pointer across video frames.?
# pred: Model: Segment-Video
# Prompt: Segment the region of Left Carotid from the video.
# ans: Model: Segment-Video
# Prompt: Locate and segment left carotid?
# pred: Model: Segment-Video
# Prompt: Identify instances where freer elevator is actively used in the video.
# ans: Model: Detect-Video
# Prompt: Identify instances where freer elevator is actively used in the video.?
# pred: Model: Segment-MRI
# Prompt: Analyze the optic protuberances in the MRI image and segment them.
# ans: Model: Segment-MRI
# Prompt: Segment optic protuberances from MRI.
# pred: Model: Segment-Video
# Prompt: Annotate all visible kerrisons in the video with bounding boxes.
# ans: Model: Detect-Video
# Prompt: Annotate all visible kerrisons in the video with bounding boxes.?
# pred: Model: Segment-Video
# Prompt: Identify the Sella segment in the current frame of the video.
# ans: Model: Segment-Video
# Prompt: Extract sella?
# pred: Model: Segment-Video
# Prompt: Accurately segment Sella from the given video.
# ans: Model: Segment-Video
# Prompt: Extract sella?
# pred: Model: Detect-Video
# Prompt: Locate freer elevator in the video and provide its coordinates.
# ans: Model: Detect-Video
# Prompt: Locate freer elevator in the video and provide its coordinates.?
# pred: Model: Segment-MRI
# Prompt: Describe the instruments being used in a medical MRI environment.
# ans: Model: Surgical-VQA
# Prompt: describe the instruments being used.
# pred: Model: Segment-Video
# Prompt: Identify instances where bipolar forceps is actively used in the video.
# ans: Model: Detect-Video
# Prompt: Identify instances where bipolar forceps is actively used in the video.?
# pred: Model: Segment-MRI
# Prompt: Project tumor segmentation onto the live surgical feed.
# ans: Model: Overlaying
# Prompt: Overlay tumor segmentation with surgical scene.
# pred: Model: Segment-MRI
# Prompt: Extract the clival recess from MRI scans.
# ans: Model: Segment-MRI
# Prompt: Segment clival recess from MRI.
# pred: Model: Detect-Video
# Prompt: Identify instances where irrigation syringe is actively used in the video.
# ans: Model: Detect-Video
# Prompt: Identify instances where irrigation syringe is actively used in the video.?
# pred: Model: Overlaying
# Prompt: Analyze the steps in the overlaying phase.
# ans: Model: Surgical-VQA
# Prompt: analyze the steps in this phase.
# pred: Model: Segment-Video
# Prompt: Locate the surgical drill in the video and provide its coordinates.
# ans: Model: Detect-Video
# Prompt: Locate surgical drill in the video and provide its coordinates.?
# pred: Model: Segment-MRI
# Prompt: Analyze the phases in this phase.
# ans: Model: Surgical-VQA
# Prompt: analyze the phases in this phase.
# pred: Model: Segment-MRI
# Prompt: Identify and segment the tumor in the MRI image.
# ans: Model: Segment-MRI
# Prompt: Segment tumor from MRI.
# pred: Model: Segment-Video
# Prompt: Segment the right carotid artery from a given video.
# ans: Model: Segment-Video
# Prompt: Find right carotid?
# pred: Model: Segment-MRI
# Prompt: Segment the detailed left carotid structure in MRI images.
# ans: Model: Segment-MRI
# Prompt: Segment left carotid from MRI.
# pred: Model: Segment-Video
# Prompt: What are the current instrument quantities?
# ans: Model: Surgical-VQA
# Prompt: what is the current instrument quantities?
# pred: Model: Overlaying
# Prompt: Project preoperative imaging onto the live surgical feed for real-time guidance during surgery.
# ans: Model: Overlaying
# Prompt: Overlay preoperative imaging with surgical scene.
# pred: Model: Surgical-VQA
# Prompt: Analyze the operation notes in this phase.
# ans: Model: Surgical-VQA
# Prompt: analyze the operation notes in this phase.
# pred: Model: Segment-MRI
# Prompt: Integrate the pre-existing anatomy segmentation with the current surgical view.
# ans: Model: Overlaying
# Prompt: Overlay anatomy segmentation with surgical scene.
# pred: Model: Segment-MRI
# Prompt: Segment the optic protuberances from MRI images.
# ans: Model: Segment-MRI
# Prompt: Segment optic protuberances from MRI.
# pred: Model: Segment-Video
# Prompt: What instruments are present in the frame?
# ans: Model: Surgical-VQA
# Prompt: what instrument positions is present in the frame?
# pred: Model: Segment-MRI
# Prompt: Segment the anatomical structure of clival recess from MRI images.
# ans: Model: Segment-MRI
# Prompt: Segment clival recess from MRI.
# pred: Model: Segment-MRI
# Prompt: Combine MRI anatomy segmentation with surgical visuals into an overlay.
# ans: Model: Overlaying
# Prompt: Overlay anatomy segmentation with surgical scene.
# pred: Model: Detect-Video
# Prompt: Detect micro doppler in the video and provide its coordinates.
# ans: Model: Detect-Video
# Prompt: Locate micro doppler in the video and provide its coordinates.?
# pred: Model: Segment-MRI
# Prompt: Segment the clival recess from MRI images.
# ans: Model: Segment-MRI
# Prompt: Segment clival recess from MRI.
# pred: Model: Segment-Video
# Prompt: Segment the right carotid artery from a video feed.
# ans: Model: Segment-Video
# Prompt: Locate right carotid?
# pred: Model: Segment-Video
# Prompt: Segment the right optic protuberance from a video feed.
# ans: Model: Segment-Video
# Prompt: Detect right optic protuberance?
# pred: Model: Segment-Video
# Prompt: Locate and segment the right carotid artery from a given video.
# ans: Model: Segment-Video
# Prompt: Extract right carotid?
# pred: Model: Segment-Video
# Prompt: Segment the left carotid artery from a given video.
# ans: Model: Segment-Video
# Prompt: Segment left carotid accurately?
# pred: Model: Segment-Video
# Prompt: Detect the left optic protuberance in the current frame of the video.
# ans: Model: Segment-Video
# Prompt: Analyze left optic protuberance?
# pred: Model: Segment-MRI
# Prompt: Identify the operation notes.
# ans: Model: Surgical-VQA
# Prompt: can you identify the operation notes?
# pred: Model: Segment-Video
# Prompt: Track the movement of a surgical drill across multiple video frames.
# ans: Model: Detect-Video
# Prompt: Track the movement of surgical drill across video frames.?
# pred: Model: Segment-MRI
# Prompt: What instruments are being used?
# ans: Model: Surgical-VQA
# Prompt: which instruments is being used?
# pred: Model: Detect-Video
# Prompt: Track the movement of a stealth pointer across multiple video frames.
# ans: Model: Detect-Video
# Prompt: Track the movement of stealth pointer across video frames.?
# pred: Model: Segment-MRI
# Prompt: Perform segmentation of clival recess from MRI images.
# ans: Model: Segment-MRI
# Prompt: Segment clival recess from MRI.
# pred: Model: Segment-Video
# Prompt: Identify the segment of the right optic protuberance in the current frame.
# ans: Model: Segment-Video
# Prompt: Locate right optic protuberance?
# pred: Model: Segment-Video
# Prompt: Segment the anatomical structure of the Right Carotid from a given video.
# ans: Model: Segment-Video
# Prompt: Extract right carotid?
# pred: Model: Segment-MRI
# Prompt: Identify and segment the tumor region in the MRI images.
# ans: Model: Segment-MRI
# Prompt: Segment tumor from MRI.
# pred: Model: Segment-MRI
# Prompt: Segment the anatomical structure of sella using MRI.
# ans: Model: Segment-MRI
# Prompt: Segment sella from MRI.
# pred: Model: Segment-Video
# Prompt: Segment the clival recess from a given video.
# ans: Model: Segment-Video
# Prompt: Segment clival recess?
# pred: Model: Detect-Video
# Prompt: Generate a map of all suction positions in the video.
# ans: Model: Detect-Video
# Prompt: Generate a map of all suction positions in the video.?
# pred: Model: Segment-Video
# Prompt: Segment the region of Clival Recess from the given video.
# ans: Model: Segment-Video
# Prompt: Segment clival recess accurately?
# pred: Model: Segment-Video
# Prompt: Identify the Clival Recess from the given video frame.
# ans: Model: Segment-Video
# Prompt: Identify clival recess?
# pred: Model: Segment-Video
# Prompt: Identify the instrument positions in a medical video.
# ans: Model: Surgical-VQA
# Prompt: which instrument positions is being used?
# pred: Model: Overlaying
# Prompt: Combine anatomy segmentation and surgical visuals into an overlay.
# ans: Model: Overlaying
# Prompt: Overlay anatomy segmentation with surgical scene.
# pred: Model: Segment-Video
# Prompt: What is the position of the instrument quantities?
# ans: Model: Surgical-VQA
# Prompt: what is the position of the instrument quantities?
# pred: Model: Segment-MRI
# Prompt: Analyze a video of a human head and segment the Clival Recess.
# ans: Model: Segment-Video
# Prompt: Locate clival recess?
# pred: Model: Overlaying
# Prompt: Display an overlay of tumor segmentation on the surgical field.
# ans: Model: Overlaying
# Prompt: Overlay tumor segmentation with surgical scene.
# pred: Model: Segment-MRI
# Prompt: Extract sella information from MRI scans.
# ans: Model: Segment-MRI
# Prompt: Segment sella from MRI.
# pred: Model: Segment-MRI
# Prompt: What instrument quantities are used?
# ans: Model: Surgical-VQA
# Prompt: which instrument quantities is being used?
# pred: Model: Detect-Video
# Prompt: Detect and highlight all pituitary rongeurs in the video.
# ans: Model: Detect-Video
# Prompt: Detect and highlight all pituitary rongeurs in the video.?
# pred: Model: Segment-Video
# Prompt: Identify the positions of instruments in the surgical scene.
# ans: Model: Surgical-VQA
# Prompt: locate the instrument positions in the surgical scene.
# pred: Model: Segment-Video
# Prompt: Identify the Right Optic Protuberance in a given video frame.
# ans: Model: Segment-Video
# Prompt: Extract right optic protuberance?
# pred: Model: Segment-MRI
# Prompt: Get the current instrument positions.
# ans: Model: Surgical-VQA
# Prompt: what is the current instrument positions?
# pred: Model: Detect-Video
# Prompt: Annotate all visible suction in the video with bounding boxes.
# ans: Model: Detect-Video
# Prompt: Annotate all visible suction in the video with bounding boxes.?
# pred: Model: Segment-MRI
# Prompt: Segment the anatomical structure of anatomy and tumor using MRI images.
# ans: Model: Segment-MRI
# Prompt: Segment anatomy and tumor from MRI.
# pred: Model: Segment-MRI
# Prompt: Overlay the tumor segmentation data onto the current surgical scene.
# ans: Model: Overlaying
# Prompt: Overlay tumor segmentation with surgical scene.
# pred: Model: Overlaying
# Prompt: Generate an MRI and surgical scene overlay with the MRI images as the background and surgical tools as the foreground.
# ans: Model: Overlaying
# Prompt: Overlay diagnosis MRI with surgical scene.
# pred: Model: Segment-MRI
# Prompt: Identify the operation notes.
# ans: Model: Surgical-VQA
# Prompt: can you identify the operation notes?
# pred: Model: Overlaying
# Prompt: Overlay preoperative imaging data onto the current surgical scene.
# ans: Model: Overlaying
# Prompt: Overlay preoperative imaging with surgical scene.
# pred: Model: Segment-MRI
# Prompt: Identify and segment the sella in MRI images.
# ans: Model: Segment-MRI
# Prompt: Segment sella from MRI.
# pred: Model: Overlaying
# Prompt: Combine a diagnosis MRI with a surgical frame.
# ans: Model: Overlaying
# Prompt: Overlay diagnosis MRI with surgical scene.
# pred: Model: Segment-Video
# Prompt: Segment the anatomical structure of Right Carotid from a given video.
# ans: Model: Segment-Video
# Prompt: Find right carotid?
# pred: Model: Segment-MRI
# Prompt: Perform segmentation of clival recess from MRI images.
# ans: Model: Segment-MRI
# Prompt: Segment clival recess from MRI.
# pred: Model: Detect-Video
# Prompt: Track the movement of micro doppler across video frames.
# ans: Model: Detect-Video
# Prompt: Track the movement of micro doppler across video frames.?
# pred: Model: Detect-Video
# Prompt: Detect suction locations in the video.
# ans: Model: Detect-Video
# Prompt: Mark the exact locations of suction in the video.?
# pred: Model: Overlaying
# Prompt: Show an overlay of tumor segmentation and the surgical frame.
# ans: Model: Overlaying
# Prompt: Overlay tumor segmentation with surgical scene.
# pred: Model: Segment-MRI
# Prompt: Identify the phases.
# ans: Model: Surgical-VQA
# Prompt: can you identify the phases?
# pred: Model: Segment-MRI
# Prompt: Identify and segment the tumor margins in MRI images.
# ans: Model: Segment-MRI
# Prompt: Segment tumor margins from MRI.
# pred: Model: Segment-MRI
# Prompt: Segment the detailed left carotid structure in MRI images.
# ans: Model: Segment-MRI
# Prompt: Segment left carotid from MRI.
# pred: Model: Segment-MRI
# Prompt: Identify and segment the pituitary region from the MRI image.
# ans: Model: Segment-MRI
# Prompt: Segment pituitary region from MRI.
# pred: Model: Segment-MRI
# Prompt: Combine MRI anatomy segmentation with surgical visuals into an overlay.
# ans: Model: Overlaying
# Prompt: Overlay anatomy segmentation with surgical scene.
# pred: Model: Segment-MRI
# Prompt: Identify and segment the clival recess in an MRI image.
# ans: Model: Segment-MRI
# Prompt: Segment clival recess from MRI.
# pred: Model: Segment-MRI
# Prompt: Segment the tumor and highlight the anatomical structures in the MRI image.
# ans: Model: Overlaying
# Prompt: Overlay tumor segmentation with surgical scene.
# pred: Model: Segment-MRI
# Prompt: Analyze the tumor margins and segment the tumor from MRI images.
# ans: Model: Segment-MRI
# Prompt: Segment tumor margins from MRI.
# pred: Model: Segment-Video
# Prompt: Project pre-operative anatomy segmentation onto live surgical video feed.
# ans: Model: Overlaying
# Prompt: Overlay anatomy segmentation with surgical scene.
# pred: Model: Segment-MRI
# Prompt: What operation note is being used?
# ans: Model: Surgical-VQA
# Prompt: which operation notes is being used?
# pred: Model: Segment-MRI
# Prompt: Describe the position of the phases in MRI images.
# ans: Model: Surgical-VQA
# Prompt: what is the position of the phases?
# pred: Model: Overlaying
# Prompt: Combine diagnosis MRI and surgical visuals into an overlay.
# ans: Model: Overlaying
# Prompt: Overlay diagnosis MRI with surgical scene.
# pred: Model: Segment-Video
# Prompt: Segment the regions involving surgical drill in the video.
# ans: Model: Detect-Video
# Prompt: Segment the regions involving surgical drill in the video.?
# pred: Model: Detect-Video
# Prompt: Detect and highlight all cup forceps in the video.
# ans: Model: Detect-Video
# Prompt: Detect and highlight all cup forceps in the video.?
# pred: Model: Segment-MRI
# Prompt: Analyze the instrument positions in this phase.
# ans: Model: Surgical-VQA
# Prompt: analyze the instrument positions in this phase.
# pred: Model: Segment-Video
# Prompt: Merge the tumor segmentation images with surgical video in real-time.
# ans: Model: Overlaying
# Prompt: Overlay tumor segmentation with surgical scene.
# pred: Model: Detect-Video
# Prompt: Detect and highlight all surgical drill in the video.
# ans: Model: Detect-Video
# Prompt: Detect and highlight all surgical drill in the video.?
# pred: Model: Detect-Video
# Prompt: Annotate all visible retractable knife in the video with bounding boxes.
# ans: Model: Detect-Video
# Prompt: Annotate all visible retractable knife in the video with bounding boxes.?
# pred: Model: Segment-MRI
# Prompt: Identify steps present in the MRI frame.
# ans: Model: Surgical-VQA
# Prompt: what steps is present in the frame?
# pred: Model: Overlaying
# Prompt: Overlay the tumor segmentation data onto the current surgical scene.
# ans: Model: Overlaying
# Prompt: Overlay tumor segmentation with surgical scene.
# pred: Model: Segment-MRI
# Prompt: Identify and segment the clival recess region from the given MRI image.
# ans: Model: Segment-MRI
# Prompt: Segment clival recess from MRI.
# pred: Model: Segment-MRI
# Prompt: Segment optic protuberances from MRI scans.
# ans: Model: Segment-MRI
# Prompt: Segment optic protuberances from MRI.
# pred: Model: Segment-Video
# Prompt: Segment the Sella from the given video.
# ans: Model: Segment-Video
# Prompt: Detect sella?
# pred: Model: Segment-Video
# Prompt: Identify the left carotid artery in the current frame of the video.
# ans: Model: Segment-Video
# Prompt: Locate left carotid?
# pred: Model: Segment-Video
# Prompt: What observations can be made about the steps?
# ans: Model: Surgical-VQA
# Prompt: what observation can be made about the steps?
# pred: Model: Segment-Video
# Prompt: Generate a map of all spatula dissector positions in the video.
# ans: Model: Detect-Video
# Prompt: Generate a map of all spatula dissector positions in the video.?
# pred: Model: Segment-MRI
# Prompt: Extract anatomical structures from MRI scans.
# ans: Model: Segment-MRI
# Prompt: Segment anatomical structures from MRI.
# pred: Model: Segment-MRI
# Prompt: Analyze the sella and segment it from MRI.
# ans: Model: Segment-MRI
# Prompt: Segment sella from MRI.
# pred: Model: Segment-MRI
# Prompt: Segment the right carotid artery from MRI images.
# ans: Model: Segment-MRI
# Prompt: Segment right carotid from MRI.
# pred: Model: Segment-Video
# Prompt: Identify and segment the left optic protuberance in the current frame of the video.
# ans: Model: Segment-Video
# Prompt: Precise segmentation of left optic protuberance?
# pred: Model: Segment-MRI
# Prompt: Perform segmentation of anatomical structures using MRI.
# ans: Model: Segment-MRI
# Prompt: Segment anatomical structures from MRI.
# pred: Model: Segment-Video
# Prompt: Analyze and segment the right carotid from a video.
# ans: Model: Segment-Video
# Prompt: Locate right carotid?
# pred: Model: Segment-Video
# Prompt: Segment the Clival Recess from a given video.
# ans: Model: Segment-Video
# Prompt: Precise segmentation of clival recess?
# pred: Model: Segment-Video
# Prompt: Analyze and segment the left carotid from a given video.
# ans: Model: Segment-Video
# Prompt: Segment left carotid?
# pred: Model: Segment-MRI
# Prompt: What are the phases being used?
# ans: Model: Surgical-VQA
# Prompt: which phases is being used?
# pred: Model: Segment-Video
# Prompt: Segment the video and mark the exact locations of dural scissors.
# ans: Model: Detect-Video
# Prompt: Mark the exact locations of dural scissors in the video.?
# pred: Model: Segment-MRI
# Prompt: Analyze an MRI image to segment anatomy and tumor.
# ans: Model: Segment-MRI
# Prompt: Segment optic protuberances from MRI.
# pred: Model: Segment-MRI
# Prompt: Explain the role of instrument quantities in image segmentation in medical MRI imaging.
# ans: Model: Surgical-VQA
# Prompt: explain the role of the instrument quantities in this step.
# pred: Model: Overlaying
# Prompt: Overlay the diagnosis MRI onto the surgical video.
# ans: Model: Overlaying
# Prompt: Overlay diagnosis MRI with surgical scene.
# pred: Model: Segment-Video
# Prompt: Segment the regions involving ring curette in the video.
# ans: Model: Detect-Video
# Prompt: Segment the regions involving ring curette in the video.?
# pred: Model: Detect-Video
# Prompt: Detect and label spatula dissector with timestamps in the video.
# ans: Model: Detect-Video
# Prompt: Detect and label spatula dissector with timestamps in the video.?
# pred: Model: Segment-Video
# Prompt: Identify and segment the Left Optic Protuberance in the current frame of the video.
# ans: Model: Segment-Video
# Prompt: Segment left optic protuberance accurately?
# pred: Model: Segment-MRI
# Prompt: What instrument quantities are being used?
# ans: Model: Surgical-VQA
# Prompt: which instrument quantities is being used?
# pred: Model: Segment-MRI
# Prompt: Segment anatomical structures from MRI images.
# ans: Model: Segment-MRI
# Prompt: Segment anatomical structures from MRI.
# pred: Model: Segment-MRI
# Prompt: Identify and segment the anatomical structures in the provided MRI image.
# ans: Model: Segment-MRI
# Prompt: Segment anatomical structures from MRI.
# pred: Model: Segment-Video
# Prompt: Segment the right carotid artery from the video.
# ans: Model: Segment-Video
# Prompt: Detect right carotid?
# pred: Model: Segment-MRI
# Prompt: Segment the clival recess from MRI data.
# ans: Model: Segment-MRI
# Prompt: Segment clival recess from MRI.
# pred: Model: Segment-Video
# Prompt: Locate and segment Sella from the video.
# ans: Model: Segment-Video
# Prompt: Locate sella?
# pred: Model: Segment-MRI
# Prompt: Segment the sella from MRI data.
# ans: Model: Segment-MRI
# Prompt: Segment sella from MRI.
# pred: Model: Detect-Video
# Prompt: Identify instances where bipolar forceps are actively used in the video.
# ans: Model: Detect-Video
# Prompt: Identify instances where bipolar forceps is actively used in the video.?
# pred: Model: Segment-Video
# Prompt: Analyze and segment the Right Optic Protuberance from a given video.
# ans: Model: Segment-Video
# Prompt: Precise segmentation of right optic protuberance?
# pred: Model: Detect-Video
# Prompt: Detect bounding boxes for all objects in the video.
# ans: Model: Detect-Video
# Prompt: Provide bounding boxes for all cottle detected in the video.?
# pred: Model: Segment-Video
# Prompt: Analyze and segment Sella from Video.
# ans: Model: Segment-Video
# Prompt: Precise segmentation of sella?
# pred: Model: Segment-MRI
# Prompt: Integrate tumor segmentation from MRI images with the current surgical view.
# ans: Model: Overlaying
# Prompt: Overlay tumor segmentation with surgical scene.
# pred: Model: Overlaying
# Prompt: Display an overlay of preoperative imaging on the surgical field.
# ans: Model: Overlaying
# Prompt: Overlay preoperative imaging with surgical scene.
# pred: Model: Segment-Video
# Prompt: Annotate all visible tissue glue in the video with bounding boxes.
# ans: Model: Detect-Video
# Prompt: Annotate all visible tissue glue in the video with bounding boxes.?
# pred: Model: Overlaying
# Prompt: Overlay the diagnosis MRI data onto the current surgical scene.
# ans: Model: Overlaying
# Prompt: Overlay diagnosis MRI with surgical scene.
# pred: Model: Overlaying
# Prompt: Show an overlay of preoperative imaging and the surgical frame.
# ans: Model: Overlaying
# Prompt: Overlay preoperative imaging with surgical scene.
# pred: Model: Segment-MRI
# Prompt: Segment anatomical structures using MRI images.
# ans: Model: Segment-MRI
# Prompt: Segment anatomical structures from MRI.
# pred: Model: Segment-MRI
# Prompt: What is the position of the operation notes in the medical report?
# ans: Model: Surgical-VQA
# Prompt: what is the position of the operation notes?
# pred: Model: Detect-Video
# Prompt: Detect all haemostatic foam in the video and provide bounding boxes for each.
# ans: Model: Detect-Video
# Prompt: Provide bounding boxes for all haemostatic foam detected in the video.?
# pred: Model: Overlaying
# Prompt: Combine preoperative imaging and surgical visuals into an overlay, highlighting the key anatomical structures and surgical site for enhanced visualization and understanding.
# ans: Model: Overlaying
# Prompt: Overlay preoperative imaging with surgical scene.
# pred: Model: Segment-Video
# Prompt: Segment the left optic protuberance from a given video frame.
# ans: Model: Segment-Video
# Prompt: Identify left optic protuberance?
# pred: Model: Segment-MRI
# Prompt: Integrate tumor segmentation with the current surgical view.
# ans: Model: Overlaying
# Prompt: Overlay tumor segmentation with surgical scene.
# pred: Model: Detect-Video
# Prompt: Detect all suction events in the video and provide bounding boxes around them.
# ans: Model: Detect-Video
# Prompt: Provide bounding boxes for all suction detected in the video.?
# pred: Model: Detect-Video
# Prompt: Detect all retractable knives in the video and provide their bounding boxes.
# ans: Model: Detect-Video
# Prompt: Provide bounding boxes for all retractable knife detected in the video.?
# pred: Model: Segment-MRI
# Prompt: Segment the detailed anatomy and tumor structure in MRI images.
# ans: Model: Segment-MRI
# Prompt: Segment anatomy and tumor from MRI.
# pred: Model: Detect-Video
# Prompt: Annotate all visible tissue glue in the video with bounding boxes.
# ans: Model: Detect-Video
# Prompt: Annotate all visible tissue glue in the video with bounding boxes.?
# pred: Model: Overlaying
# Prompt: Overlay MRI diagnosis image with a surgical scene image
# ans: Model: Overlaying
# Prompt: Overlay anatomy segmentation with surgical scene.
# pred: Model: Overlaying
# Prompt: Project preoperative imaging onto the live surgical feed in real-time.
# ans: Model: Overlaying
# Prompt: Overlay preoperative imaging with surgical scene.
# pred: Model: Segment-MRI
# Prompt: Analyze the clival recess and segment it from the MRI image.
# ans: Model: Segment-MRI
# Prompt: Segment clival recess from MRI.
# pred: Model: Segment-MRI
# Prompt: Extract the sella information from MRI scans.
# ans: Model: Segment-MRI
# Prompt: Segment sella from MRI.
# pred: Model: Segment-Video
# Prompt: Segment Sella from video frames.
# ans: Model: Segment-Video
# Prompt: Extract sella?
# pred: Model: Segment-MRI
# Prompt: Segment the anatomical structure of sella using MRI images.
# ans: Model: Segment-MRI
# Prompt: Segment sella from MRI.
# pred: Model: Segment-Video
# Prompt: Segment the Left Optic Protuberance from a given video.
# ans: Model: Segment-Video
# Prompt: Locate left optic protuberance?
# pred: Model: Segment-Video
# Prompt: Segment the region of Left Optic Protuberance from the input video.
# ans: Model: Segment-Video
# Prompt: Extract left optic protuberance?
# pred: Model: Segment-MRI
# Prompt: Overlay MRI diagnosis and highlight anatomical structures.
# ans: Model: Overlaying
# Prompt: Overlay diagnosis MRI with surgical scene.
# pred: Model: Segment-Video
# Prompt: Segment Sella from a video.
# ans: Model: Segment-Video
# Prompt: Detect sella?
# pred: Model: Segment-Video
# Prompt: Segment the regions involving pituitary rongeurs in the video.
# ans: Model: Detect-Video
# Prompt: Segment the regions involving pituitary rongeurs in the video.?
# pred: Model: Segment-MRI
# Prompt: Analyze the anatomy and tumor from an MRI image and segment it.
# ans: Model: Segment-MRI
# Prompt: Segment anatomy and tumor from MRI.
# pred: Model: Segment-MRI
# Prompt: Segment the pituitary region from MRI data.
# ans: Model: Segment-MRI
# Prompt: Segment pituitary region from MRI.
# pred: Model: Overlaying
# Prompt: Overlay the MRI diagnosis onto the current surgical scene.
# ans: Model: Overlaying
# Prompt: Overlay diagnosis MRI with surgical scene.
# pred: Model: Overlaying
# Prompt: Overlay preoperative imaging data onto the current surgical scene.
# ans: Model: Overlaying
# Prompt: Overlay preoperative imaging with surgical scene.
# pred: Model: Overlaying
# Prompt: Show an overlay of preoperative imaging and the surgical frame.
# ans: Model: Overlaying
# Prompt: Overlay preoperative imaging with surgical scene.
# pred: Model: Segment-Video
# Prompt: Identify the instruments being used.
# ans: Model: Surgical-VQA
# Prompt: which instruments is being used?
# pred: Model: Segment-MRI
# Prompt: Identify and segment the sella in MRI images.
# ans: Model: Segment-MRI
# Prompt: Segment sella from MRI.
# pred: Model: Segment-MRI
# Prompt: Identify the instruments.
# ans: Model: Surgical-VQA
# Prompt: can you identify the instruments?
# pred: Model: Segment-Video
# Prompt: Segment the left carotid from a video.
# ans: Model: Segment-Video
# Prompt: Locate and segment left carotid?
# pred: Model: Segment-Video
# Prompt: What observations can be made about the instrument positions?
# ans: Model: Surgical-VQA
# Prompt: what observation can be made about the instrument positions?
# pred: Model: Segment-Video
# Prompt: Analyze and segment the Left Optic Protuberance from the given video.
# ans: Model: Segment-Video
# Prompt: Analyze left optic protuberance?
# pred: Model: Overlaying
# Prompt: Overlay the diagnosis MRI data onto the current surgical scene
# ans: Model: Overlaying
# Prompt: Overlay diagnosis MRI with surgical scene.
# pred: Model: Segment-MRI
# Prompt: Identify the instrument quantities.
# ans: Model: Surgical-VQA
# Prompt: can you identify the instrument quantities?
# pred: Model: Segment-Video
# Prompt: What are the typical instrument positions in surgical procedures?
# ans: Model: Surgical-VQA
# Prompt: what is the position of the instrument positions?
# pred: Model: Segment-MRI
# Prompt: What observations can be made about the phases?
# ans: Model: Surgical-VQA
# Prompt: what observation can be made about the phases?
# pred: Model: Segment-Video
# Prompt: Locate and segment the Clival Recess from a given video.
# ans: Model: Segment-Video
# Prompt: Segment clival recess?
# pred: Model: Detect-Video
# Prompt: Detect and label cottle with timestamps in the video.
# ans: Model: Detect-Video
# Prompt: Detect and label cottle with timestamps in the video.?
# pred: Model: Segment-Video
# Prompt: Analyze the instrument positions in this phase.
# ans: Model: Surgical-VQA
# Prompt: analyze the instrument positions in this phase.
# pred: Model: Detect-Video
# Prompt: Identify the exact locations of suction in the video.
# ans: Model: Detect-Video
# Prompt: Mark the exact locations of suction in the video.?
# pred: Model: Overlaying
# Prompt: Merge MRI images with surgical video in real-time.
# ans: Model: Overlaying
# Prompt: Overlay diagnosis MRI with surgical scene.
# pred: Model: Segment-Video
# Prompt: Identify and segment the left optic protuberance in the current frame of the video.
# ans: Model: Segment-Video
# Prompt: Segment left optic protuberance accurately?
# pred: Model: Overlaying
# Prompt: Combine MRI and surgical visuals into an overlay.
# ans: Model: Overlaying
# Prompt: Overlay diagnosis MRI with surgical scene.
# pred: Model: Segment-MRI
# Prompt: Segment the detailed right carotid structure in MRI images.
# ans: Model: Segment-MRI
# Prompt: Segment right carotid from MRI.
# pred: Model: Overlaying
# Prompt: Overlay anatomical structures onto an image.
# ans: Model: Overlaying
# Prompt: Overlay anatomy segmentation with surgical scene.
# pred: Model: Segment-Video
# Prompt: Segment the regions involving stealth pointer in the video.
# ans: Model: Detect-Video
# Prompt: Segment the regions involving stealth pointer in the video.?
# pred: Model: Segment-MRI
# Prompt: Segment the sella from MRI data.
# ans: Model: Segment-MRI
# Prompt: Segment sella from MRI.
# pred: Model: Segment-MRI
# Prompt: Segment anatomical structures from MRI images.
# ans: Model: Segment-MRI
# Prompt: Segment anatomical structures from MRI.
# pred: Model: Segment-Video
# Prompt: Analyze and segment Sella from Video.
# ans: Model: Segment-Video
# Prompt: Analyze sella?
# pred: Model: Segment-MRI
# Prompt: Segment the clival recess from MRI images.
# ans: Model: Segment-MRI
# Prompt: Segment clival recess from MRI.
# pred: Model: Detect-Video
# Prompt: Identify instances where freer elevator is actively used in the video.
# ans: Model: Detect-Video
# Prompt: Identify instances where freer elevator is actively used in the video.?
# pred: Model: Segment-Video
# Prompt: Segment the right carotid artery from a given video.
# ans: Model: Segment-Video
# Prompt: Precise segmentation of right carotid?
# pred: Model: Segment-MRI
# Prompt: Analyze the instrument quantities in this phase.
# ans: Model: Surgical-VQA
# Prompt: analyze the instrument quantities in this phase.
# pred: Model: Segment-Video
# Prompt: Analyze and segment the left carotid from the video.
# ans: Model: Segment-Video
# Prompt: Analyze left carotid?
# pred: Model: Segment-MRI
# Prompt: Describe the steps being used.
# ans: Model: Surgical-VQA
# Prompt: describe the steps being used.
# pred: Model: Segment-MRI
# Prompt: What instrument quantities are being used?
# ans: Model: Surgical-VQA
# Prompt: which instrument quantities is being used?
# pred: Model: Segment-MRI
# Prompt: Identify and segment the right carotid in this MRI image.
# ans: Model: Segment-MRI
# Prompt: Segment right carotid from MRI.
# pred: Model: Overlaying
# Prompt: Overlay diagnosis MRI and highlight anatomical structures.
# ans: Model: Overlaying
# Prompt: Overlay diagnosis MRI with surgical scene.
# pred: Model: Segment-Video
# Prompt: Segment the regions involving bipolar forceps in the video.
# ans: Model: Detect-Video
# Prompt: Segment the regions involving bipolar forceps in the video.?
# pred: Model: Overlaying
# Prompt: Combine preoperative imaging and surgical visuals into an overlay for comparison and reference during surgery.
# ans: Model: Overlaying
# Prompt: Overlay preoperative imaging with surgical scene.
# pred: Model: Segment-Video
# Prompt: Segment the region of Right Optic Protuberance from the given video.
# ans: Model: Segment-Video
# Prompt: Extract right optic protuberance?
# pred: Model: Segment-Video
# Prompt: Identify the Clival Recess from a given video of the skull.
# ans: Model: Segment-Video
# Prompt: Locate clival recess?
# pred: Model: Segment-MRI
# Prompt: Identify the steps.
# ans: Model: Surgical-VQA
# Prompt: can you identify the steps?
# pred: Model: Segment-Video
# Prompt: Segment the region of Left Carotid from the video.
# ans: Model: Segment-Video
# Prompt: Identify left carotid?
# pred: Model: Segment-MRI
# Prompt: Extract the tumor margins information from MRI scans.
# ans: Model: Segment-MRI
# Prompt: Segment tumor margins from MRI.
# pred: Model: Segment-Video
# Prompt: Overlay the anatomy segmentation on the surgical video.
# ans: Model: Overlaying
# Prompt: Overlay anatomy segmentation with surgical scene.
# pred: Model: Detect-Video
# Prompt: Identify instances where an irrigation syringe is actively used in the video.
# ans: Model: Detect-Video
# Prompt: Identify instances where irrigation syringe is actively used in the video.?
# pred: Model: Segment-Video
# Prompt: Segment the regions involving cup forceps in the video.
# ans: Model: Detect-Video
# Prompt: Segment the regions involving cup forceps in the video.?
# pred: Model: Segment-MRI
# Prompt: Segment the detailed anatomy and tumor structure in MRI images.
# ans: Model: Segment-MRI
# Prompt: Segment anatomy and tumor from MRI.
# pred: Model: Segment-MRI
# Prompt: Describe the instrument positions being used.
# ans: Model: Surgical-VQA
# Prompt: describe the instrument positions being used.
# pred: Model: Segment-MRI
# Prompt: Segment anatomical structures from MRI images.
# ans: Model: Segment-MRI
# Prompt: Segment anatomical structures from MRI.
# pred: Model: Segment-Video
# Prompt: Segment the anatomical structure of Left Carotid from the given video.
# ans: Model: Segment-Video
# Prompt: Find left carotid?
# pred: Model: Overlaying
# Prompt: Display an overlay of preoperative imaging on the surgical field to assist the surgeon during the operation.
# ans: Model: Overlaying
# Prompt: Overlay preoperative imaging with surgical scene.
# pred: Model: Overlaying
# Prompt: Integrate tumor segmentation with the current surgical view.
# ans: Model: Overlaying
# Prompt: Overlay tumor segmentation with surgical scene.
# pred: Model: Segment-Video
# Prompt: Analyze and segment the Left Optic Protuberance from the video.
# ans: Model: Segment-Video
# Prompt: Analyze left optic protuberance?
# pred: Model: Segment-Video
# Prompt: What are the positions of the instruments?
# ans: Model: Surgical-VQA
# Prompt: what is the position of the instruments?
# pred: Model: Segment-MRI
# Prompt: Project MRI imaging onto the live surgical feed.
# ans: Model: Overlaying
# Prompt: Overlay diagnosis MRI with surgical scene.
# pred: Model: Segment-Video
# Prompt: Identify the Clival Recess from the given video.
# ans: Model: Segment-Video
# Prompt: Detect clival recess?
# pred: Model: Segment-Video
# Prompt: Segment the regions involving irrigation syringe in the video.
# ans: Model: Detect-Video
# Prompt: Segment the regions involving irrigation syringe in the video.?
# pred: Model: Detect-Video
# Prompt: Locate the stealth pointer in the video and provide its coordinates.
# ans: Model: Detect-Video
# Prompt: Locate stealth pointer in the video and provide its coordinates.?
# pred: Model: Segment-MRI
# Prompt: Identify and segment the right carotid region in the MRI image.
# ans: Model: Segment-MRI
# Prompt: Segment right carotid from MRI.
# pred: Model: Segment-MRI
# Prompt: Analyze the instrument positions in this phase.
# ans: Model: Surgical-VQA
# Prompt: analyze the instrument positions in this phase.
# pred: Model: Segment-Video
# Prompt: Segment the left carotid artery from a given video.
# ans: Model: Segment-Video
# Prompt: Locate and segment left carotid?
# pred: Model: Segment-Video
# Prompt: Segment the region of Clival Recess from the input video.
# ans: Model: Segment-Video
# Prompt: Detect clival recess?
# pred: Model: Segment-Video
# Prompt: Segment the left optic protuberance in the current frame of the video.
# ans: Model: Segment-Video
# Prompt: Locate left optic protuberance?
# pred: Model: Segment-MRI
# Prompt: Analyze the phases in this phase.
# ans: Model: Surgical-VQA
# Prompt: analyze the phases in this phase.
# pred: Model: Overlaying
# Prompt: Overlay preoperative imaging and highlight anatomical structures.
# ans: Model: Overlaying
# Prompt: Overlay preoperative imaging with surgical scene.
# pred: Model: Segment-Video
# Prompt: Locate and segment the right carotid from a given video.
# ans: Model: Segment-Video
# Prompt: Identify right carotid?
# pred: Model: Segment-MRI
# Prompt: Identify the phases.
# ans: Model: Surgical-VQA
# Prompt: can you identify the phases?
# pred: Model: Segment-Video
# Prompt: Locate and segment the Left Optic Protuberance from a given video.
# ans: Model: Segment-Video
# Prompt: Segment left optic protuberance?
# pred: Model: Overlaying
# Prompt: Display an overlay of preoperative imaging on the surgical field.
# ans: Model: Overlaying
# Prompt: Overlay preoperative imaging with surgical scene.
# pred: Model: Segment-Video
# Prompt: Identify the left carotid artery in the current frame of the video.
# ans: Model: Segment-Video
# Prompt: Detect left carotid?
# pred: Model: Detect-Video
# Prompt: Detect retractable knives in the video and provide their bounding boxes.
# ans: Model: Detect-Video
# Prompt: Provide bounding boxes for all retractable knife detected in the video.?
# pred: Model: Segment-MRI
# Prompt: Describe the position of instrument positions in a medical context.
# ans: Model: Surgical-VQA
# Prompt: what is the position of the instrument positions?
# pred: Model: Detect-Video
# Prompt: Detect spatula dissector in the video and provide bounding boxes for all detected objects.
# ans: Model: Detect-Video
# Prompt: Provide bounding boxes for all spatula dissector detected in the video.?
# pred: Model: Segment-MRI
# ...
# ans: Model: Segment-MRI
# Prompt: Segment left carotid from MRI.
# pred: Model: Segment-MRI
# Prompt: Identify the phases.
# ans: Model: Surgical-VQA
# Prompt: can you identify the phases?
# pred: Model: Segment-MRI
# Prompt: Segment the pituitary region from MRI images.
# ans: Model: Segment-MRI
# Prompt: Segment pituitary region from MRI.
# pred: Model: Segment-Video
# Prompt: What are the current instrument quantities?
# ans: Model: Surgical-VQA
# Prompt: what is the current instrument quantities?
# pred: Model: Segment-MRI
# Prompt: Analyze the tumor and segment it from the MRI image.
# ans: Model: Segment-MRI
# Prompt: Segment tumor from MRI.
# pred: Model: Segment-MRI
# Prompt: Segment the anatomy and tumor from the provided MRI images.
# ans: Model: Segment-MRI
# Prompt: Segment sella from MRI.
# pred: Model: Detect-Video
# Prompt: Identify the instruments in the surgical scene.
# ans: Model: Surgical-VQA
# Prompt: locate the instruments in the surgical scene.
# pred: Model: Segment-Video
# Prompt: What instruments are present in the frame?
# ans: Model: Surgical-VQA
# Prompt: what instruments is present in the frame?
# pred: Model: Segment-Video
# Prompt: Analyze and segment Clival Recess from a given video.
# ans: Model: Segment-Video
# Prompt: Segment clival recess accurately?
# pred: Model: Detect-Video
# Prompt: Track the movement of bipolar forceps across video frames.
# ans: Model: Detect-Video
# Prompt: Track the movement of bipolar forceps across video frames.?
# pred: Model: Segment-MRI
# Prompt: Perform segmentation of optic protuberances using MRI.
# ans: Model: Segment-MRI
# Prompt: Segment optic protuberances from MRI.
# pred: Model: Segment-MRI
# Prompt: Segment the anatomical structure of the right carotid using MRI images.
# ans: Model: Segment-MRI
# Prompt: Segment right carotid from MRI.
# pred: Model: Detect-Video
# Prompt: Detect all spatula dissector objects in the video and provide their bounding boxes.
# ans: Model: Detect-Video
# Prompt: Provide bounding boxes for all spatula dissector detected in the video.?
# pred: Model: Detect-Video
# Prompt: Detect and label retractable knife with timestamps in the video.
# ans: Model: Detect-Video
# Prompt: Detect and label retractable knife with timestamps in the video.?
# pred: Model: Segment-Video
# Prompt: Segment Sella from Video
# ans: Model: Segment-Video
# Prompt: Segment sella?
# pred: Model: Overlaying
# Prompt: Show an overlay of anatomy segmentation and the surgical frame.
# ans: Model: Overlaying
# Prompt: Overlay anatomy segmentation with surgical scene.
# pred: Model: Segment-Video
# Prompt: Segment the left carotid artery from a given video.
# ans: Model: Segment-Video
# Prompt: Segment left carotid?
# pred: Model: Segment-MRI
# Prompt: Perform segmentation of anatomy and tumor using MRI images.
# ans: Model: Segment-MRI
# Prompt: Segment anatomy and tumor from MRI.
# pred: Model: Segment-MRI
# Prompt: Segment the anatomy and tumor from MRI images.
# ans: Model: Segment-MRI
# Prompt: Segment anatomy and tumor from MRI.
# pred: Model: Segment-Video
# Prompt: Segment the Clival Recess from the given video.
# ans: Model: Segment-Video
# Prompt: Segment clival recess?
# pred: Model: Segment-MRI
# Prompt: Identify the instrument position in an MRI scan.
# ans: Model: Surgical-VQA
# Prompt: which instrument positions is being used?
# pred: Model: Segment-Video
# Prompt: What observation can be made about the instrument positions?
# ans: Model: Surgical-VQA
# Prompt: what observation can be made about the instrument positions?
# pred: Model: Segment-MRI
# Prompt: Extract optic protuberances information from MRI scans.
# ans: Model: Segment-MRI
# Prompt: Segment optic protuberances from MRI.
# pred: Model: Segment-Video
# Prompt: What instrument quantities are being used?
# ans: Model: Surgical-VQA
# Prompt: which instrument quantities is being used?
# pred: Model: Segment-Video
# Prompt: Annotate kerrisons in the video with exact locations.
# ans: Model: Detect-Video
# Prompt: Mark the exact locations of kerrisons in the video.?
# pred: Model: Segment-MRI
# Prompt: Analyze an MRI image to segment anatomy and tumor.
# ans: Model: Segment-MRI
# Prompt: Segment right carotid from MRI.
# pred: Model: Segment-Video
# Prompt: Identify and segment the right optic protuberance from a given video.
# ans: Model: Segment-Video
# Prompt: Precise segmentation of right optic protuberance?
# pred: Model: Segment-Video
# Prompt: Identify instances where irrigation syringe is actively used in the video.
# ans: Model: Detect-Video
# Prompt: Identify instances where irrigation syringe is actively used in the video.?
# pred: Model: Detect-Video
# Prompt: Detect and label spatula dissector with timestamps in the video.
# ans: Model: Detect-Video
# Prompt: Detect and label spatula dissector with timestamps in the video.?
# pred: Model: Segment-MRI
# Prompt: Identify the operation notes.
# ans: Model: Surgical-VQA
# Prompt: can you identify the operation notes?
# pred: Model: Detect-Video
# Prompt: Annotate all visible kerrisons in the video with bounding boxes.
# ans: Model: Detect-Video
# Prompt: Annotate all visible kerrisons in the video with bounding boxes.?
# pred: Model: Segment-Video
# Prompt: Locate the irrigation syringe in the video and provide its coordinates.
# ans: Model: Detect-Video
# Prompt: Locate irrigation syringe in the video and provide its coordinates.?
# pred: Model: Overlaying
# Prompt: Integrate MRI diagnosis with the current surgical view.
# ans: Model: Overlaying
# Prompt: Overlay diagnosis MRI with surgical scene.
# pred: Model: Overlaying
# Prompt: Generate an overlay of diagnosis MRI and surgical scene.
# ans: Model: Overlaying
# Prompt: Overlay diagnosis MRI with surgical scene.
# pred: Model: Segment-Video
# Prompt: Segment the regions involving bipolar forceps in the video.
# ans: Model: Detect-Video
# Prompt: Segment the regions involving bipolar forceps in the video.?
# pred: Model: Detect-Video
# Prompt: Generate a map of all haemostatic foam positions in the video.
# ans: Model: Detect-Video
# Prompt: Generate a map of all haemostatic foam positions in the video.?
# pred: Model: Segment-Video
# Prompt: Segment the anatomical structure of Right Optic Protuberance from a given video.
# ans: Model: Segment-Video
# Prompt: Identify right optic protuberance?
# pred: Model: Segment-Video
# Prompt: Segment the region of Left Optic Protuberance from the video.
# ans: Model: Segment-Video
# Prompt: Segment left optic protuberance accurately?
# pred: Model: Segment-MRI
# Prompt: Describe the current phases of the human body.
# ans: Model: Surgical-VQA
# Prompt: what is the current phases?
# pred: Model: Detect-Video
# Prompt: Describe the steps being used.
# ans: Model: Surgical-VQA
# Prompt: describe the steps being used.
# pred: Model: Segment-Video
# Prompt: Segment the video and mark the exact locations of dural scissors.
# ans: Model: Detect-Video
# Prompt: Mark the exact locations of dural scissors in the video.?
# pred: Model: Detect-Video
# Prompt: Locate freer elevator in the video and provide its coordinates.
# ans: Model: Detect-Video
# Prompt: Locate freer elevator in the video and provide its coordinates.?
# pred: Model: Overlaying
# Prompt: Project MRI imaging onto the live surgical feed.
# ans: Model: Overlaying
# Prompt: Overlay diagnosis MRI with surgical scene.
# pred: Model: Segment-Video
# Prompt: Locate and segment the Left Optic Protuberance from a given video.
# ans: Model: Segment-Video
# Prompt: Segment left optic protuberance?
# pred: Model: Segment-MRI
# Prompt: Display an overlay of tumor segmentation on the surgical field from MRI images.
# ans: Model: Overlaying
# Prompt: Overlay tumor segmentation with surgical scene.
# pred: Model: Overlaying
# Prompt: Overlay anatomy segmentation on the surgical frame
# ans: Model: Overlaying
# Prompt: Overlay anatomy segmentation with surgical scene.
# pred: Model: Segment-MRI
# Prompt: Segment the anatomical structure of anatomical structures using MRI images.
# ans: Model: Segment-MRI
# Prompt: Segment anatomical structures from MRI.
# pred: Model: Segment-MRI
# Prompt: Segment optic protuberances from MRI images.
# ans: Model: Segment-MRI
# Prompt: Segment optic protuberances from MRI.
# pred: Model: Segment-Video
# Prompt: Segment the Clival Recess from the given video.
# ans: Model: Segment-Video
# Prompt: Segment clival recess accurately?
# pred: Model: Overlaying
# Prompt: Overlay preoperative imaging and highlight anatomical structures.
# ans: Model: Overlaying
# Prompt: Overlay preoperative imaging with surgical scene.
# pred: Model: Segment-MRI
# Prompt: Describe the phases being used.
# ans: Model: Surgical-VQA
# Prompt: describe the phases being used.
# pred: Model: Segment-MRI
# Prompt: Segment the anatomy and tumor from the provided MRI images.
# ans: Model: Segment-MRI
# Prompt: Segment right carotid from MRI.
# pred: Model: Segment-MRI
# Prompt: Locate and segment the left carotid region in MRI images.
# ans: Model: Segment-MRI
# Prompt: Segment left carotid from MRI.
# pred: Model: Segment-Video
# Prompt: Segment the left optic protuberance in the current frame of the video.
# ans: Model: Segment-Video
# Prompt: Segment left optic protuberance accurately?
# pred: Model: Segment-Video
# Prompt: Identify instances where bipolar forceps are actively used in the video.
# ans: Model: Detect-Video
# Prompt: Identify instances where bipolar forceps is actively used in the video.?
# pred: Model: Segment-Video
# Prompt: Detect the left optic protuberance in the current frame of the video.
# ans: Model: Segment-Video
# Prompt: Analyze left optic protuberance?
# pred: Model: Segment-Video
# Prompt: Segment the regions involving pituitary rongeurs in the video.
# ans: Model: Detect-Video
# Prompt: Segment the regions involving pituitary rongeurs in the video.?
# pred: Model: Segment-MRI
# Prompt: Explain the role of the steps in this step.
# ans: Model: Surgical-VQA
# Prompt: explain the role of the steps in this step.
# pred: Model: Detect-Video
# Prompt: Generate a map of all retractable knife positions in the video.
# ans: Model: Detect-Video
# Prompt: Generate a map of all retractable knife positions in the video.?
# pred: Model: Segment-Video
# Prompt: Locate and segment the Left Optic Protuberance from a given video.
# ans: Model: Segment-Video
# Prompt: Precise segmentation of left optic protuberance?
# pred: Model: Segment-MRI
# Prompt: Project pre-operative tumor segmentation onto live surgical feed.
# ans: Model: Overlaying
# Prompt: Overlay tumor segmentation with surgical scene.
# pred: Model: Detect-Video
# Prompt: Detect and label tissue glue with timestamps in the video.
# ans: Model: Detect-Video
# Prompt: Detect and label tissue glue with timestamps in the video.?
# pred: Model: Overlaying
# Prompt: Overlay the diagnosis MRI data onto the current surgical scene.
# ans: Model: Overlaying
# Prompt: Overlay diagnosis MRI with surgical scene.
# pred: Model: Segment-MRI
# Prompt: Extract anatomical structures from MRI scans.
# ans: Model: Segment-MRI
# Prompt: Segment anatomical structures from MRI.
# pred: Model: Detect-Video
# Prompt: Detect and highlight all freer elevator in the video.
# ans: Model: Detect-Video
# Prompt: Detect and highlight all freer elevator in the video.?
# pred: Model: Segment-Video
# Prompt: Segment the left optic protuberance from the given video frames.
# ans: Model: Segment-Video
# Prompt: Precise segmentation of left optic protuberance?
# pred: Model: Segment-MRI
# Prompt: What is the position of the operation notes?
# ans: Model: Surgical-VQA
# Prompt: what is the position of the operation notes?
# pred: Model: Segment-MRI
# Prompt: Segment the anatomical structure of optic protuberances from MRI images.
# ans: Model: Segment-MRI
# Prompt: Segment optic protuberances from MRI.
# pred: Model: Segment-Video
# Prompt: Segment the right optic protuberance from a given video.
# ans: Model: Segment-Video
# Prompt: Find right optic protuberance?
# pred: Model: Segment-MRI
# Prompt: List the current phases.
# ans: Model: Surgical-VQA
# Prompt: what is the current phases?
# pred: Model: Segment-Video
# Prompt: Segment the Left Optic Protuberance from the given video frames.
# ans: Model: Segment-Video
# Prompt: Analyze left optic protuberance?
# pred: Model: Segment-MRI
# Prompt: Segment the optic protuberances region in MRI images.
# ans: Model: Segment-MRI
# Prompt: Segment optic protuberances from MRI.
# pred: Model: Segment-Video
# Prompt: Analyze and segment the right carotid artery from a video.
# ans: Model: Segment-Video
# Prompt: Locate right carotid?
# pred: Model: Detect-Video
# Prompt: Locate the stealth pointer in the video and provide its coordinates.
# ans: Model: Detect-Video
# Prompt: Locate stealth pointer in the video and provide its coordinates.?
# pred: Model: Segment-MRI
# Prompt: Overlay preoperative imaging with anatomical structures and highlight key areas of interest.
# ans: Model: Overlaying
# Prompt: Overlay preoperative imaging with surgical scene.
# pred: Model: Segment-MRI
# Prompt: What is the position of the instrument quantities in the context of MRI imaging?
# ans: Model: Surgical-VQA
# Prompt: what is the position of the instrument quantities?
# pred: Model: Segment-MRI
# Prompt: Summarize the current operation notes.
# ans: Model: Surgical-VQA
# Prompt: what is the current operation notes?
# pred: Model: Segment-MRI
# Prompt: Segment the detailed anatomical structures in MRI images.
# ans: Model: Segment-MRI
# Prompt: Segment anatomical structures from MRI.
# pred: Model: Overlaying
# Prompt: Generate an overlay of diagnosis MRI image and surgical scene for comparison and analysis.
# ans: Model: Overlaying
# Prompt: Overlay diagnosis MRI with surgical scene.
# pred: Model: Segment-MRI
# Prompt: Display current operation notes.
# ans: Model: Surgical-VQA
# Prompt: what is the current operation notes?
# pred: Model: Segment-MRI
# Prompt: Segment the anatomical structure of the left carotid artery from MRI images.
# ans: Model: Segment-MRI
# Prompt: Segment left carotid from MRI.
# pred: Model: Detect-Video
# Prompt: Locate the operation notes in the surgical scene.
# ans: Model: Surgical-VQA
# Prompt: locate the operation notes in the surgical scene.
# pred: Model: Segment-Video
# Prompt: Describe the instrument positions.
# ans: Model: Surgical-VQA
# Prompt: describe the instrument positions being used.
# pred: Model: Segment-Video
# Prompt: Segment the video into frames and detect the nasal cutting forceps in each frame, then create a map of their positions.
# ans: Model: Detect-Video
# Prompt: Generate a map of all nasal cutting forceps positions in the video.?
# pred: Model: Overlaying
# Prompt: Merge preoperative imaging images with real-time surgical video.
# ans: Model: Overlaying
# Prompt: Overlay preoperative imaging with surgical scene.
# pred: Model: Segment-MRI
# Prompt: Analyze the left carotid artery from an MRI scan and segment it from surrounding tissues.
# ans: Model: Segment-MRI
# Prompt: Segment left carotid from MRI.
# pred: Model: Overlaying
# Prompt: Combine preoperative imaging and surgical visuals into an overlay to enhance surgical planning and visualization.
# ans: Model: Overlaying
# Prompt: Overlay preoperative imaging with surgical scene.
# pred: Model: Segment-Video
# Prompt: Annotate all visible haemostatic foam in the video with bounding boxes.
# ans: Model: Detect-Video
# Prompt: Annotate all visible haemostatic foam in the video with bounding boxes.?
# pred: Model: Segment-MRI
# Prompt: What can be observed about the instrument quantities in the MRI segment?
# ans: Model: Surgical-VQA
# Prompt: what observation can be made about the instrument quantities?
# pred: Model: Segment-MRI
# Prompt: Segment the right carotid artery from MRI images.
# ans: Model: Segment-MRI
# Prompt: Segment right carotid from MRI.
# pred: Model: Detect-Video
# Prompt: Provide bounding boxes for all suction detected in the video.
# ans: Model: Detect-Video
# Prompt: Provide bounding boxes for all suction detected in the video.?
# pred: Model: Segment-MRI
# Prompt: Analyze the anatomy and tumor from an MRI image, then segment the tumor.
# ans: Model: Segment-MRI
# Prompt: Segment anatomy and tumor from MRI.
# pred: Model: Segment-MRI
# Prompt: Segment the anatomy and tumor from MRI data.
# ans: Model: Segment-MRI
# Prompt: Segment anatomy and tumor from MRI.
# pred: Model: Segment-Video
# Prompt: Segment the left optic protuberance from a given video.
# ans: Model: Segment-Video
# Prompt: Locate and segment left optic protuberance?

# %%
import os
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')

# File Path
output_file_path = '/content/drive/My Drive/pre_ans_SINGLE.txt'

# Write data
with open(output_file_path, 'w') as file:
    for i in range(len(all_pred)):
        file.write(f"pred: {all_pred[i]}\n")
        file.write(f"ans: {all_ans[i]}\n")
        file.write("\n")  # 添加换行以便于阅读

print(f"file saved at: {output_file_path}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# file saved at: /content/drive/My Drive/pre_ans_SINGLE.txt

# %%
## 定义新的变量来存储提取的 Prompt 部分
all_pred_prompts = []
all_ans_prompts = []

# 提取 Prompt 部分的函数
# def extract_prompt(entry):
#     for line in entry.split('\n'):
#         if line.startswith("Prompt:"):
#             return line[len("Prompt: "):]  # 去掉 "Prompt: " 保留内容

def extract_prompt(entry):
    # 用列表解析找到所有以 "Prompt:" 开头的行，并提取内容
    prompts = [line[len("Prompt: "):].strip() for line in entry.split('\n') if line.startswith("Prompt:")]
    # 用 "|" 将所有提取的内容连接成一个字符串
    return "|".join(prompts) if prompts else ""

# 提取 all_pred 和 all_ans 中的 Prompt 部分
all_pred_prompts = [extract_prompt(item) for item in all_pred]
all_ans_prompts = [extract_prompt(item) for item in all_ans]

# 打印结果验证
print("Extracted Prompts from all_pred:", all_pred_prompts)
print("Extracted Prompts from all_ans:", all_ans_prompts)
print(len(all_pred_prompts))
print(len(all_ans_prompts))
# Out:
# Extracted Prompts from all_pred: ['Segment the nasal cavity structures and provide a detailed 3D reconstruction. Overlay the surgical pathway for better guidance and patient education.', 'Analyze the current surgical view using MRI and video data. Enhance the view for better visualization.', 'Identify vascular landmarks on MRI images and measure their proximity to the tumor.', 'Analyze and enhance the current surgical view using MRI and video segmentation tools to provide a clearer image.', 'Identify vascular landmarks and calculate their proximity to the tumor in MRI images. Provide distances in millimeters.', 'Identify vascular landmarks in MRI images and assess their proximity to the tumor.', 'Analyze the current surgical view to identify key anatomical structures and enhance the image for better visibility.', 'Detect the suction tool and overlay its path relative to the tumor margin.', 'Analyze the current surgical view using MRI segmentation to identify relevant anatomical structures and detect any instruments in the scene to enhance the visualization.', 'Segment the brain from the MRI image and overlay surgical instruments near the tumor.', 'Use MRI segmentation to identify key vascular landmarks and assess their proximity to the tumor.', 'Segment the nasal cavity structures and overlay the surgical pathway for better guidance.', 'Analyze the current surgical view to identify relevant anatomical structures and instruments.', 'Analyze and enhance the current surgical view using the video and MRI images.', 'Segment the nasal cavity structures and provide an overlay of the surgical pathway for better guidance.', 'Segment a pre-operative MRI of a patient with a tumor, then overlay vascular landmarks on the MRI to identify proximity to the tumor.', 'Analyze the current surgical view to identify relevant anatomical structures and enhance the image quality.', "Analyze the tumor's MRI and video images to identify vascular landmarks and determine their proximity to the tumor. Provide a detailed report on the distances and spatial relationships between the landmarks and the tumor.", 'Segment the brain from the MRI image and highlight the tumor. Identify the position of surgical instruments near it.', "Analyze the current surgical view to identify potential issues or complications. Provide a detailed breakdown of the patient's anatomy and any abnormalities.", 'Segment the optic nerve in the video and provide details about its relation to the tumor.', 'Segment the nasal cavity structures from MRI images and overlay the surgical pathway for better guidance.', 'Segment the optic nerve in the video and provide details about its relation to the tumor.| Provide a detailed 3D segmentation of the optic nerve in the MRI scan and its relation to the tumor.', 'Segment the nasal cavity structures from MRI images and overlay the surgical pathway for better guidance.', 'Analyze the current surgical view and enhance the image quality using MRI segmentation techniques. Detect any instruments in the image and highlight them.', 'Show the video and MRI scans of the patient and highlight the vascular landmarks and tumor. Ask yes/no questions about the proximity of the vascular landmarks to the tumor.', 'Explain how to overlay vascular landmarks on a MRI image and determine their proximity to a tumor.', 'Segment the optic nerve in the video and highlight its relation to the tumor. Provide detailed annotations and markings.', 'Analyze the current surgical view and enhance it using video and MRI data.', 'Analyze the current surgical view to identify key features and enhance the image quality.', 'Analyze the current surgical view using MRI segmentation to identify relevant anatomical structures, and then use instrument detection to identify the tools in the surgical field.', 'Analyze the current surgical view to identify any potential issues or complications. Provide a detailed breakdown of the procedure, highlighting any areas of concern.', 'Use 3D segme ...
# Extracted Prompts from all_ans: ['Segment nasal cavity structures?|Overlay surgical pathway?', 'Use Segment-Video functionality?|Use Segment-MRI functionality?', 'Overlay vascular landmarks?|Answer questions about proximity to tumor?', 'Use Segment-Video functionality?|Use Segment-MRI functionality?', 'Overlay vascular landmarks?|Answer questions about proximity to tumor?', 'Overlay vascular landmarks?|Answer questions about proximity to tumor?', 'Use Segment-MRI functionality?|Use Overlaying functionality?', 'Detect suction tool?|Overlay its path relative to tumor margin?', 'Use Segment-MRI functionality?|Use Surgical-VQA functionality?', 'Segment brain tumor from MRI?|Identify position of surgical instruments?', 'Overlay vascular landmarks?|Answer questions about proximity to tumor?', 'Segment nasal cavity structures?|Overlay surgical pathway?', 'Use Segment-MRI functionality?|Use Overlaying functionality?', 'Use Detect-Instrument functionality?|Use Surgical-VQA functionality?', 'Segment nasal cavity structures?|Overlay surgical pathway?', 'Overlay vascular landmarks?|Answer questions about proximity to tumor?', 'Use Segment-MRI functionality?|Use Surgical-VQA functionality?', 'Overlay vascular landmarks?|Answer questions about proximity to tumor?', 'Segment brain tumor from MRI?|Identify position of surgical instruments?', 'Use Detect-Instrument functionality?|Use Surgical-VQA functionality?', 'Segment optic nerve from video?|Provide details about relation to tumor?', 'Segment nasal cavity structures?|Overlay surgical pathway?', 'Segment optic nerve from video?|Provide details about relation to tumor?', 'Segment nasal cavity structures?|Overlay surgical pathway?', 'Use Segment-MRI functionality?|Use Overlaying functionality?', 'Overlay vascular landmarks?|Answer questions about proximity to tumor?', 'Overlay vascular landmarks?|Answer questions about proximity to tumor?', 'Segment optic nerve from video?|Provide details about relation to tumor?', 'Use Segment-MRI functionality?|Use Overlaying functionality?', 'Use Segment-Video functionality?|Use Segment-MRI functionality?', 'Use Detect-Instrument functionality?|Use Surgical-VQA functionality?', 'Use Segment-MRI functionality?|Use Surgical-VQA functionality?', 'Segment nasal cavity structures?|Overlay surgical pathway?', 'Use Segment-MRI functionality?|Use Overlaying functionality?', 'Segment brain tumor from MRI?|Identify position of surgical instruments?', 'Use Segment-Video functionality?|Use Detect-Instrument functionality?', 'Segment nasal cavity structures?|Overlay surgical pathway?', 'Segment nasal cavity structures?|Overlay surgical pathway?', 'Use Segment-Video functionality?|Use Detect-Instrument functionality?', 'Segment brain tumor from MRI?|Identify position of surgical instruments?', 'Use Detect-Instrument functionality?|Use Surgical-VQA functionality?', 'Detect suction tool?|Overlay its path relative to tumor margin?', 'Use Detect-Instrument functionality?|Use Surgical-VQA functionality?', 'Detect suction tool?|Overlay its path relative to tumor margin?', 'Use Segment-Video functionality?|Use Segment-MRI functionality?', 'Overlay vascular landmarks?|Answer questions about proximity to tumor?', 'Use Segment-MRI functionality?|Use Surgical-VQA functionality?', 'Segment nasal cavity structures?|Overlay surgical pathway?', 'Segment brain tumor from MRI?|Identify position of surgical instruments?', 'Use Segment-MRI functionality?|Use Overlaying functionality?', 'Segment optic nerve from video?|Provide details about relation to tumor?', 'Use Detect-Instrument functionality?|Use Surgical-VQA functionality?', 'Use Segment-MRI functionality?|Use Overlaying functionality?', 'Use Segment-MRI functionality?|Use Surgical-VQA functionality?', 'Use Segment-MRI functionality?|Use Overlaying functionality?', 'Overlay vascular landmarks?|Answer questions about proximity to tumor?', 'Use Detect-Instrument functionality?|Use Surgical-VQA functionality?', 'Use Segment-Video funct ...
# 2500
# 2500

# %%
# !pip install rouge_score
rouge = evaluate.load("rouge")
rouge_results = rouge.compute(predictions= all_pred_prompts, references=all_ans_prompts)
print(rouge_results)
# Out:
# Collecting rouge_score
#   Downloading rouge_score-0.1.2.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: absl-py in /usr/local/lib/python3.11/dist-packages (from rouge_score) (1.4.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.11/dist-packages (from rouge_score) (3.9.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from rouge_score) (1.26.4)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.11/dist-packages (from rouge_score) (1.17.0)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk->rouge_score) (8.1.8)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from nltk->rouge_score) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.11/dist-packages (from nltk->rouge_score) (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from nltk->rouge_score) (4.67.1)
# Building wheels for collected packages: rouge_score
#   Building wheel for rouge_score (setup.py) ... done
#   Created wheel for rouge_score: filename=rouge_score-0.1.2-py3-none-any.whl size=24935 sha256=0a9994468e49dd9b2cebb84ba01140b2350e6d8e0976c10e143420a510b3191c
#   Stored in directory: /root/.cache/pip/wheels/1e/19/43/8a442dc83660ca25e163e1bd1f89919284ab0d0c1475475148
# Successfully built rouge_score
# Installing collected packages: rouge_score
# Successfully installed rouge_score-0.1.2
# Downloading builder script:   0%|          | 0.00/6.27k [00:00<?, ?B/s]
# {'rouge1': 0.2991429580209265, 'rouge2': 0.1322224175626351, 'rougeL': 0.2852462025444323, 'rougeLsum': 0.2848774904624124}

# %%
bleu_score = corpus_bleu(all_ans_prompts, all_pred_prompts, weights=(1.0, 0.0, 0.0, 0.0))
print(bleu_score)
# Out:
# 0.1509241731293971
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)

# %%
import nltk
nltk.download('wordnet')
from nltk.tokenize import word_tokenize
nltk.download('punkt_tab')
import warnings
warnings.filterwarnings("ignore", category=UserWarning)

m_score=0
for line in zip(all_ans_prompts, all_pred_prompts):
    ref = word_tokenize(line[0])
    hypo = word_tokenize(line[1])
    m_score += meteor_score([ref], hypo)
meteors = m_score/len(all_ans)
print(meteors)
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# 0.259473432796108

# %%
import re

# Function to extract the "Model" part from a given text
# def extract_model(text):
#     match = re.search(r"Model:\s*(.*?)\n", text)
#     return match.group(1) if match else ""

def extract_model(text):
    # 使用正则表达式找到所有 "Model:" 后面紧跟的名称
    matches = re.findall(r"Model:\s*(.*?)\n", text)
    # 去除每个模型名称中的所有空格，并按顺序用 "|" 连接
    cleaned_matches = ["".join(match.split()) for match in matches]
    return "|".join(cleaned_matches) if cleaned_matches else ""

# Function to calculate exact match accuracy
def calculate_exact_match_accuracy(predictions, answers):
    # Extract and strip spaces from the models
    pred_models = [extract_model(pred).strip() for pred in predictions]
    true_models = [extract_model(ans).strip() for ans in answers]

    # Debug prints for checking values
    print(pred_models)
    print(true_models)

    correct_matches = sum(p == t for p, t in zip(pred_models, true_models))
    total = len(true_models)
    return correct_matches / total if total > 0 else 0

# Calculate exact match accuracy
accuracy = calculate_exact_match_accuracy(all_pred, all_ans)
print(f"Exact Match Accuracy: {accuracy * 100:.2f}%")
# Out:
# ['Segment-MRI|Segment-Video', 'Segment-MRI|Segment-Video', 'Segment-MRI|Overlaying', 'Segment-MRI|Segment-Video', 'Segment-MRI|Overlaying', 'Segment-MRI|Overlaying', 'Segment-Video|Segment-MRI', 'Detect-Instrument|Overlaying', 'Segment-MRI|Detect-Instrument', 'Segment-MRI|Overlaying', 'Segment-MRI|Overlaying', 'Segment-Video|Segment-MRI', 'Segment-Video|Segment-MRI', 'Segment-Video|Segment-MRI', 'Segment-Video|Segment-MRI', 'Segment-MRI|Overlaying', 'Segment-Video|Segment-MRI', 'Segment-MRI|Segment-Video', 'Segment-MRI|Segment-Video', 'Segment-Video|Segment-MRI', 'Segment-Video|Segment-MRI', 'Segment-MRI|Segment-Video', 'Segment-Video|Segment-MRI', 'Segment-MRI|Overlaying', 'Segment-MRI|Detect-Instrument', 'Segment-Video|Segment-MRI', 'Segment-MRI|Overlaying', 'Segment-Video|Segment-MRI', 'Segment-Video|Segment-MRI', 'Segment-Video|Segment-MRI', 'Segment-MRI|Detect-Instrument', 'Segment-Video|Segment-MRI', 'Segment-Video|Segment-MRI', 'Segment-MRI|Segment-Video', 'Segment-MRI|Detect-Instrument', 'Segment-Video|Detect-Instrument', 'Segment-Video|Overlaying', 'Segment-MRI|Segment-Video', 'Segment-Video|Segment-MRI', 'Segment-MRI|Segment-Video', 'Segment-MRI|Segment-Video', 'Detect-Instrument|Overlaying', 'Segment-MRI|Overlaying', 'Detect-Instrument|Overlaying', 'Segment-Video|Segment-MRI', 'Overlaying', 'Segment-Video|Overlaying', 'Segment-Video|Segment-MRI', 'Segment-MRI|Segment-Video', 'Segment-Video|Detect-Instrument', 'Segment-Video|Segment-MRI', 'Segment-Video|Overlaying', 'Segment-MRI|Segment-Video', 'Segment-MRI|Overlaying', 'Segment-MRI|Overlaying', 'Segment-MRI|Overlaying', 'Segment-Video|Segment-MRI', 'Segment-Video|Detect-Instrument', 'Detect-Instrument|Overlaying', 'Segment-MRI|Segment-Video', 'Segment-Video|Detect-Instrument', 'Segment-MRI|Segment-Video', 'Segment-MRI|Segment-Video', 'Segment-MRI|Overlaying', 'Segment-Video|Overlaying', 'Segment-Video|Segment-MRI', 'Detect-Instrument|Overlaying', 'Segment-MRI|Segment-Video', 'Detect-Instrument|Overlaying', 'Segment-MRI|Segment-Video', 'Segment-MRI|Segment-Video', 'Segment-Video|Overlaying', 'Segment-Video|Overlaying', 'Segment-Video|Detect-Instrument', 'Segment-MRI|Overlaying', 'Segment-MRI|Segment-Video', 'Segment-Video|Segment-MRI', 'Segment-Video|Segment-MRI', 'Segment-MRI|Segment-Video', 'Segment-Video|Overlaying', 'Segment-MRI|Overlaying', 'Segment-MRI|Segment-Video', 'Segment-Video|Overlaying', 'Segment-MRI|Overlaying', 'Segment-MRI|Detect-Instrument', 'Segment-Video|Segment-MRI', 'Detect-Instrument|Overlaying', 'Segment-MRI|Segment-Video', 'Segment-MRI|Overlaying', 'Detect-Instrument|Overlaying', 'Segment-Video|Detect-Instrument', 'Segment-MRI|Segment-Video', 'Segment-Video|Detect-Instrument', 'Segment-Video|Detect-Instrument', 'Segment-Video|Detect-Instrument', 'Segment-Video|Segment-MRI', 'Segment-MRI|Segment-Video', 'Segment-MRI|Segment-Video', 'Segment-Video|Segment-MRI', 'Segment-MRI|Segment-Video', 'Segment-MRI|Detect-Instrument', 'Segment-MRI|Detect-Instrument', 'Segment-Video|Segment-MRI', 'Segment-Video|Segment-MRI', 'Segment-Video|Detect-Instrument', 'Segment-Video|Segment-MRI', 'Segment-Video|Segment-MRI', 'Segment-Video|Segment-MRI', 'Overlaying', 'Segment-Video', 'Segment-Video|Segment-MRI', 'Overlaying', 'Segment-Video|Segment-MRI', 'Segment-MRI|Overlaying', 'Segment-Video|Detect-Instrument', 'Segment-Video|Segment-MRI', 'Segment-MRI|Segment-Video', 'Segment-Video|Segment-MRI', 'Segment-MRI|Segment-Video', 'Segment-Video|Detect-Instrument', 'Segment-Video|Detect-Instrument', 'Segment-Video|Detect-Instrument', 'Segment-Video|Segment-MRI', 'Segment-Video|Segment-MRI', 'Segment-MRI|Overlaying', 'Segment-MRI|Segment-Video', 'Segment-Video|Segment-MRI', 'Segment-MRI|Segment-Video', 'Segment-MRI|Overlaying', 'Segment-MRI|Segment-Video', 'Segment-MRI|Segment-Video', 'Segment-MRI|Segment-Video', 'Segment-MRI|Segment-Video', 'Segment-Video|Detect-Instrument', 'Segment-MRI|Detect-Instrument', 'Segment-Video|Detect-Instrument', 'Segment-MRI|Detect-Instrume ...
# ['Segment-Video|Overlaying', 'Segment-Video|Segment-MRI', 'Overlaying|Surgical-VQA', 'Segment-Video|Segment-MRI', 'Overlaying|Surgical-VQA', 'Overlaying|Surgical-VQA', 'Segment-MRI|Overlaying', 'Detect-Instrument|Overlaying', 'Segment-MRI|Surgical-VQA', 'Segment-MRI|Detect-Instrument', 'Overlaying|Surgical-VQA', 'Segment-Video|Overlaying', 'Segment-MRI|Overlaying', 'Detect-Instrument|Surgical-VQA', 'Segment-Video|Overlaying', 'Overlaying|Surgical-VQA', 'Segment-MRI|Surgical-VQA', 'Overlaying|Surgical-VQA', 'Segment-MRI|Detect-Instrument', 'Detect-Instrument|Surgical-VQA', 'Segment-Video|Surgical-VQA', 'Segment-Video|Overlaying', 'Segment-Video|Surgical-VQA', 'Segment-Video|Overlaying', 'Segment-MRI|Overlaying', 'Overlaying|Surgical-VQA', 'Overlaying|Surgical-VQA', 'Segment-Video|Surgical-VQA', 'Segment-MRI|Overlaying', 'Segment-Video|Segment-MRI', 'Detect-Instrument|Surgical-VQA', 'Segment-MRI|Surgical-VQA', 'Segment-Video|Overlaying', 'Segment-MRI|Overlaying', 'Segment-MRI|Detect-Instrument', 'Segment-Video|Detect-Instrument', 'Segment-Video|Overlaying', 'Segment-Video|Overlaying', 'Segment-Video|Detect-Instrument', 'Segment-MRI|Detect-Instrument', 'Detect-Instrument|Surgical-VQA', 'Detect-Instrument|Overlaying', 'Detect-Instrument|Surgical-VQA', 'Detect-Instrument|Overlaying', 'Segment-Video|Segment-MRI', 'Overlaying|Surgical-VQA', 'Segment-MRI|Surgical-VQA', 'Segment-Video|Overlaying', 'Segment-MRI|Detect-Instrument', 'Segment-MRI|Overlaying', 'Segment-Video|Surgical-VQA', 'Detect-Instrument|Surgical-VQA', 'Segment-MRI|Overlaying', 'Segment-MRI|Surgical-VQA', 'Segment-MRI|Overlaying', 'Overlaying|Surgical-VQA', 'Detect-Instrument|Surgical-VQA', 'Segment-Video|Detect-Instrument', 'Detect-Instrument|Overlaying', 'Segment-Video|Surgical-VQA', 'Detect-Instrument|Surgical-VQA', 'Segment-Video|Segment-MRI', 'Segment-Video|Detect-Instrument', 'Segment-MRI|Detect-Instrument', 'Segment-MRI|Overlaying', 'Segment-MRI|Surgical-VQA', 'Detect-Instrument|Overlaying', 'Segment-MRI|Overlaying', 'Detect-Instrument|Overlaying', 'Overlaying|Surgical-VQA', 'Segment-MRI|Surgical-VQA', 'Detect-Instrument|Surgical-VQA', 'Segment-Video|Segment-MRI', 'Segment-MRI|Overlaying', 'Segment-MRI|Detect-Instrument', 'Segment-Video|Overlaying', 'Detect-Instrument|Surgical-VQA', 'Segment-Video|Surgical-VQA', 'Segment-Video|Overlaying', 'Segment-MRI|Surgical-VQA', 'Segment-Video|Overlaying', 'Segment-MRI|Overlaying', 'Segment-Video|Detect-Instrument', 'Overlaying|Surgical-VQA', 'Segment-MRI|Detect-Instrument', 'Segment-Video|Segment-MRI', 'Detect-Instrument|Overlaying', 'Segment-Video|Overlaying', 'Segment-Video|Overlaying', 'Detect-Instrument|Overlaying', 'Detect-Instrument|Surgical-VQA', 'Overlaying|Surgical-VQA', 'Segment-Video|Detect-Instrument', 'Detect-Instrument|Surgical-VQA', 'Segment-Video|Segment-MRI', 'Segment-Video|Detect-Instrument', 'Segment-Video|Detect-Instrument', 'Segment-MRI|Detect-Instrument', 'Segment-MRI|Overlaying', 'Segment-Video|Overlaying', 'Detect-Instrument|Overlaying', 'Segment-MRI|Detect-Instrument', 'Segment-Video|Segment-MRI', 'Segment-Video|Surgical-VQA', 'Detect-Instrument|Surgical-VQA', 'Segment-Video|Detect-Instrument', 'Segment-Video|Surgical-VQA', 'Detect-Instrument|Surgical-VQA', 'Overlaying|Surgical-VQA', 'Segment-Video|Surgical-VQA', 'Segment-Video|Segment-MRI', 'Overlaying|Surgical-VQA', 'Segment-Video|Segment-MRI', 'Overlaying|Surgical-VQA', 'Segment-MRI|Surgical-VQA', 'Segment-MRI|Surgical-VQA', 'Segment-MRI|Overlaying', 'Segment-Video|Surgical-VQA', 'Segment-Video|Segment-MRI', 'Segment-MRI|Overlaying', 'Segment-Video|Detect-Instrument', 'Detect-Instrument|Surgical-VQA', 'Detect-Instrument|Surgical-VQA', 'Segment-Video|Segment-MRI', 'Overlaying|Surgical-VQA', 'Overlaying|Surgical-VQA', 'Segment-MRI|Surgical-VQA', 'Segment-Video|Segment-MRI', 'Segment-MRI|Surgical-VQA', 'Segment-MRI|Detect-Instrument', 'Segment-MRI|Overlaying', 'Segment-Video|Overlaying', 'Segment-Video|Segment-MRI', 'Segment-Video|Detect-Instrument' ...
# Exact Match Accuracy: 19.04%
