# %% [markdown]
# <a href="https://colab.research.google.com/github/PeterHJY628/MyOwnExample/blob/main/1Detect-Instrument-text.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip -q install "torch==2.4.0" tensorboard pillow torchvision accelerate huggingface_hub
# !pip -q install  --upgrade \
  "transformers==4.45.1" \
  "datasets==3.0.1" \
  "accelerate==0.34.2" \
  "evaluate==0.4.3" \
  "bitsandbytes==0.44.0" \
  "trl==0.11.1" \
  "peft==0.13.0" \
  "qwen_vl_utils"
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 797.3/797.3 MB 2.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.2/176.2 MB 6.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.4/209.4 MB 4.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 26.7 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchaudio 2.5.1+cu121 requires torch==2.5.1, but you have torch 2.4.0 which is incompatible.
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 2.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 67.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 471.6/471.6 kB 32.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 324.4/324.4 kB 29.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.0/84.0 kB 8.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 122.4/122.4 MB 8.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 318.4/318.4 kB 25.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.5/322.5 kB 27.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 11.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.6/177.6 kB 16.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 80.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.5/115.5 kB 10.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.8/33.8 MB 58.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 13.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 18.0 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.6.1 which is incompatible.
# torchaudio 2.5.1+cu121 requires torch==2.5.1, but you have torch 2.4.0 which is incompatible.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
os.environ['HF_HOME'] = '/home/sa5u24/VQA'
hf_home = os.path.expanduser(
    os.getenv("HF_HOME", os.path.join(os.getenv("XDG_CACHE_HOME", "~/.cache"), "huggingface"))
)
print(hf_home)

from huggingface_hub import login

# Replace 'your-hf-token-here' with your actual Hugging Face token
login(token="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")
# Out:
# /home/sa5u24/VQA

# %%
def generate_SM(que):
    sm = (
        "Select a model to answer the following question:\n"
        f"{que}\n"
        "Select a model only from the following model list: Segment-Video, Segment-MRI, "
        "Detect-Instrument, Overlaying, Surgical-VQA to answer the question.\n"
        "Generate a shortest prompt for the chosen model. "
        "Your response should be like: Model: ? Prompt: ? and no other words."
    )
    return sm
#f"{que}\n"

def format_data(sample):
    system_message = generate_SM(sample[0])
    return [
        {
            "role": "system",
            "content": system_message
        },
        {
            "role": "assistant",
            "content": sample[1]
        },
    ]

# %%
from datasets import load_dataset

dataset_id = "HuggingFaceM4/ChartQA"
train_dataset, eval_dataset, test_dataset = load_dataset(dataset_id, split=['train[:10%]', 'val[:10%]', 'test[:10%]'])

train_dataset = [format_data(sample) for sample in train_dataset]
eval_dataset = [format_data(sample) for sample in eval_dataset]
test_dataset = [format_data(sample) for sample in test_dataset]

train_dataset[200], len(train_dataset), len(eval_dataset), len(test_dataset)
# Out:
# ([{'role': 'system',
#    'content': [{'type': 'text',
#      'text': 'You are a Vision Language Model specialized in interpreting visual data from chart images.\nYour task is to analyze the provided chart image and respond to queries with concise answers, usually a single word, number, or short phrase.\nThe charts include a variety of types (e.g., line charts, bar charts) and contain colors, labels, and text.\nFocus on delivering accurate, succinct answers based on the visual information. Avoid additional explanation unless absolutely necessary.'}]},
#   {'role': 'user',
#    'content': [{'type': 'text',
#      'text': 'Is the rightmost value of light brown graph 58?'}]},
#   {'role': 'assistant', 'content': [{'type': 'text', 'text': 'No'}]}],
#  2830,
#  192,
#  250)

# %%
import os
import re
import torch
import random
import numpy as np
from torch.utils.data import Dataset, DataLoader
import pandas as pd
from google.colab import drive

# Mount Google Drive to access the file
drive.mount('/content/drive')

class TextQuestionLabelDataset(Dataset):
    def __init__(self, input_file):
        # Load data from a CSV file
        self.data = pd.read_csv(input_file)
        #print(self.data.head())  # 显示前 5 行数据


        # Extract questions and labels from the Input column
        #self.questions = self.data['Input'].apply(lambda x: re.search(r'Question: (.+?)\n', x).group(1)).tolist()
        self.questions = self.data['Input'].tolist()
        self.labels = self.data['Label'].tolist()

    def __len__(self):
        # Return the total number of samples
        return len(self.questions)

    def __getitem__(self, idx):
        # Return a single sample (question, label) given an index
        question = self.questions[idx]
        label = self.labels[idx]
        return question, label

input_file = '/content/drive/MyDrive/Detect-Instrument.csv'

# Initialize dataset
dataset = TextQuestionLabelDataset(input_file)

# Split the dataset for train, eval, and test (e.g., 10% for each)
dataset_length = len(dataset)
#train_size = int(0.1 * dataset_length)
train_size = 0
#eval_size = int(0.1 * dataset_length)
eval_size = 0
test_size = dataset_length - train_size - eval_size
#seed everything
seed = 42
torch.manual_seed(seed)
random.seed(seed)
np.random.seed(seed)

# train_dataset, eval_dataset, test_dataset = torch.utils.data.random_split(
#     dataset, [train_size, eval_size, test_size]
# )

train_dataset = torch.utils.data.Subset(dataset, range(0, train_size))
eval_dataset = torch.utils.data.Subset(dataset, range(train_size, train_size + eval_size))
test_dataset = torch.utils.data.Subset(dataset, range(train_size + eval_size, len(dataset)))
#print(train_dataset[0])
train_dataset = [format_data(sample) for sample in train_dataset]
eval_dataset = [format_data(sample) for sample in eval_dataset]
test_dataset = [format_data(sample) for sample in test_dataset]

# Create DataLoaders for batching
# train_loader = DataLoader(train_dataset, batch_size=2, shuffle=True)
# eval_loader = DataLoader(eval_dataset, batch_size=2, shuffle=False)
def custom_collate_fn(sample):
    """
    确保 DataLoader 返回的样本格式不变。
    """
    return sample
test_loader = DataLoader(test_dataset, batch_size=4, shuffle=False,collate_fn=custom_collate_fn)
# test_dataset[0]
# test_dataset[0]
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import gc
import time
import torch
from transformers import pipeline

def clear_memory():
    # Delete variables if they exist in the current global scope
    if 'inputs' in globals(): del globals()['inputs']
    if 'model' in globals(): del globals()['model']
    if 'tokenizer' in globals(): del globals()['tokenizer']
    if 'pipeline' in globals(): del globals()['pipeline']
    if 'trainer' in globals(): del globals()['trainer']
    if 'processor' in globals(): del globals()['processor']
    if 'trainer' in globals(): del globals()['trainer']
    if 'peft_model' in globals(): del globals()['peft_model']
    if 'bnb_config' in globals(): del globals()['bnb_config']
    time.sleep(2)

    # Garbage collection and clearing CUDA memory
    gc.collect()
    time.sleep(2)
    torch.cuda.empty_cache()
    torch.cuda.synchronize()
    time.sleep(2)
    gc.collect()
    time.sleep(2)

    print(f"GPU allocated memory: {torch.cuda.memory_allocated() / 1024**3:.2f} GB")
    print(f"GPU reserved memory: {torch.cuda.memory_reserved() / 1024**3:.2f} GB")

# def generate_text_from_sample(model_id, sample, max_new_tokens=1024):
#     pipe = pipeline(
#     "text-generation",
#     model=model_id,
#     torch_dtype=torch.bfloat16,
#     device_map="auto",
#     )
#     input = sample[:2]

#     outputs = pipe(
#     input,
#     max_new_tokens,
#     )
#     print(outputs[0]["generated_text"][-1])

#     return outputs[0]["generated_text"][-1]  # Return the first decoded output text

def generate_text_from_sample(pipe, sample, max_new_tokens=1024):
    input = sample[:1]
    #print(f"input: {input}")

    outputs = pipe(
    input,
    max_new_tokens = max_new_tokens,
    )
    #print(outputs[0]["generated_text"][-1])

    return outputs[0]["generated_text"][-1]["content"]  # Return the first decoded output text

# %%
clear_memory()
# Out:
# GPU allocated memory: 6.01 GB
# GPU reserved memory: 6.08 GB

# %%
import evaluate
import torch
from nltk.translate.meteor_score import meteor_score, single_meteor_score
from nltk.translate.bleu_score import sentence_bleu, corpus_bleu
import requests
from torch import nn
from transformers import MllamaForConditionalGeneration, AutoProcessor, MllamaConfig, AutoModelForCausalLM
from typing import List, Optional, Tuple, Union
from PIL import Image
import matplotlib.pyplot as plt
from qwen_vl_utils import process_vision_info
from transformers import BitsAndBytesConfig
from transformers import AutoTokenizer, AutoModelForCausalLM



quantization_config = BitsAndBytesConfig(
    load_in_4bit=True,
    # low_cpu_mem_usage=True,
    # bnb_4bit_compute_dtype=torch.float16
)

model_id = "meta-llama/Llama-3.2-3B-Instruct"
model = model_id
tokenizer = AutoTokenizer.from_pretrained(model_id)
if tokenizer.pad_token_id is None:
  tokenizer.pad_token = tokenizer.eos_token

pipe = pipeline(
"text-generation",
model=model_id,
tokenizer=tokenizer,
torch_dtype=torch.bfloat16,
#device_map="auto",
device=0,
)
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %% [markdown]
# # **Test one sample**

# %%
import os
import re
import torch
import random
import numpy as np
from torch.utils.data import Dataset, DataLoader
import pandas as pd
from google.colab import drive
import torch
from transformers import pipeline
from transformers import AutoTokenizer, AutoModelForCausalLM


def generate_text_from_sample(model_id, sample, max_new_tokens=1024):
    tokenizer = AutoTokenizer.from_pretrained(model_id)
    if tokenizer.pad_token_id is None:
      tokenizer.pad_token = tokenizer.eos_token

    pipe = pipeline(
    "text-generation",
    model=model_id,
    tokenizer=tokenizer,
    torch_dtype=torch.bfloat16,
    #device_map="auto",
    device=0,
    )
    input = sample[:1]

    outputs = pipe(
    input,
    max_new_tokens = max_new_tokens,
    )
    print(outputs[0]["generated_text"][-1])

    return outputs[0]["generated_text"][-1]["content"]  # Return the first decoded output text

# Mount Google Drive to access the file
drive.mount('/content/drive')

class TextQuestionLabelDataset(Dataset):
    def __init__(self, input_file):
        # Load data from a CSV file
        self.data = pd.read_csv(input_file)
        # print(self.data.head())  # 显示前 5 行数据


        # Extract questions and labels from the Input column
        #self.questions = self.data['Input'].apply(lambda x: re.search(r'Question: (.+?)\n', x).group(1)).tolist()
        self.questions = self.data['Input'].tolist()
        self.labels = self.data['Label'].tolist()

    def __len__(self):
        # Return the total number of samples
        return len(self.questions)

    def __getitem__(self, idx):
        # Return a single sample (question, label) given an index
        question = self.questions[idx]
        label = self.labels[idx]
        return question, label

input_file = '/content/drive/MyDrive/test10.csv'

# Initialize dataset
dataset = TextQuestionLabelDataset(input_file)

# Split the dataset for train, eval, and test (e.g., 10% for each)
dataset_length = len(dataset)
#train_size = int(0.1 * dataset_length)
train_size = 0
#eval_size = int(0.1 * dataset_length)
eval_size = 0
test_size = dataset_length - train_size - eval_size

#seed everything
seed = 42
torch.manual_seed(seed)
random.seed(seed)
np.random.seed(seed)

# train_dataset, eval_dataset, test_dataset = torch.utils.data.random_split(
#     dataset, [train_size, eval_size, test_size]
# )

train_dataset = torch.utils.data.Subset(dataset, range(0, train_size))
eval_dataset = torch.utils.data.Subset(dataset, range(train_size, train_size + eval_size))
test_dataset = torch.utils.data.Subset(dataset, range(train_size + eval_size, len(dataset)))

def generate_SM(que):
    sm = (
        "Select a model to answer the following question:\n"
        f"{que}\n"
        "Select a model only from the following model list: Segment-Video, Segment-MRI, "
        "Detect-Video, Overlaying, Surgical-VQA to answer the question.\n"
        "Generate a shortest prompt for the chosen model. "
        "Your response should be like: 'Model: ? \nPrompt: ?' and no other words."
    )
    return sm
#f"{que}\n"

def format_data_test1(sample):
    system_message = generate_SM(sample[0])
    return [
        {
            "role": "system",
            "content": system_message
        },
        # {
        #     "role": "user",
        #     "content": sample[0]
        # },
        {
            "role": "assistant",
            "content": sample[1]
        },
    ]
def convert_sample_to_messages(sample):
    """
    Convert sample[:2] into the desired 'messages' format.

    Args:
    sample (list): A list containing at least two elements [system_message, user_message].

    Returns:
    list: A list of dictionaries formatted for the messages.
    """
    # 使用 sample 的第一个元素作为 system_message，第二个元素作为 user_message
    return [
        {"role": "system", "content": sample[0]},  # 系统消息
        {"role": "user", "content": sample[1]},    # 用户消息
    ]

model_id = "meta-llama/Llama-3.2-3B-Instruct"
input1 = format_data_test1(test_dataset[0])
print(input1)
print(input1[:1])
output1 = generate_text_from_sample(model_id,input1)
ans1 = input1[1]['content']
print("output1: ",output1)
print("answer1: ",ans1)
# print("--------------------------------------------")
# output2 = generate_text_from_sample(model, processor, input1)
# ans2 = input2[2]['content'][0]['text']
# print("output2: ",output2)
# print("answer2: ",ans2)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# [{'role': 'system', 'content': "Select a model to answer the following question:\nQuestion: Analyze and segment Right Optic Protuberance from Video?\nSelect a model only from the following model list: Segment-Video, Segment-MRI, Detect-Video, Overlaying, Surgical-VQA to answer the question.\nGenerate a shortest prompt for the chosen model. Your response should be like: 'Model: ? Prompt: ?' and no other words."}, {'role': 'assistant', 'content': 'Model: Segment-Video\nPrompt: Analyze right optic protuberance?'}]
# [{'role': 'system', 'content': "Select a model to answer the following question:\nQuestion: Analyze and segment Right Optic Protuberance from Video?\nSelect a model only from the following model list: Segment-Video, Segment-MRI, Detect-Video, Overlaying, Surgical-VQA to answer the question.\nGenerate a shortest prompt for the chosen model. Your response should be like: 'Model: ? Prompt: ?' and no other words."}]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Exception ignored in: <function tqdm.__del__ at 0x7e2863781120>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/tqdm/std.py", line 1147, in __del__
#     def __del__(self):
# KeyboardInterrupt:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-65-12f4d2504729> in <cell line: 137>()
#     135 print(input1)
#     136 print(input1[:1])
# --> 137 output1 = generate_text_from_sample(model_id,input1)
#     138 ans1 = input1[1]['content']
#     139 print("output1: ",output1)
#
# <ipython-input-65-12f4d2504729> in generate_text_from_sample(model_id, sample, max_new_tokens)
#      17       tokenizer.pad_token = tokenizer.eos_token
#      18
# ---> 19     pipe = pipeline(
#      20     "text-generation",
#      21     model=model_id,
#
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/__init__.py in pipeline(task, model, config, tokenizer, feature_extractor, image_processor, framework, revision, use_fast, token, device, device_map, torch_dtype, trust_remote_code, model_kwargs, pipeline_class, **kwargs)
#    1100         kwargs["device"] = device
#    1101
# -> 1102     return pipeline_class(model=model, framework=framework, task=task, **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/text_generation.py in __init__(self, *args, **kwargs)
#      94
#      95     def __init__(self, *args, **kwargs):
# ---> 96         super().__init__(*args, **kwargs)
#      97         self.check_model_type(
#      98             TF_MODEL_FOR_CAUSAL_LM_MAPPING_NAMES if self.framework == "tf" else MODEL_FOR_CAUSAL_LM_MAPPING_NAMES
#
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py in __init__(self, model, tokenizer, feature_extractor, image_processor, modelcard, framework, task, args_parser, device, torch_dtype, binary_output, **kwargs)
#     899             and hf_device_map is None
#     900         ):
# --> 901             self.model.to(self.device)
#     902
#     903         # If the model can generate, create a local generation config. This is done to avoid side-effects on the model
#
# /usr/local/lib/python3.10/dist-packages/transformers/modeling_utils.py in to(self, *args, **kwargs)
#    2956                     " `dtype` by passing the correct `torch_dtype` argument."
#    2957                 )
# -> 2958         return super().to(*args, **kwargs)
#    2959
#    2960     def half(self, *args):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in to(self, *args, **kwargs)
#    1172                     raise
#    1173
# -> 1174         return self._apply(convert)
#    1175
#    1176     def register_full_backward_pre_hook(
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _apply(self, fn, recurse)
#     778         if recurse:
#     779             for module in self.children():
# --> 780                 module._apply(fn)
#     781
#     782         def compute_should_use_set_data(tensor, tensor_applied):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _apply(self, fn, recurse)
#     778         if recurse:
#     779             for module in self.children():
# --> 780                 module._apply(fn)
#     781
#     782         def compute_should_use_set_data(tensor, tensor_applied):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _apply(self, fn, recurse)
#     778         if recurse:
#     779             for module in self.children():
# --> 780                 module._apply(fn)
#     781
#     782         def compute_should_use_set_data(tensor, tensor_applied):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _apply(self, fn, recurse)
#     778         if recurse:
#     779             for module in self.children():
# --> 780                 module._apply(fn)
#     781
#     782         def compute_should_use_set_data(tensor, tensor_applied):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _apply(self, fn, recurse)
#     778         if recurse:
#     779             for module in self.children():
# --> 780                 module._apply(fn)
#     781
#     782         def compute_should_use_set_data(tensor, tensor_applied):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _apply(self, fn, recurse)
#     803             # `with torch.no_grad():`
#     804             with torch.no_grad():
# --> 805                 param_applied = fn(param)
#     806             p_should_use_set_data = compute_should_use_set_data(param, param_applied)
#     807
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in convert(t)
#    1158                         memory_format=convert_to_format,
#    1159                     )
# -> 1160                 return t.to(
#    1161                     device,
#    1162                     dtype if t.is_floating_point() or t.is_complex() else None,
#
# KeyboardInterrupt:

# %%
all_pred = []
all_ans = []

# %%
import os
import torch
import pickle
from google.colab import drive

drive.mount('/content/drive')
start_index = 0
# 设置保存路径
save_path = '/content/drive/MyDrive/Sharing/Detect-I-T2.pkl'

# 尝试加载之前的进度
if os.path.exists(save_path):
    with open(save_path, 'rb') as f:
        saved_data = pickle.load(f)
        start_index = saved_data['start_index']
        all_pred = saved_data['all_pred']
        all_ans = saved_data['all_ans']
        print(f"Resuming from index {start_index}")
else:
    start_index = 0
    all_pred = []
    all_ans = []
    print("Starting fresh")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Starting fresh

# %%
# model = pipe.model
# model.eval()
# with torch.no_grad():
#     for i, sample in enumerate(test_dataset):
#         # 跳过已处理的样本
#         if i < start_index:
#             continue

#         output = generate_text_from_sample(pipe, sample)
#         ans = sample[1]['content']
#         all_pred.append(output)
#         all_ans.append(ans)

#         # 更新进度
#         start_index = i + 1
#         saved_data = {
#             'start_index': start_index,
#             'all_pred': all_pred,
#             'all_ans': all_ans
#         }

#         # 保存到Google Drive
#         with open(save_path, 'wb') as f:
#             pickle.dump(saved_data, f)

#         print(f"Processed sample {i+1}/{len(test_dataset)}")

# print("All samples processed!")

model = pipe.model
model.eval()

with torch.no_grad():
    for batch_index, batch in enumerate(test_loader):
        # 如果需要跳过处理过的样本
        if batch_index < start_index:
            continue
        temp_ans = []
        temp_pred = []

        # 遍历 batch 中的每个 sample
        for sample_index, sample in enumerate(batch):
            print(f"  Processing sample {sample_index + 1} in batch {batch_index + 1}")
            # print(f" Sample: {sample}")

            # 调用 generate_text_from_sample
            output = generate_text_from_sample(pipe, sample)
            ans = sample[1]['content']
            temp_pred.append(output)
            temp_ans.append(ans)

        # 保存结果
        all_pred.extend(temp_pred)
        all_ans.extend(temp_ans)

        # 更新进度
        start_index = batch_index + 1
        saved_data = {
            'start_index': start_index,
            'all_pred': all_pred,
            'all_ans': all_ans
        }

        # 保存到 Google Drive
        with open(save_path, 'wb') as f:
            pickle.dump(saved_data, f)

        print(f"Processed batch {batch_index+1}/{len(test_loader)}")

print("All samples processed!")
# Out:
#   Processing sample 1 in batch 2
#   Processing sample 2 in batch 2
#   Processing sample 3 in batch 2
#   Processing sample 4 in batch 2
# Processed batch 2/250
#   Processing sample 1 in batch 3
#   Processing sample 2 in batch 3
#   Processing sample 3 in batch 3
#   Processing sample 4 in batch 3
# Processed batch 3/250
#   Processing sample 1 in batch 4
#   Processing sample 2 in batch 4
#   Processing sample 3 in batch 4
#   Processing sample 4 in batch 4
# Processed batch 4/250
#   Processing sample 1 in batch 5
#   Processing sample 2 in batch 5
#   Processing sample 3 in batch 5
#   Processing sample 4 in batch 5
# Processed batch 5/250
#   Processing sample 1 in batch 6
#   Processing sample 2 in batch 6
#   Processing sample 3 in batch 6
#   Processing sample 4 in batch 6
# Processed batch 6/250
#   Processing sample 1 in batch 7
#   Processing sample 2 in batch 7
#   Processing sample 3 in batch 7
#   Processing sample 4 in batch 7
# Processed batch 7/250
#   Processing sample 1 in batch 8
#   Processing sample 2 in batch 8
#   Processing sample 3 in batch 8
#   Processing sample 4 in batch 8
# Processed batch 8/250
#   Processing sample 1 in batch 9
#   Processing sample 2 in batch 9
#   Processing sample 3 in batch 9
#   Processing sample 4 in batch 9
# Processed batch 9/250
#   Processing sample 1 in batch 10
#   Processing sample 2 in batch 10
#   Processing sample 3 in batch 10
#   Processing sample 4 in batch 10
# Processed batch 10/250
#   Processing sample 1 in batch 11
#   Processing sample 2 in batch 11
#   Processing sample 3 in batch 11
#   Processing sample 4 in batch 11
# Processed batch 11/250
#   Processing sample 1 in batch 12
#   Processing sample 2 in batch 12
#   Processing sample 3 in batch 12
#   Processing sample 4 in batch 12
# Processed batch 12/250
#   Processing sample 1 in batch 13
#   Processing sample 2 in batch 13
#   Processing sample 3 in batch 13
#   Processing sample 4 in batch 13
# Processed batch 13/250
#   Processing sample 1 in batch 14
#   Processing sample 2 in batch 14
#   Processing sample 3 in batch 14
#   Processing sample 4 in batch 14
# Processed batch 14/250
#   Processing sample 1 in batch 15
#   Processing sample 2 in batch 15
#   Processing sample 3 in batch 15
#   Processing sample 4 in batch 15
# Processed batch 15/250
#   Processing sample 1 in batch 16
#   Processing sample 2 in batch 16
#   Processing sample 3 in batch 16
#   Processing sample 4 in batch 16
# Processed batch 16/250
#   Processing sample 1 in batch 17
#   Processing sample 2 in batch 17
#   Processing sample 3 in batch 17
#   Processing sample 4 in batch 17
# Processed batch 17/250
#   Processing sample 1 in batch 18
#   Processing sample 2 in batch 18
#   Processing sample 3 in batch 18
#   Processing sample 4 in batch 18
# Processed batch 18/250
#   Processing sample 1 in batch 19
#   Processing sample 2 in batch 19
#   Processing sample 3 in batch 19
#   Processing sample 4 in batch 19
# Processed batch 19/250
#   Processing sample 1 in batch 20
#   Processing sample 2 in batch 20
#   Processing sample 3 in batch 20
#   Processing sample 4 in batch 20
# Processed batch 20/250
#   Processing sample 1 in batch 21
#   Processing sample 2 in batch 21
#   Processing sample 3 in batch 21
#   Processing sample 4 in batch 21
# Processed batch 21/250
#   Processing sample 1 in batch 22
#   Processing sample 2 in batch 22
#   Processing sample 3 in batch 22
#   Processing sample 4 in batch 22
# Processed batch 22/250
#   Processing sample 1 in batch 23
#   Processing sample 2 in batch 23
#   Processing sample 3 in batch 23
#   Processing sample 4 in batch 23
# Processed batch 23/250
#   Processing sample 1 in batch 24
#   Processing sample 2 in batch 24
#   Processing sample 3 in batch 24
#   Processing sample 4 in batch 24
# Processed batch 24/250
#   Processing sample 1 in batch 25
#   Processing sample 2 in batch 25
#   Processing sample 3 in batch 25
#   Processing sample 4 in batch 25
# Processed batch 25/250
#   Processing sample 1 in batch 26
#   Processing sample 2 in batch 26
#   Processing sample 3 in batch 26
#   Processing sample 4 in batch 26
# Processed batch 26/250
#   Processing sample 1 in batch 27
#   Processing sample 2 in batch 27
#   Processing sample 3 in batch 27
#   Processing sample 4 in batch 27
# Processed batch 27/250
#   Processing sample 1 in batch 28
#   Processing sample 2 in batch 28
#   Processing sample 3 in batch 28
#   Processing sample 4 in batch 28
# Processed batch 28/250
#   Processing sample 1 in batch 29
#   Processing sample 2 in batch 29
#   Processing sample 3 in batch 29
#   Processing sample 4 in batch 29
# Processed batch 29/250
#   Processing sample 1 in batch 30
#   Processing sample 2 in batch 30
#   Processing sample 3 in batch 30
#   Processing sample 4 in batch 30
# Processed batch 30/250
#   Processing sample 1 in batch 31
#   Processing sample 2 in batch 31
#   Processing sample 3 in batch 31
#   Processing sample 4 in batch 31
# Processed batch 31/250
#   Processing sample 1 in batch 32
#   Processing sample 2 in batch 32
#   Processing sample 3 in batch 32
#   Processing sample 4 in batch 32
# Processed batch 32/250
#   Processing sample 1 in batch 33
#   Processing sample 2 in batch 33
#   Processing sample 3 in batch 33
#   Processing sample 4 in batch 33
# Processed batch 33/250
#   Processing sample 1 in batch 34
#   Processing sample 2 in batch 34
#   Processing sample 3 in batch 34
#   Processing sample 4 in batch 34
# Processed batch 34/250
#   Processing sample 1 in batch 35
#   Processing sample 2 in batch 35
#   Processing sample 3 in batch 35
#   Processing sample 4 in batch 35
# Processed batch 35/250
#   Processing sample 1 in batch 36
#   Processing sample 2 in batch 36
#   Processing sample 3 in batch 36
#   Processing sample 4 in batch 36
# Processed batch 36/250
#   Processing sample 1 in batch 37
#   Processing sample 2 in batch 37
#   Processing sample 3 in batch 37
#   Processing sample 4 in batch 37
# Processed batch 37/250
#   Processing sample 1 in batch 38
#   Processing sample 2 in batch 38
#   Processing sample 3 in batch 38
#   Processing sample 4 in batch 38
# Processed batch 38/250
#   Processing sample 1 in batch 39
#   Processing sample 2 in batch 39
#   Processing sample 3 in batch 39
#   Processing sample 4 in batch 39
# Processed batch 39/250
#   Processing sample 1 in batch 40
#   Processing sample 2 in batch 40
#   Processing sample 3 in batch 40
#   Processing sample 4 in batch 40
# Processed batch 40/250
#   Processing sample 1 in batch 41
#   Processing sample 2 in batch 41
#   Processing sample 3 in batch 41
#   Processing sample 4 in batch 41
# Processed batch 41/250
#   Processing sample 1 in batch 42
#   Processing sample 2 in batch 42
#   Processing sample 3 in batch 42
#   Processing sample 4 in batch 42
# Processed batch 42/250
#   Processing sample 1 in batch 43
#   Processing sample 2 in batch 43
#   Processing sample 3 in batch 43
#   Processing sample 4 in batch 43
# Processed batch 43/250
#   Processing sample 1 in batch 44
#   Processing sample 2 in batch 44
#   Processing sample 3 in batch 44
#   Processing sample 4 in batch 44
# Processed batch 44/250
#   Processing sample 1 in batch 45
#   Processing sample 2 in batch 45
#   Processing sample 3 in batch 45
#   Processing sample 4 in batch 45
# Processed batch 45/250
#   Processing sample 1 in batch 46
#   Processing sample 2 in batch 46
#   Processing sample 3 in batch 46
#   Processing sample 4 in batch 46
# Processed batch 46/250
#   Processing sample 1 in batch 47
#   Processing sample 2 in batch 47
#   Processing sample 3 in batch 47
#   Processing sample 4 in batch 47
# Processed batch 47/250
#   Processing sample 1 in batch 48
#   Processing sample 2 in batch 48
#   Processing sample 3 in batch 48
#   Processing sample 4 in batch 48
# Processed batch 48/250
#   Processing sample 1 in batch 49
#   Processing sample 2 in batch 49
#   Processing sample 3 in batch 49
#   Processing sample 4 in batch 49
# Processed batch 49/250
#   Processing sample 1 in batch 50
#   Processing sample 2 in batch 50
#   Processing sample 3 in batch 50
#   Processing sample 4 in batch 50
# Processed batch 50/250
#   Processing sample 1 in batch 51
#   Processing sample 2 in batch 51
#   Processing sample 3 in batch 51
#   Processing sample 4 in batch 51
# Processed batch 51/250
#   Processing sample 1 in batch 52
#   Processing sample 2 in batch 52
#   Processing sample 3 in batch 52
#   Processing sample 4 in batch 52
# Processed batch 52/250
#   Processing sample 1 in batch 53
#   Processing sample 2 in batch 53
#   Processing sample 3 in batch 53
#   Processing sample 4 in batch 53
# Processed batch 53/250
#   Processing sample 1 in batch 54
#   Processing sample 2 in batch 54
#   Processing sample 3 in batch 54
#   Processing sample 4 in batch 54
# Processed batch 54/250
#   Processing sample 1 in batch 55
#   Processing sample 2 in batch 55
#   Processing sample 3 in batch 55
#   Processing sample 4 in batch 55
# Processed batch 55/250
#   Processing sample 1 in batch 56
#   Processing sample 2 in batch 56
#   Processing sample 3 in batch 56
#   Processing sample 4 in batch 56
# Processed batch 56/250
#   Processing sample 1 in batch 57
#   Processing sample 2 in batch 57
#   Processing sample 3 in batch 57
#   Processing sample 4 in batch 57
# Processed batch 57/250
#   Processing sample 1 in batch 58
#   Processing sample 2 in batch 58
#   Processing sample 3 in batch 58
#   Processing sample 4 in batch 58
# Processed batch 58/250
#   Processing sample 1 in batch 59
#   Processing sample 2 in batch 59
#   Processing sample 3 in batch 59
#   Processing sample 4 in batch 59
# Processed batch 59/250
#   Processing sample 1 in batch 60
#   Processing sample 2 in batch 60
#   Processing sample 3 in batch 60
#   Processing sample 4 in batch 60
# Processed batch 60/250
#   Processing sample 1 in batch 61
#   Processing sample 2 in batch 61
#   Processing sample 3 in batch 61
#   Processing sample 4 in batch 61
# Processed batch 61/250
#   Processing sample 1 in batch 62
#   Processing sample 2 in batch 62
#   Processing sample 3 in batch 62
#   Processing sample 4 in batch 62
# Processed batch 62/250
#   Processing sample 1 in batch 63
#   Processing sample 2 in batch 63
#   Processing sample 3 in batch 63
#   Processing sample 4 in batch 63
# Processed batch 63/250
#   Processing sample 1 in batch 64
#   Processing sample 2 in batch 64
#   Processing sample 3 in batch 64
#   Processing sample 4 in batch 64
# Processed batch 64/250
#   Processing sample 1 in batch 65
#   Processing sample 2 in batch 65
#   Processing sample 3 in batch 65
#   Processing sample 4 in batch 65
# Processed batch 65/250
#   Processing sample 1 in batch 66
#   Processing sample 2 in batch 66
#   Processing sample 3 in batch 66
#   Processing sample 4 in batch 66
# Processed batch 66/250
#   Processing sample 1 in batch 67
#   Processing sample 2 in batch 67
#   Processing sample 3 in batch 67
#   Processing sample 4 in batch 67
# Processed batch 67/250
#   Processing sample 1 in batch 68
#   Processing sample 2 in batch 68
#   Processing sample 3 in batch 68
#   Processing sample 4 in batch 68
# Processed batch 68/250
#   Processing sample 1 in batch 69
#   Processing sample 2 in batch 69
#   Processing sample 3 in batch 69
#   Processing sample 4 in batch 69
# Processed batch 69/250
#   Processing sample 1 in batch 70
#   Processing sample 2 in batch 70
#   Processing sample 3 in batch 70
#   Processing sample 4 in batch 70
# Processed batch 70/250
#   Processing sample 1 in batch 71
#   Processing sample 2 in batch 71
#   Processing sample 3 in batch 71
#   Processing sample 4 in batch 71
# Processed batch 71/250
#   Processing sample 1 in batch 72
#   Processing sample 2 in batch 72
#   Processing sample 3 in batch 72
#   Processing sample 4 in batch 72
# Processed batch 72/250
#   Processing sample 1 in batch 73
#   Processing sample 2 in batch 73
#   Processing sample 3 in batch 73
#   Processing sample 4 in batch 73
# Processed batch 73/250
#   Processing sample 1 in batch 74
#   Processing sample 2 in batch 74
#   Processing sample 3 in batch 74
#   Processing sample 4 in batch 74
# Processed batch 74/250
#   Processing sample 1 in batch 75
#   Processing sample 2 in batch 75
#   Processing sample 3 in batch 75
#   Processing sample 4 in batch 75
# Processed batch 75/250
#   Processing sample 1 in batch 76
#   Processing sample 2 in batch 76
#   Processing sample 3 in batch 76
#   Processing sample 4 in batch 76
# Processed batch 76/250
#   Processing sample 1 in batch 77
#   Processing sample 2 in batch 77
#   Processing sample 3 in batch 77
#   Processing sample 4 in batch 77
# Processed batch 77/250
#   Processing sample 1 in batch 78
#   Processing sample 2 in batch 78
#   Processing sample 3 in batch 78
#   Processing sample 4 in batch 78
# Processed batch 78/250
#   Processing sample 1 in batch 79
#   Processing sample 2 in batch 79
#   Processing sample 3 in batch 79
#   Processing sample 4 in batch 79
# Processed batch 79/250
#   Processing sample 1 in batch 80
#   Processing sample 2 in batch 80
#   Processing sample 3 in batch 80
#   Processing sample 4 in batch 80
# Processed batch 80/250
#   Processing sample 1 in batch 81
#   Processing sample 2 in batch 81
#   Processing sample 3 in batch 81
#   Processing sample 4 in batch 81
# Processed batch 81/250
#   Processing sample 1 in batch 82
#   Processing sample 2 in batch 82
#   Processing sample 3 in batch 82
#   Processing sample 4 in batch 82
# Processed batch 82/250
#   Processing sample 1 in batch 83
#   Processing sample 2 in batch 83
#   Processing sample 3 in batch 83
#   Processing sample 4 in batch 83
# Processed batch 83/250
#   Processing sample 1 in batch 84
#   Processing sample 2 in batch 84
#   Processing sample 3 in batch 84
#   Processing sample 4 in batch 84
# Processed batch 84/250
#   Processing sample 1 in batch 85
#   Processing sample 2 in batch 85
#   Processing sample 3 in batch 85
#   Processing sample 4 in batch 85
# Processed batch 85/250
#   Processing sample 1 in batch 86
#   Processing sample 2 in batch 86
#   Processing sample 3 in batch 86
#   Processing sample 4 in batch 86
# Processed batch 86/250
#   Processing sample 1 in batch 87
#   Processing sample 2 in batch 87
#   Processing sample 3 in batch 87
#   Processing sample 4 in batch 87
# Processed batch 87/250
#   Processing sample 1 in batch 88
#   Processing sample 2 in batch 88
#   Processing sample 3 in batch 88
#   Processing sample 4 in batch 88
# Processed batch 88/250
#   Processing sample 1 in batch 89
#   Processing sample 2 in batch 89
#   Processing sample 3 in batch 89
#   Processing sample 4 in batch 89
# Processed batch 89/250
#   Processing sample 1 in batch 90
#   Processing sample 2 in batch 90
#   Processing sample 3 in batch 90
#   Processing sample 4 in batch 90
# Processed batch 90/250
#   Processing sample 1 in batch 91
#   Processing sample 2 in batch 91
#   Processing sample 3 in batch 91
#   Processing sample 4 in batch 91
# Processed batch 91/250
#   Processing sample 1 in batch 92
#   Processing sample 2 in batch 92
#   Processing sample 3 in batch 92
#   Processing sample 4 in batch 92
# Processed batch 92/250
#   Processing sample 1 in batch 93
#   Processing sample 2 in batch 93
#   Processing sample 3 in batch 93
#   Processing sample 4 in batch 93
# Processed batch 93/250
#   Processing sample 1 in batch 94
#   Processing sample 2 in batch 94
#   Processing sample 3 in batch 94
#   Processing sample 4 in batch 94
# Processed batch 94/250
#   Processing sample 1 in batch 95
#   Processing sample 2 in batch 95
#   Processing sample 3 in batch 95
#   Processing sample 4 in batch 95
# Processed batch 95/250
#   Processing sample 1 in batch 96
#   Processing sample 2 in batch 96
#   Processing sample 3 in batch 96
#   Processing sample 4 in batch 96
# Processed batch 96/250
#   Processing sample 1 in batch 97
#   Processing sample 2 in batch 97
#   Processing sample 3 in batch 97
#   Processing sample 4 in batch 97
# Processed batch 97/250
#   Processing sample 1 in batch 98
#   Processing sample 2 in batch 98
#   Processing sample 3 in batch 98
#   Processing sample 4 in batch 98
# Processed batch 98/250
#   Processing sample 1 in batch 99
#   Processing sample 2 in batch 99
#   Processing sample 3 in batch 99
#   Processing sample 4 in batch 99
# Processed batch 99/250
#   Processing sample 1 in batch 100
#   Processing sample 2 in batch 100
#   Processing sample 3 in batch 100
#   Processing sample 4 in batch 100
# Processed batch 100/250
#   Processing sample 1 in batch 101
#   Processing sample 2 in batch 101
#   Processing sample 3 in batch 101
#   Processing sample 4 in batch 101
# Processed batch 101/250
#   Processing sample 1 in batch 102
#   Processing sample 2 in batch 102
#   Processing sample 3 in batch 102
#   Processing sample 4 in batch 102
# Processed batch 102/250
#   Processing sample 1 in batch 103
#   Processing sample 2 in batch 103
#   Processing sample 3 in batch 103
#   Processing sample 4 in batch 103
# Processed batch 103/250
#   Processing sample 1 in batch 104
#   Processing sample 2 in batch 104
#   Processing sample 3 in batch 104
#   Processing sample 4 in batch 104
# Processed batch 104/250
#   Processing sample 1 in batch 105
#   Processing sample 2 in batch 105
#   Processing sample 3 in batch 105
#   Processing sample 4 in batch 105
# Processed batch 105/250
#   Processing sample 1 in batch 106
#   Processing sample 2 in batch 106
#   Processing sample 3 in batch 106
#   Processing sample 4 in batch 106
# Processed batch 106/250
#   Processing sample 1 in batch 107
#   Processing sample 2 in batch 107
#   Processing sample 3 in batch 107
#   Processing sample 4 in batch 107
# Processed batch 107/250
#   Processing sample 1 in batch 108
#   Processing sample 2 in batch 108
#   Processing sample 3 in batch 108
#   Processing sample 4 in batch 108
# Processed batch 108/250
#   Processing sample 1 in batch 109
#   Processing sample 2 in batch 109
#   Processing sample 3 in batch 109
#   Processing sample 4 in batch 109
# Processed batch 109/250
#   Processing sample 1 in batch 110
#   Processing sample 2 in batch 110
#   Processing sample 3 in batch 110
#   Processing sample 4 in batch 110
# Processed batch 110/250
#   Processing sample 1 in batch 111
#   Processing sample 2 in batch 111
#   Processing sample 3 in batch 111
#   Processing sample 4 in batch 111
# Processed batch 111/250
#   Processing sample 1 in batch 112
#   Processing sample 2 in batch 112
#   Processing sample 3 in batch 112
#   Processing sample 4 in batch 112
# Processed batch 112/250
#   Processing sample 1 in batch 113
#   Processing sample 2 in batch 113
#   Processing sample 3 in batch 113
#   Processing sample 4 in batch 113
# Processed batch 113/250
#   Processing sample 1 in batch 114
#   Processing sample 2 in batch 114
#   Processing sample 3 in batch 114
#   Processing sample 4 in batch 114
# Processed batch 114/250
#   Processing sample 1 in batch 115
#   Processing sample 2 in batch 115
#   Processing sample 3 in batch 115
#   Processing sample 4 in batch 115
# Processed batch 115/250
#   Processing sample 1 in batch 116
#   Processing sample 2 in batch 116
#   Processing sample 3 in batch 116
#   Processing sample 4 in batch 116
# Processed batch 116/250
#   Processing sample 1 in batch 117
#   Processing sample 2 in batch 117
#   Processing sample 3 in batch 117
#   Processing sample 4 in batch 117
# Processed batch 117/250
#   Processing sample 1 in batch 118
#   Processing sample 2 in batch 118
#   Processing sample 3 in batch 118
#   Processing sample 4 in batch 118
# Processed batch 118/250
#   Processing sample 1 in batch 119
#   Processing sample 2 in batch 119
#   Processing sample 3 in batch 119
#   Processing sample 4 in batch 119
# Processed batch 119/250
#   Processing sample 1 in batch 120
#   Processing sample 2 in batch 120
#   Processing sample 3 in batch 120
#   Processing sample 4 in batch 120
# Processed batch 120/250
#   Processing sample 1 in batch 121
#   Processing sample 2 in batch 121
#   Processing sample 3 in batch 121
#   Processing sample 4 in batch 121
# Processed batch 121/250
#   Processing sample 1 in batch 122
#   Processing sample 2 in batch 122
#   Processing sample 3 in batch 122
#   Processing sample 4 in batch 122
# Processed batch 122/250
#   Processing sample 1 in batch 123
#   Processing sample 2 in batch 123
#   Processing sample 3 in batch 123
#   Processing sample 4 in batch 123
# Processed batch 123/250
#   Processing sample 1 in batch 124
#   Processing sample 2 in batch 124
#   Processing sample 3 in batch 124
#   Processing sample 4 in batch 124
# Processed batch 124/250
#   Processing sample 1 in batch 125
#   Processing sample 2 in batch 125
#   Processing sample 3 in batch 125
#   Processing sample 4 in batch 125
# Processed batch 125/250
#   Processing sample 1 in batch 126
#   Processing sample 2 in batch 126
#   Processing sample 3 in batch 126
#   Processing sample 4 in batch 126
# Processed batch 126/250
#   Processing sample 1 in batch 127
#   Processing sample 2 in batch 127
#   Processing sample 3 in batch 127
#   Processing sample 4 in batch 127
# Processed batch 127/250
#   Processing sample 1 in batch 128
#   Processing sample 2 in batch 128
#   Processing sample 3 in batch 128
#   Processing sample 4 in batch 128
# Processed batch 128/250
#   Processing sample 1 in batch 129
#   Processing sample 2 in batch 129
#   Processing sample 3 in batch 129
#   Processing sample 4 in batch 129
# Processed batch 129/250
#   Processing sample 1 in batch 130
#   Processing sample 2 in batch 130
#   Processing sample 3 in batch 130
#   Processing sample 4 in batch 130
# Processed batch 130/250
#   Processing sample 1 in batch 131
#   Processing sample 2 in batch 131
#   Processing sample 3 in batch 131
#   Processing sample 4 in batch 131
# Processed batch 131/250
#   Processing sample 1 in batch 132
#   Processing sample 2 in batch 132
#   Processing sample 3 in batch 132
#   Processing sample 4 in batch 132
# Processed batch 132/250
#   Processing sample 1 in batch 133
#   Processing sample 2 in batch 133
#   Processing sample 3 in batch 133
#   Processing sample 4 in batch 133
# Processed batch 133/250
#   Processing sample 1 in batch 134
#   Processing sample 2 in batch 134
#   Processing sample 3 in batch 134
#   Processing sample 4 in batch 134
# Processed batch 134/250
#   Processing sample 1 in batch 135
#   Processing sample 2 in batch 135
#   Processing sample 3 in batch 135
#   Processing sample 4 in batch 135
# Processed batch 135/250
#   Processing sample 1 in batch 136
#   Processing sample 2 in batch 136
#   Processing sample 3 in batch 136
#   Processing sample 4 in batch 136
# Processed batch 136/250
#   Processing sample 1 in batch 137
#   Processing sample 2 in batch 137
#   Processing sample 3 in batch 137
#   Processing sample 4 in batch 137
# Processed batch 137/250
#   Processing sample 1 in batch 138
#   Processing sample 2 in batch 138
#   Processing sample 3 in batch 138
#   Processing sample 4 in batch 138
# Processed batch 138/250
#   Processing sample 1 in batch 139
#   Processing sample 2 in batch 139
#   Processing sample 3 in batch 139
#   Processing sample 4 in batch 139
# Processed batch 139/250
#   Processing sample 1 in batch 140
#   Processing sample 2 in batch 140
#   Processing sample 3 in batch 140
#   Processing sample 4 in batch 140
# Processed batch 140/250
#   Processing sample 1 in batch 141
#   Processing sample 2 in batch 141
#   Processing sample 3 in batch 141
#   Processing sample 4 in batch 141
# Processed batch 141/250
#   Processing sample 1 in batch 142
#   Processing sample 2 in batch 142
#   Processing sample 3 in batch 142
#   Processing sample 4 in batch 142
# Processed batch 142/250
#   Processing sample 1 in batch 143
#   Processing sample 2 in batch 143
#   Processing sample 3 in batch 143
#   Processing sample 4 in batch 143
# Processed batch 143/250
#   Processing sample 1 in batch 144
#   Processing sample 2 in batch 144
#   Processing sample 3 in batch 144
#   Processing sample 4 in batch 144
# Processed batch 144/250
#   Processing sample 1 in batch 145
#   Processing sample 2 in batch 145
#   Processing sample 3 in batch 145
#   Processing sample 4 in batch 145
# Processed batch 145/250
#   Processing sample 1 in batch 146
#   Processing sample 2 in batch 146
#   Processing sample 3 in batch 146
#   Processing sample 4 in batch 146
# Processed batch 146/250
#   Processing sample 1 in batch 147
#   Processing sample 2 in batch 147
#   Processing sample 3 in batch 147
#   Processing sample 4 in batch 147
# Processed batch 147/250
#   Processing sample 1 in batch 148
#   Processing sample 2 in batch 148
#   Processing sample 3 in batch 148
#   Processing sample 4 in batch 148
# Processed batch 148/250
#   Processing sample 1 in batch 149
#   Processing sample 2 in batch 149
#   Processing sample 3 in batch 149
#   Processing sample 4 in batch 149
# Processed batch 149/250
#   Processing sample 1 in batch 150
#   Processing sample 2 in batch 150
#   Processing sample 3 in batch 150
#   Processing sample 4 in batch 150
# Processed batch 150/250
#   Processing sample 1 in batch 151
#   Processing sample 2 in batch 151
#   Processing sample 3 in batch 151
#   Processing sample 4 in batch 151
# Processed batch 151/250
#   Processing sample 1 in batch 152
#   Processing sample 2 in batch 152
#   Processing sample 3 in batch 152
#   Processing sample 4 in batch 152
# Processed batch 152/250
#   Processing sample 1 in batch 153
#   Processing sample 2 in batch 153
#   Processing sample 3 in batch 153
#   Processing sample 4 in batch 153
# Processed batch 153/250
#   Processing sample 1 in batch 154
#   Processing sample 2 in batch 154
#   Processing sample 3 in batch 154
#   Processing sample 4 in batch 154
# Processed batch 154/250
#   Processing sample 1 in batch 155
#   Processing sample 2 in batch 155
#   Processing sample 3 in batch 155
#   Processing sample 4 in batch 155
# Processed batch 155/250
#   Processing sample 1 in batch 156
#   Processing sample 2 in batch 156
#   Processing sample 3 in batch 156
#   Processing sample 4 in batch 156
# Processed batch 156/250
#   Processing sample 1 in batch 157
#   Processing sample 2 in batch 157
#   Processing sample 3 in batch 157
#   Processing sample 4 in batch 157
# Processed batch 157/250
#   Processing sample 1 in batch 158
#   Processing sample 2 in batch 158
#   Processing sample 3 in batch 158
#   Processing sample 4 in batch 158
# Processed batch 158/250
#   Processing sample 1 in batch 159
#   Processing sample 2 in batch 159
#   Processing sample 3 in batch 159
#   Processing sample 4 in batch 159
# Processed batch 159/250
#   Processing sample 1 in batch 160
#   Processing sample 2 in batch 160
#   Processing sample 3 in batch 160
#   Processing sample 4 in batch 160
# Processed batch 160/250
#   Processing sample 1 in batch 161
#   Processing sample 2 in batch 161
#   Processing sample 3 in batch 161
#   Processing sample 4 in batch 161
# Processed batch 161/250
#   Processing sample 1 in batch 162
#   Processing sample 2 in batch 162
#   Processing sample 3 in batch 162
#   Processing sample 4 in batch 162
# Processed batch 162/250
#   Processing sample 1 in batch 163
#   Processing sample 2 in batch 163
#   Processing sample 3 in batch 163
#   Processing sample 4 in batch 163
# Processed batch 163/250
#   Processing sample 1 in batch 164
#   Processing sample 2 in batch 164
#   Processing sample 3 in batch 164
#   Processing sample 4 in batch 164
# Processed batch 164/250
#   Processing sample 1 in batch 165
#   Processing sample 2 in batch 165
#   Processing sample 3 in batch 165
#   Processing sample 4 in batch 165
# Processed batch 165/250
#   Processing sample 1 in batch 166
#   Processing sample 2 in batch 166
#   Processing sample 3 in batch 166
#   Processing sample 4 in batch 166
# Processed batch 166/250
#   Processing sample 1 in batch 167
#   Processing sample 2 in batch 167
#   Processing sample 3 in batch 167
#   Processing sample 4 in batch 167
# Processed batch 167/250
#   Processing sample 1 in batch 168
#   Processing sample 2 in batch 168
#   Processing sample 3 in batch 168
#   Processing sample 4 in batch 168
# Processed batch 168/250
#   Processing sample 1 in batch 169
#   Processing sample 2 in batch 169
#   Processing sample 3 in batch 169
#   Processing sample 4 in batch 169
# Processed batch 169/250
#   Processing sample 1 in batch 170
#   Processing sample 2 in batch 170
#   Processing sample 3 in batch 170
#   Processing sample 4 in batch 170
# Processed batch 170/250
#   Processing sample 1 in batch 171
#   Processing sample 2 in batch 171
#   Processing sample 3 in batch 171
#   Processing sample 4 in batch 171
# Processed batch 171/250
#   Processing sample 1 in batch 172
#   Processing sample 2 in batch 172
#   Processing sample 3 in batch 172
#   Processing sample 4 in batch 172
# Processed batch 172/250
#   Processing sample 1 in batch 173
#   Processing sample 2 in batch 173
#   Processing sample 3 in batch 173
#   Processing sample 4 in batch 173
# Processed batch 173/250
#   Processing sample 1 in batch 174
#   Processing sample 2 in batch 174
#   Processing sample 3 in batch 174
#   Processing sample 4 in batch 174
# Processed batch 174/250
#   Processing sample 1 in batch 175
#   Processing sample 2 in batch 175
#   Processing sample 3 in batch 175
#   Processing sample 4 in batch 175
# Processed batch 175/250
#   Processing sample 1 in batch 176
#   Processing sample 2 in batch 176
#   Processing sample 3 in batch 176
#   Processing sample 4 in batch 176
# Processed batch 176/250
#   Processing sample 1 in batch 177
#   Processing sample 2 in batch 177
#   Processing sample 3 in batch 177
#   Processing sample 4 in batch 177
# Processed batch 177/250
#   Processing sample 1 in batch 178
#   Processing sample 2 in batch 178
#   Processing sample 3 in batch 178
#   Processing sample 4 in batch 178
# Processed batch 178/250
#   Processing sample 1 in batch 179
#   Processing sample 2 in batch 179
#   Processing sample 3 in batch 179
#   Processing sample 4 in batch 179
# Processed batch 179/250
#   Processing sample 1 in batch 180
#   Processing sample 2 in batch 180
#   Processing sample 3 in batch 180
#   Processing sample 4 in batch 180
# Processed batch 180/250
#   Processing sample 1 in batch 181
#   Processing sample 2 in batch 181
#   Processing sample 3 in batch 181
#   Processing sample 4 in batch 181
# Processed batch 181/250
#   Processing sample 1 in batch 182
#   Processing sample 2 in batch 182
#   Processing sample 3 in batch 182
#   Processing sample 4 in batch 182
# Processed batch 182/250
#   Processing sample 1 in batch 183
#   Processing sample 2 in batch 183
#   Processing sample 3 in batch 183
#   Processing sample 4 in batch 183
# Processed batch 183/250
#   Processing sample 1 in batch 184
#   Processing sample 2 in batch 184
#   Processing sample 3 in batch 184
#   Processing sample 4 in batch 184
# Processed batch 184/250
#   Processing sample 1 in batch 185
#   Processing sample 2 in batch 185
#   Processing sample 3 in batch 185
#   Processing sample 4 in batch 185
# Processed batch 185/250
#   Processing sample 1 in batch 186
#   Processing sample 2 in batch 186
#   Processing sample 3 in batch 186
#   Processing sample 4 in batch 186
# Processed batch 186/250
#   Processing sample 1 in batch 187
#   Processing sample 2 in batch 187
#   Processing sample 3 in batch 187
#   Processing sample 4 in batch 187
# Processed batch 187/250
#   Processing sample 1 in batch 188
#   Processing sample 2 in batch 188
#   Processing sample 3 in batch 188
#   Processing sample 4 in batch 188
# Processed batch 188/250
#   Processing sample 1 in batch 189
#   Processing sample 2 in batch 189
#   Processing sample 3 in batch 189
#   Processing sample 4 in batch 189
# Processed batch 189/250
#   Processing sample 1 in batch 190
#   Processing sample 2 in batch 190
#   Processing sample 3 in batch 190
#   Processing sample 4 in batch 190
# Processed batch 190/250
#   Processing sample 1 in batch 191
#   Processing sample 2 in batch 191
#   Processing sample 3 in batch 191
#   Processing sample 4 in batch 191
# Processed batch 191/250
#   Processing sample 1 in batch 192
#   Processing sample 2 in batch 192
#   Processing sample 3 in batch 192
#   Processing sample 4 in batch 192
# Processed batch 192/250
#   Processing sample 1 in batch 193
#   Processing sample 2 in batch 193
#   Processing sample 3 in batch 193
#   Processing sample 4 in batch 193
# Processed batch 193/250
#   Processing sample 1 in batch 194
#   Processing sample 2 in batch 194
#   Processing sample 3 in batch 194
#   Processing sample 4 in batch 194
# Processed batch 194/250
#   Processing sample 1 in batch 195
#   Processing sample 2 in batch 195
#   Processing sample 3 in batch 195
#   Processing sample 4 in batch 195
# Processed batch 195/250
#   Processing sample 1 in batch 196
#   Processing sample 2 in batch 196
#   Processing sample 3 in batch 196
#   Processing sample 4 in batch 196
# Processed batch 196/250
#   Processing sample 1 in batch 197
#   Processing sample 2 in batch 197
#   Processing sample 3 in batch 197
#   Processing sample 4 in batch 197
# Processed batch 197/250
#   Processing sample 1 in batch 198
#   Processing sample 2 in batch 198
#   Processing sample 3 in batch 198
#   Processing sample 4 in batch 198
# Processed batch 198/250
#   Processing sample 1 in batch 199
#   Processing sample 2 in batch 199
#   Processing sample 3 in batch 199
#   Processing sample 4 in batch 199
# Processed batch 199/250
#   Processing sample 1 in batch 200
#   Processing sample 2 in batch 200
#   Processing sample 3 in batch 200
#   Processing sample 4 in batch 200
# Processed batch 200/250
#   Processing sample 1 in batch 201
#   Processing sample 2 in batch 201
#   Processing sample 3 in batch 201
#   Processing sample 4 in batch 201
# Processed batch 201/250
#   Processing sample 1 in batch 202
#   Processing sample 2 in batch 202
#   Processing sample 3 in batch 202
#   Processing sample 4 in batch 202
# Processed batch 202/250
#   Processing sample 1 in batch 203
#   Processing sample 2 in batch 203
#   Processing sample 3 in batch 203
#   Processing sample 4 in batch 203
# Processed batch 203/250
#   Processing sample 1 in batch 204
#   Processing sample 2 in batch 204
#   Processing sample 3 in batch 204
#   Processing sample 4 in batch 204
# Processed batch 204/250
#   Processing sample 1 in batch 205
#   Processing sample 2 in batch 205
#   Processing sample 3 in batch 205
#   Processing sample 4 in batch 205
# Processed batch 205/250
#   Processing sample 1 in batch 206
#   Processing sample 2 in batch 206
#   Processing sample 3 in batch 206
#   Processing sample 4 in batch 206
# Processed batch 206/250
#   Processing sample 1 in batch 207
#   Processing sample 2 in batch 207
#   Processing sample 3 in batch 207
#   Processing sample 4 in batch 207
# Processed batch 207/250
#   Processing sample 1 in batch 208
#   Processing sample 2 in batch 208
#   Processing sample 3 in batch 208
#   Processing sample 4 in batch 208
# Processed batch 208/250
#   Processing sample 1 in batch 209
#   Processing sample 2 in batch 209
#   Processing sample 3 in batch 209
#   Processing sample 4 in batch 209
# Processed batch 209/250
#   Processing sample 1 in batch 210
#   Processing sample 2 in batch 210
#   Processing sample 3 in batch 210
#   Processing sample 4 in batch 210
# Processed batch 210/250
#   Processing sample 1 in batch 211
#   Processing sample 2 in batch 211
#   Processing sample 3 in batch 211
#   Processing sample 4 in batch 211
# Processed batch 211/250
#   Processing sample 1 in batch 212
#   Processing sample 2 in batch 212
#   Processing sample 3 in batch 212
#   Processing sample 4 in batch 212
# Processed batch 212/250
#   Processing sample 1 in batch 213
#   Processing sample 2 in batch 213
#   Processing sample 3 in batch 213
#   Processing sample 4 in batch 213
# Processed batch 213/250
#   Processing sample 1 in batch 214
#   Processing sample 2 in batch 214
#   Processing sample 3 in batch 214
#   Processing sample 4 in batch 214
# Processed batch 214/250
#   Processing sample 1 in batch 215
#   Processing sample 2 in batch 215
#   Processing sample 3 in batch 215
#   Processing sample 4 in batch 215
# Processed batch 215/250
#   Processing sample 1 in batch 216
#   Processing sample 2 in batch 216
#   Processing sample 3 in batch 216
#   Processing sample 4 in batch 216
# Processed batch 216/250
#   Processing sample 1 in batch 217
#   Processing sample 2 in batch 217
#   Processing sample 3 in batch 217
#   Processing sample 4 in batch 217
# Processed batch 217/250
#   Processing sample 1 in batch 218
#   Processing sample 2 in batch 218
#   Processing sample 3 in batch 218
#   Processing sample 4 in batch 218
# Processed batch 218/250
#   Processing sample 1 in batch 219
#   Processing sample 2 in batch 219
#   Processing sample 3 in batch 219
#   Processing sample 4 in batch 219
# Processed batch 219/250
#   Processing sample 1 in batch 220
#   Processing sample 2 in batch 220
#   Processing sample 3 in batch 220
#   Processing sample 4 in batch 220
# Processed batch 220/250
#   Processing sample 1 in batch 221
#   Processing sample 2 in batch 221
#   Processing sample 3 in batch 221
#   Processing sample 4 in batch 221
# Processed batch 221/250
#   Processing sample 1 in batch 222
#   Processing sample 2 in batch 222
#   Processing sample 3 in batch 222
#   Processing sample 4 in batch 222
# Processed batch 222/250
#   Processing sample 1 in batch 223
#   Processing sample 2 in batch 223
#   Processing sample 3 in batch 223
#   Processing sample 4 in batch 223
# Processed batch 223/250
#   Processing sample 1 in batch 224
#   Processing sample 2 in batch 224
#   Processing sample 3 in batch 224
#   Processing sample 4 in batch 224
# Processed batch 224/250
#   Processing sample 1 in batch 225
#   Processing sample 2 in batch 225
#   Processing sample 3 in batch 225
#   Processing sample 4 in batch 225
# Processed batch 225/250
#   Processing sample 1 in batch 226
#   Processing sample 2 in batch 226
#   Processing sample 3 in batch 226
#   Processing sample 4 in batch 226
# Processed batch 226/250
#   Processing sample 1 in batch 227
#   Processing sample 2 in batch 227
#   Processing sample 3 in batch 227
#   Processing sample 4 in batch 227
# Processed batch 227/250
#   Processing sample 1 in batch 228
#   Processing sample 2 in batch 228
#   Processing sample 3 in batch 228
#   Processing sample 4 in batch 228
# Processed batch 228/250
#   Processing sample 1 in batch 229
#   Processing sample 2 in batch 229
#   Processing sample 3 in batch 229
#   Processing sample 4 in batch 229
# Processed batch 229/250
#   Processing sample 1 in batch 230
#   Processing sample 2 in batch 230
#   Processing sample 3 in batch 230
#   Processing sample 4 in batch 230
# Processed batch 230/250
#   Processing sample 1 in batch 231
#   Processing sample 2 in batch 231
#   Processing sample 3 in batch 231
#   Processing sample 4 in batch 231
# Processed batch 231/250
#   Processing sample 1 in batch 232
#   Processing sample 2 in batch 232
#   Processing sample 3 in batch 232
#   Processing sample 4 in batch 232
# Processed batch 232/250
#   Processing sample 1 in batch 233
#   Processing sample 2 in batch 233
#   Processing sample 3 in batch 233
#   Processing sample 4 in batch 233
# Processed batch 233/250
#   Processing sample 1 in batch 234
#   Processing sample 2 in batch 234
#   Processing sample 3 in batch 234
#   Processing sample 4 in batch 234
# Processed batch 234/250
#   Processing sample 1 in batch 235
#   Processing sample 2 in batch 235
#   Processing sample 3 in batch 235
#   Processing sample 4 in batch 235
# Processed batch 235/250
#   Processing sample 1 in batch 236
#   Processing sample 2 in batch 236
#   Processing sample 3 in batch 236
#   Processing sample 4 in batch 236
# Processed batch 236/250
#   Processing sample 1 in batch 237
#   Processing sample 2 in batch 237
#   Processing sample 3 in batch 237
#   Processing sample 4 in batch 237
# Processed batch 237/250
#   Processing sample 1 in batch 238
#   Processing sample 2 in batch 238
#   Processing sample 3 in batch 238
#   Processing sample 4 in batch 238
# Processed batch 238/250
#   Processing sample 1 in batch 239
#   Processing sample 2 in batch 239
#   Processing sample 3 in batch 239
#   Processing sample 4 in batch 239
# Processed batch 239/250
#   Processing sample 1 in batch 240
#   Processing sample 2 in batch 240
#   Processing sample 3 in batch 240
#   Processing sample 4 in batch 240
# Processed batch 240/250
#   Processing sample 1 in batch 241
#   Processing sample 2 in batch 241
#   Processing sample 3 in batch 241
#   Processing sample 4 in batch 241
# Processed batch 241/250
#   Processing sample 1 in batch 242
#   Processing sample 2 in batch 242
#   Processing sample 3 in batch 242
#   Processing sample 4 in batch 242
# Processed batch 242/250
#   Processing sample 1 in batch 243
#   Processing sample 2 in batch 243
#   Processing sample 3 in batch 243
#   Processing sample 4 in batch 243
# Processed batch 243/250
#   Processing sample 1 in batch 244
#   Processing sample 2 in batch 244
#   Processing sample 3 in batch 244
#   Processing sample 4 in batch 244
# Processed batch 244/250
#   Processing sample 1 in batch 245
#   Processing sample 2 in batch 245
#   Processing sample 3 in batch 245
#   Processing sample 4 in batch 245
# Processed batch 245/250
#   Processing sample 1 in batch 246
#   Processing sample 2 in batch 246
#   Processing sample 3 in batch 246
#   Processing sample 4 in batch 246
# Processed batch 246/250
#   Processing sample 1 in batch 247
#   Processing sample 2 in batch 247
#   Processing sample 3 in batch 247
#   Processing sample 4 in batch 247
# Processed batch 247/250
#   Processing sample 1 in batch 248
#   Processing sample 2 in batch 248
#   Processing sample 3 in batch 248
#   Processing sample 4 in batch 248
# Processed batch 248/250
#   Processing sample 1 in batch 249
#   Processing sample 2 in batch 249
#   Processing sample 3 in batch 249
#   Processing sample 4 in batch 249
# Processed batch 249/250
#   Processing sample 1 in batch 250
#   Processing sample 2 in batch 250
#   Processing sample 3 in batch 250
#   Processing sample 4 in batch 250
# Processed batch 250/250
# All samples processed!

# %%
for i in range(len(all_pred)):
    print("pred:", all_pred[i])
    print("ans:", all_ans[i])
# Out:
# pred: Model: Segment-Video
# Prompt: Locate Cottle in a video clip.
# ans: Model: Detect-Instrument
# Prompt: Mark the exact locations of cottle in the video.?
# pred: Model: Detect-Instrument
# Prompt: Track movement of cup forceps across video frames.
# ans: Model: Detect-Instrument
# Prompt: Track the movement of cup forceps across video frames.?
# pred: Model: Detect-Instrument
# Prompt: detect bounding boxes for dural scissors in video
# ans: Model: Detect-Instrument
# Prompt: Provide bounding boxes for all dural scissors detected in the video.?
# pred: Model: Segment-Video
# Prompt: Locate freer elevator in video and provide its coordinates.
# ans: Model: Detect-Instrument
# Prompt: Locate freer elevator in the video and provide its coordinates.?

# %%
import os
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')

# File Path
output_file_path = '/content/drive/MyDrive/pre_ans_SINGLE_text1.txt'

# Write data
with open(output_file_path, 'w') as file:
    for i in range(len(all_pred)):
        file.write(f"pred: {all_pred[i]}\n")
        file.write(f"ans: {all_ans[i]}\n")
        file.write("\n")  # 添加换行以便于阅读

print(f"file saved at: {output_file_path}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# file saved at: /content/drive/MyDrive/pre_ans_SINGLE_text1.txt

# %%
# 定义新的变量来存储提取的 Prompt 部分
all_pred_prompts = []
all_ans_prompts = []

# # 提取 Prompt 部分的函数
# def extract_prompt(entry):
#     for line in entry.split('\n'):
#         if line.startswith("Prompt:"):
#             return line[len("Prompt: "):]  # 去掉 "Prompt: " 保留内容
# def extract_prompt(entry):
#     lines = entry.split('\n')  # 按行分割
#     for line in lines:
#         if line.startswith("Prompt:"):
#             return line[len("Prompt: "):]  # 提取 "Prompt:" 后面的内容
#     # 如果没有 "Prompt:"，提取非空的其他行
#     for line in lines:
#         if line.strip() and not line.startswith("Model:"):
#             return line.strip()  # 返回非空且不以 "Model:" 开头的行
#     return None
def extract_prompt(entry):
    # 优先处理包含 "Prompt:" 的情况
    if "Prompt:" in entry:
        # 提取 "Prompt:" 后的内容
        return entry.split("Prompt:")[1].strip()
    else:
        # 如果没有 "Prompt:"，提取非空且不以 "Model:" 开头的部分
        for line in entry.split('\n'):
            if line.strip() and not line.startswith("Model:"):
                return line.strip()
    return None  # 如果没有找到内容，返回 None

# 提取 all_pred 和 all_ans 中的 Prompt 部分
all_pred_prompts = [extract_prompt(item) for item in all_pred]
all_ans_prompts = [extract_prompt(item) for item in all_ans]

# 打印结果验证
print("Extracted Prompts from all_pred:", all_pred_prompts)
print("Extracted Prompts from all_ans:", all_ans_prompts)
# Out:
# Extracted Prompts from all_pred: ['Locate Cottle in a video clip.', 'Track movement of cup forceps across video frames.', 'detect bounding boxes for dural scissors in video', 'Locate freer elevator in video and provide its coordinates.', 'Find haemostatic foam positions in video.', 'Identify instances where an irrigation syringe is used in the video.', 'Detect-Instrument', 'Segment regions involving micro doppler in video', 'annotate visible nasal cutting forceps with bounding boxes in video.', 'Segment-Video', 'Segment-Video and show exact locations of retractable knife.', 'Detect-Instrument', 'detect spatula dissector in video and provide bounding boxes', 'Locate stealth pointer in video and provide its coordinates.', 'Generate a map of all suction positions in the video.', 'Detect-Instrument', 'Detect and label tissue glue with timestamps in the video.', 'Segment regions involving bipolar forceps in video.', 'Annotate visible Cottle with bounding boxes.', 'Detect and highlight cup forceps in the video.', 'Segment-video, locate dural scissors.', 'Track movement of freer elevator across video frames.', 'detect haemostatic foam bounding boxes', 'Locate irrigation syringe in video and provide its coordinates?', 'Generate a map of all kerrison positions in the video.', 'Identify micro doppler instances in video.', 'Detect and label nasal cutting forceps with timestamps in the video.', 'Segment pituitary rongeurs in the video.', 'annotate all visible retractable knives in the video with bounding boxes', 'video highlight ring curette', 'Show exact locations of spatula dissector in the video.', 'Track the movement of a stealth pointer across video frames.', 'detect suction bounding boxes in video', 'Locate surgical drill in the video and provide its coordinates?', 'Identify and map all tissue glue positions in a given video.', 'Identify instances of bipolar forceps in the video.', 'Detect and label Cottle with timestamps in the video.', 'Segment regions involving cup forceps in video.', 'Annotate all visible dural scissors in the video with bounding boxes.', 'detect and highlight all freer elevators in a video.', 'Highlight haemostatic foam locations in video.', 'Track irrigation syringe movement across video frames.', 'detect kerrisons in video and provide bounding boxes', 'Locate micro doppler in video and provide its coordinates', 'Detect all nasal cutting forceps positions in a given video.', 'Detect-Instrument', 'Detect and label retractable knife with timestamps in the video.', 'Segment regions involving ring curette in video.', 'annotate visible spatula dissector with bounding boxes in video.', 'highlight all stealth pointer in video.', '"Annotate suction marks in the video with bounding boxes"', 'Track the movement of a surgical drill across video frames.', 'detect tissue glue in video and provide bounding boxes', 'Locate bipolar forceps in video and provide coordinates?', 'Generate a map of all Cottle positions in the video.', 'Identify instances where cup forceps is actively used in the video.', 'Detect and label dural scissors with timestamps in the video.', '"Video segment regions involving freer elevator"', 'Annotate visible haemostatic foam in the video with bounding boxes.', 'Detect and highlight all irrigation syringe in the video.', 'Locate kerrisons in the video.', 'Track micro doppler across frames in a video.', 'detect nasal cutting forceps bounding boxes in video', 'Locate pituitary rongeurs in the video and provide its coordinates?', 'detect retractable knife positions in video', 'Identify ring curette in video.', 'Detect and label spatula dissector with timestamps in video.', 'Segment-Video', 'Annotate visible suction in video with bounding boxes.', 'Detect and highlight surgical drill in video.', 'Highlight the locations of tissue glue in the video.', 'Track movement of bipolar forceps across video frames.', 'detect bounding boxes for all Cottle detected in the video', 'Locate cup forceps in video and provid ...
# Extracted Prompts from all_ans: ['Mark the exact locations of cottle in the video.?', 'Track the movement of cup forceps across video frames.?', 'Provide bounding boxes for all dural scissors detected in the video.?', 'Locate freer elevator in the video and provide its coordinates.?', 'Generate a map of all haemostatic foam positions in the video.?', 'Identify instances where irrigation syringe is actively used in the video.?', 'Detect and label kerrisons with timestamps in the video.?', 'Segment the regions involving micro doppler in the video.?', 'Annotate all visible nasal cutting forceps in the video with bounding boxes.?', 'Detect and highlight all pituitary rongeurs in the video.?', 'Mark the exact locations of retractable knife in the video.?', 'Track the movement of ring curette across video frames.?', 'Provide bounding boxes for all spatula dissector detected in the video.?', 'Locate stealth pointer in the video and provide its coordinates.?', 'Generate a map of all suction positions in the video.?', 'Identify instances where surgical drill is actively used in the video.?', 'Detect and label tissue glue with timestamps in the video.?', 'Segment the regions involving bipolar forceps in the video.?', 'Annotate all visible cottle in the video with bounding boxes.?', 'Detect and highlight all cup forceps in the video.?', 'Mark the exact locations of dural scissors in the video.?', 'Track the movement of freer elevator across video frames.?', 'Provide bounding boxes for all haemostatic foam detected in the video.?', 'Locate irrigation syringe in the video and provide its coordinates.?', 'Generate a map of all kerrisons positions in the video.?', 'Identify instances where micro doppler is actively used in the video.?', 'Detect and label nasal cutting forceps with timestamps in the video.?', 'Segment the regions involving pituitary rongeurs in the video.?', 'Annotate all visible retractable knife in the video with bounding boxes.?', 'Detect and highlight all ring curette in the video.?', 'Mark the exact locations of spatula dissector in the video.?', 'Track the movement of stealth pointer across video frames.?', 'Provide bounding boxes for all suction detected in the video.?', 'Locate surgical drill in the video and provide its coordinates.?', 'Generate a map of all tissue glue positions in the video.?', 'Identify instances where bipolar forceps is actively used in the video.?', 'Detect and label cottle with timestamps in the video.?', 'Segment the regions involving cup forceps in the video.?', 'Annotate all visible dural scissors in the video with bounding boxes.?', 'Detect and highlight all freer elevator in the video.?', 'Mark the exact locations of haemostatic foam in the video.?', 'Track the movement of irrigation syringe across video frames.?', 'Provide bounding boxes for all kerrisons detected in the video.?', 'Locate micro doppler in the video and provide its coordinates.?', 'Generate a map of all nasal cutting forceps positions in the video.?', 'Identify instances where pituitary rongeurs is actively used in the video.?', 'Detect and label retractable knife with timestamps in the video.?', 'Segment the regions involving ring curette in the video.?', 'Annotate all visible spatula dissector in the video with bounding boxes.?', 'Detect and highlight all stealth pointer in the video.?', 'Mark the exact locations of suction in the video.?', 'Track the movement of surgical drill across video frames.?', 'Provide bounding boxes for all tissue glue detected in the video.?', 'Locate bipolar forceps in the video and provide its coordinates.?', 'Generate a map of all cottle positions in the video.?', 'Identify instances where cup forceps is actively used in the video.?', 'Detect and label dural scissors with timestamps in the video.?', 'Segment the regions involving freer elevator in the video.?', 'Annotate all visible haemostatic foam in the video with bounding boxes.?', 'Detect and highlight all irrigation syringe in the vide ...

# %%
print(len(all_pred_prompts))

none_indices = [index for index, value in enumerate(all_pred_prompts) if value is None]

# 输出结果
if none_indices:
    print(f"列表中包含 None，位置为: {none_indices}")
else:
    print("列表中没有 None")
# Out:
# 1000
# 列表中没有 None

# %%
print(all_pred_prompts[343])
print(all_pred[343])
# Out:
# Explain the role of steps in segmentation tasks.
# Model: Segment-MRI Prompt: Explain the role of steps in segmentation tasks.

# %%
# !pip install rouge_score
rouge = evaluate.load("rouge")
rouge_results = rouge.compute(predictions= all_pred_prompts, references=all_ans_prompts)
print(rouge_results)
# Out:
# Requirement already satisfied: rouge_score in /usr/local/lib/python3.11/dist-packages (0.1.2)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.11/dist-packages (from rouge_score) (1.4.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.11/dist-packages (from rouge_score) (3.9.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from rouge_score) (1.26.4)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.11/dist-packages (from rouge_score) (1.17.0)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk->rouge_score) (8.1.8)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from nltk->rouge_score) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.11/dist-packages (from nltk->rouge_score) (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from nltk->rouge_score) (4.67.1)
# {'rouge1': 0.7480455409765763, 'rouge2': 0.5002196048920133, 'rougeL': 0.688541938812673, 'rougeLsum': 0.6891078923103502}

# %%
bleu_score = corpus_bleu(all_ans_prompts, all_pred_prompts, weights=(1.0, 0.0, 0.0, 0.0))
print(bleu_score)
# Out:
# 0.3536280233527939

# %%
import nltk
nltk.download('wordnet')
from nltk.tokenize import word_tokenize
nltk.download('punkt_tab')
import warnings
warnings.filterwarnings("ignore", category=UserWarning)

m_score=0
for line in zip(all_ans_prompts, all_pred_prompts):
    ref = word_tokenize(line[0])
    hypo = word_tokenize(line[1])
    m_score += meteor_score([ref], hypo)
meteors = m_score/len(all_ans)
print(meteors)
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# 0.6080526550973597

# %%
import re

# Function to extract the "Model" part from a given text
def extract_model(text):
    match = re.search(r"Model:\s*(.*?)\n", text)
    return match.group(1) if match else ""

# Function to calculate exact match accuracy
def calculate_exact_match_accuracy(predictions, answers):
    # Extract and strip spaces from the models
    pred_models = [extract_model(pred).strip() for pred in predictions]
    true_models = [extract_model(ans).strip() for ans in answers]

    # Debug prints for checking values
    print(pred_models)
    print(true_models)

    correct_matches = sum(p == t for p, t in zip(pred_models, true_models))
    total = len(true_models)
    return correct_matches / total if total > 0 else 0

# Calculate exact match accuracy
accuracy = calculate_exact_match_accuracy(all_pred, all_ans)
print(f"Exact Match Accuracy: {accuracy * 100:.2f}%")
# Out:
# ['Segment-Video', 'Detect-Instrument', 'Detect-Instrument', 'Segment-Video', 'Segment-Video', 'Detect-Instrument', '', 'Segment-Video', 'Detect-Instrument', '', 'Detect-Instrument', '', 'Detect-Instrument', 'Segment-Video', 'Detect-Instrument', '', 'Segment-Video', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Segment-Video', 'Segment-Video', 'Detect-Instrument', 'Segment-Video', 'Segment-Video', 'Detect-Instrument', '', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Segment-Video', 'Detect-Instrument', 'Detect-Instrument', 'Segment-Video', 'Detect-Instrument', 'Segment-Video', 'Segment-Video', 'Detect-Instrument', 'Segment-Video', 'Segment-Video', 'Detect-Instrument', 'Detect-Instrument', 'Segment-Video', 'Detect-Instrument', '', 'Detect-Instrument', 'Segment-Video', 'Detect-Instrument', 'Segment-Video', 'Segment-Video', 'Detect-Instrument', 'Segment-Video', 'Detect-Instrument', 'Segment-Video', 'Detect-Instrument', 'Detect-Instrument', '', 'Segment-Video', 'Detect-Instrument', 'Segment-Video', 'Segment-Video', 'Detect-Instrument', 'Segment-Video', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', '', 'Detect-Instrument', 'Detect-Instrument', 'Segment-Video', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', '', 'Segment-Video', 'Segment-Video', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Segment-Video', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Segment-Video', '', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Segment-Video', 'Detect-Instrument', 'Detect-Instrument', 'Segment-Video', 'Segment-Video', 'Detect-Instrument', 'Detect-Instrument', 'Segment-Video', 'Detect-Instrument', 'Segment-Video', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Segment-Video', 'Segment-Video', '', 'Segment-Video', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Segment-Video', 'Segment-Video', 'Detect-Instrument', 'Segment-Video', 'Segment-Video', 'Detect-Instrument', 'Segment-Video', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Segment-Video', 'Detect-Instrument', 'Detect-Instrument', 'Segment-Video', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Segment-Video', 'Segment-Video', 'Detect-Instrument', 'Detect-Instrument', 'Segment-Video', 'Detect-Instrument', 'Segment-Video', 'Detect-Instrument', 'Segment-Video', 'Detect-Instrument', 'Segment-Video', 'Segment-Video', 'Detect-Instrument', 'Segment-Video', 'Detect-Instrument', 'Segment-Video', '', 'Detect-Instrument', 'Segment-Video', 'Detect-Instrument', 'Detect-Instrument', 'Segment-Video', 'Detect-Instrument', 'Detect-Instrument', 'Segment-Video', 'Detect-Instrument', '', 'Detect-Instrument', 'Segment-Video', 'Detect-Instrument', 'Detect-Instrument', 'Segment-Video', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Segment-Video', 'Segment-Video', 'Segment-Video', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Segment-Video', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Segment-Video', '', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Segment-Video', 'Detect-Instrument', 'Detect-Instrument', 'Segment-Video', 'Segment-Video', 'Detect-Instrument', '', 'Segment-Video', 'Detect-Instrument', 'Segment-Video', 'Detect-Instrument', '', 'Detect-Instrument', 'Segment-Video', 'Segment-Video', '', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Segment-Video', 'Segment-Video', 'Detect-Instrument', 'Segment-Video', 'Segment-Video', '', '', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Segment-Video', 'Detect-Instrument', 'Detect-Instrument', 'Segment-Video', 'Detect-Instrument', '', 'Segment-Video', 'Detect-Instrument', 'Segment-Video', 'Segment-Video', 'Detect-Instrument', ' ...
# ['Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-Instrument', 'Detect-I ...
# Exact Match Accuracy: 55.80%
